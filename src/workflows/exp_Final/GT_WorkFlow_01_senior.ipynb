# %% [markdown]
# # 9 WorkFlow Analista Senior

# %% [markdown]
# ### 9.5 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán
# enriquecer
# <br>El Analista Sr corre sus scripts en máquinas virtuales de al menos 128 GB de RAM en Toronto, creando una virtual machine para cada corrida.
# <br>Estas virtual machines se auto-suicidarán a los 30 minutos de haber terminado de procesar.

# %% [markdown]
# ## 9.7  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Jul 22 23:51:34 2026"

# %%
system("pip install --upgrade --force-reinstall kaggle kagglesdk", intern = FALSE)

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  671174 35.9 1479540    79.1 1479540  79.1
# Vcells 1242565  9.5 8388608    64.0 1978703  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 998443

PARAM$experimento <- 9900
PARAM$dataset <- "analistasr_competencia_2026.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 9.7.1   Preprocesamiento del dataset

# %% [markdown]
# #### 9.7.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 9.7.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
if( !require("mice")) install.packages("mice", repos = "http://cran.us.r-project.org")
require("mice")
# Out:
# Loading required package: mice
#
#
# Attaching package: ‘mice’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following objects are masked from ‘package:base’:
#
#     cbind, rbind

# %%
# Escrito por alumnos de  Universidad Austral  Rosario

Corregir_MICE <- function(pcampo, pmeses) {

  meth <- rep("", ncol(dataset))
  names(meth) <- colnames(dataset)
  meth[names(meth) == pcampo] <- "sample"

  # llamada a mice  !
  imputacion <- mice(dataset,
    method = meth,
    maxit = 5,
    m = 1,
    seed = 7)

  tbl <- mice::complete(dataset)

  dataset[, paste0(pcampo) := ifelse(foto_mes %in% pmeses, tbl[, get(pcampo)], get(pcampo))]

}

# %%
Corregir_interpolar <- function(pcampo, pmeses) {

  tbl <- dataset[, list(
    "v1" = shift(get(pcampo), 1, type = "lag"),
    "v2" = shift(get(pcampo), 1, type = "lead")
  ),
  by = eval(PARAM$dataset_metadata$entity_id)
  ]

  tbl[, paste0(PARAM$dataset_metadata$entity_id) := NULL]
  tbl[, promedio := rowMeans(tbl, na.rm = TRUE)]

  dataset[
    ,
    paste0(pcampo) := ifelse(!(foto_mes %in% pmeses),
      get(pcampo),
      tbl$promedio
    )
  ]
}

# %%
AsignarNA_campomeses <- function(pcampo, pmeses) {

  if( pcampo %in% colnames( dataset ) ) {

    dataset[ foto_mes %in% pmeses, paste0(pcampo) := NA ]
  }
}

# %%
Corregir_atributo <- function(pcampo, pmeses, pmetodo)
{
  # si el campo no existe en el dataset, Afuera !
  if( !(pcampo %in% colnames( dataset )) )
    return( 1 )

  # llamo a la funcion especializada que corresponde
  switch( pmetodo,
    "MachineLearning"     = AsignarNA_campomeses(pcampo, pmeses),
    "EstadisticaClasica"  = Corregir_interpolar(pcampo, pmeses),
    "MICE"                = Corregir_MICE(pcampo, pmeses),
  )

  return( 0 )
}

# %%
Corregir_Rotas <- function(dataset, pmetodo) {
  gc(verbose= FALSE)
  cat( "inicio Corregir_Rotas()\n")
  # acomodo los errores del dataset

  Corregir_atributo("active_quarter", c(202006), pmetodo) # 1
  Corregir_atributo("internet", c(202006), pmetodo) # 2

  Corregir_atributo("mrentabilidad", c(201905, 201910, 202006), pmetodo) # 3
  Corregir_atributo("mrentabilidad_annual", c(201905, 201910, 202006), pmetodo) # 4

  Corregir_atributo("mcomisiones", c(201905, 201910, 202006), pmetodo) # 5

  Corregir_atributo("mactivos_margen", c(201905, 201910, 202006), pmetodo) # 6
  Corregir_atributo("mpasivos_margen", c(201905, 201910, 202006), pmetodo) # 7

  Corregir_atributo("mcuentas_saldo", c(202006), pmetodo) # 8

  Corregir_atributo("ctarjeta_debito_transacciones", c(202006), pmetodo) # 9

  Corregir_atributo("mautoservicio", c(202006), pmetodo) # 10

  Corregir_atributo("ctarjeta_visa_transacciones", c(202006), pmetodo) # 11
  Corregir_atributo("mtarjeta_visa_consumo", c(202006), pmetodo) # 12

  Corregir_atributo("ctarjeta_master_transacciones", c(202006), pmetodo) # 13
  Corregir_atributo("mtarjeta_master_consumo", c(202006), pmetodo) # 14

  Corregir_atributo("ctarjeta_visa_debitos_automaticos", c(201904), pmetodo) # 15
  Corregir_atributo("mttarjeta_visa_debitos_automaticos", c(201904), pmetodo) # 16

  Corregir_atributo("ccajeros_propios_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 17

  Corregir_atributo("mcajeros_propios_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 18

  Corregir_atributo("ctarjeta_visa_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 19

  Corregir_atributo("mtarjeta_visa_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 20

  Corregir_atributo("ctarjeta_master_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 21

  Corregir_atributo("mtarjeta_master_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 22

  Corregir_atributo("ccomisiones_otras", c(201905, 201910, 202006), pmetodo) # 23
  Corregir_atributo("mcomisiones_otras", c(201905, 201910, 202006), pmetodo) # 24

  Corregir_atributo("cextraccion_autoservicio", c(202006), pmetodo) # 25
  Corregir_atributo("mextraccion_autoservicio", c(202006), pmetodo) # 26

  Corregir_atributo("ccheques_depositados", c(202006), pmetodo) # 27
  Corregir_atributo("mcheques_depositados", c(202006), pmetodo) # 28
  Corregir_atributo("ccheques_emitidos", c(202006), pmetodo) # 29
  Corregir_atributo("mcheques_emitidos", c(202006), pmetodo) # 30
  Corregir_atributo("ccheques_depositados_rechazados", c(202006), pmetodo) # 31
  Corregir_atributo("mcheques_depositados_rechazados", c(202006), pmetodo) # 32
  Corregir_atributo("ccheques_emitidos_rechazados", c(202006), pmetodo) # 33
  Corregir_atributo("mcheques_emitidos_rechazados", c(202006), pmetodo) # 34

  Corregir_atributo("tcallcenter", c(202006), pmetodo) # 35
  Corregir_atributo("ccallcenter_transacciones", c(202006), pmetodo) # 36

  Corregir_atributo("thomebanking", c(202006), pmetodo) # 37
  Corregir_atributo("chomebanking_transacciones", c(201910, 202006), pmetodo) # 38

  Corregir_atributo("ccajas_transacciones", c(202006), pmetodo) # 39
  Corregir_atributo("ccajas_consultas", c(202006), pmetodo) # 40

  Corregir_atributo("ccajas_depositos", c(202006, 202105), pmetodo) # 41

  Corregir_atributo("ccajas_extracciones", c(202006), pmetodo) # 41
  Corregir_atributo("ccajas_otras", c(202006), pmetodo) # 43

  Corregir_atributo("catm_trx", c(202006), pmetodo) # 44
  Corregir_atributo("matm", c(202006), pmetodo) # 45
  Corregir_atributo("catm_trx_other", c(202006), pmetodo) # 46
  Corregir_atributo("matm_other", c(202006), pmetodo) # 47

  cat( "fin Corregir_rotas()\n")
}

# %%
# resuelvo el Catastrophe Analysis

setorder( dataset, numero_de_cliente, foto_mes )

PARAM$CA$metodo= "MachineLearning"

if( PARAM$CA$metodo %in% c("MachineLearning", "EstadisticaClasica", "MICE") )
  Corregir_Rotas(dataset, PARAM$CA$metodo)
# Out:
# inicio Corregir_Rotas()
# fin Corregir_rotas()

# %% [markdown]
# #### 9.7.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, ajustando por algunos indices financieros

# %%
# meses que me interesan para el ajuste de variables monetarias
vfoto_mes <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005, 202006,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105, 202106,
  202107, 202108, 202109
)

# %%
# los valores que siguen fueron calculados por alumnos

# momento 1.0  31-dic-2020 a las 23:59
vIPC <- c(
  1.9903030878, 1.9174403544, 1.8296186587,
  1.7728862972, 1.7212488323, 1.6776304408,
  1.6431248196, 1.5814483345, 1.4947526791,
  1.4484037589, 1.3913580777, 1.3404220402,
  1.3154288912, 1.2921698342, 1.2472681797,
  1.2300475145, 1.2118694724, 1.1881073259,
  1.1693969743, 1.1375456949, 1.1065619600,
  1.0681100000, 1.0370000000, 1.0000000000,
  0.9680542110, 0.9344152616, 0.8882274350,
  0.8532444140, 0.8251880213, 0.8003763543,
  0.7763107219, 0.7566381305, 0.7289384687
)

vdolar_blue <- c(
   39.045455,  38.402500,  41.639474,
   44.274737,  46.095455,  45.063333,
   43.983333,  54.842857,  61.059524,
   65.545455,  66.750000,  72.368421,
   77.477273,  78.191667,  82.434211,
  101.087500, 126.236842, 125.857143,
  130.782609, 133.400000, 137.954545,
  170.619048, 160.400000, 153.052632,
  157.900000, 149.780952, 143.615385,
  146.250000, 153.550000, 162.000000,
  178.478261, 180.878788, 184.357143
)

vdolar_oficial <- c(
   38.430000,  39.428000,  42.542105,
   44.354211,  46.088636,  44.955000,
   43.751429,  54.650476,  58.790000,
   61.403182,  63.012632,  63.011579,
   62.983636,  63.580556,  65.200000,
   67.872000,  70.047895,  72.520952,
   75.324286,  77.488500,  79.430909,
   83.134762,  85.484737,  88.181667,
   91.474000,  93.997778,  96.635909,
   98.526000,  99.613158, 100.619048,
  101.619048, 102.569048, 103.781818
)

vUVA <- c(
  2.001408838932958,  1.950325472789153,  1.89323032351521,
  1.8247220405493787, 1.746027787673673,  1.6871348409529485,
  1.6361678865622313, 1.5927529755859773, 1.5549162794128493,
  1.4949100586391746, 1.4197729500774545, 1.3678188186372326,
  1.3136508617223726, 1.2690535173062818, 1.2381595983200178,
  1.211656735577568,  1.1770808941405335, 1.1570338657445522,
  1.1388769475653255, 1.1156993751209352, 1.093638313080772,
  1.0657171590878205, 1.0362173587708712, 1.0,
  0.9669867858358365, 0.9323750098728378, 0.8958202912590305,
  0.8631993702994263, 0.8253893405524657, 0.7928918905364516,
  0.7666323845128089, 0.7428976357662823, 0.721615762047849
)

# %%
tb_indices <- as.data.table( list(
  "IPC" = vIPC,
  "dolar_blue" = vdolar_blue,
  "dolar_oficial" = vdolar_oficial,
  "UVA" = vUVA
  )
)

tb_indices[[ 'foto_mes' ]] <- vfoto_mes

tb_indices
# Out:
#    IPC       dolar_blue dolar_oficial UVA       foto_mes
# 1  1.9903031  39.04545   38.43000     2.0014088 201901
# 2  1.9174404  38.40250   39.42800     1.9503255 201902
# 3  1.8296187  41.63947   42.54210     1.8932303 201903
# 4  1.7728863  44.27474   44.35421     1.8247220 201904
# 5  1.7212488  46.09546   46.08864     1.7460278 201905
# 6  1.6776304  45.06333   44.95500     1.6871348 201906
# 7  1.6431248  43.98333   43.75143     1.6361679 201907
# 8  1.5814483  54.84286   54.65048     1.5927530 201908
# 9  1.4947527  61.05952   58.79000     1.5549163 201909
# 10 1.4484038  65.54546   61.40318     1.4949101 201910
# 11 1.3913581  66.75000   63.01263     1.4197730 201911
# 12 1.3404220  72.36842   63.01158     1.3678188 201912
# 13 1.3154289  77.47727   62.98364     1.3136509 202001
# 14 1.2921698  78.19167   63.58056     1.2690535 202002
# 15 1.2472682  82.43421   65.20000     1.2381596 202003
# 16 1.2300475 101.08750   67.87200     1.2116567 202004
# 17 1.2118695 126.23684   70.04789     1.1770809 202005
# 18 1.1881073 125.85714   72.52095     1.1570339 202006
# 19 1.1693970 130.78261   75.32429     1.1388769 202007
# 20 1.1375457 133.40000   77.48850     1.1156994 202008
# 21 1.1065620 137.95454   79.43091     1.0936383 202009
# 22 1.0681100 170.61905   83.13476     1.0657172 202010
# 23 1.0370000 160.40000   85.48474     1.0362174 202011
# 24 1.0000000 153.05263   88.18167     1.0000000 202012
# 25 0.9680542 157.90000   91.47400     0.9669868 202101
# 26 0.9344153 149.78095   93.99778     0.9323750 202102
# 27 0.8882274 143.61539   96.63591     0.8958203 202103
# 28 0.8532444 146.25000   98.52600     0.8631994 202104
# 29 0.8251880 153.55000   99.61316     0.8253893 202105
# 30 0.8003764 162.00000  100.61905     0.7928919 202106
# 31 0.7763107 178.47826  101.61905     0.7666324 202107
# 32 0.7566381 180.87879  102.56905     0.7428976 202108
# 33 0.7289385 184.35714  103.78182     0.7216158 202109

# %%
drift_UVA <- function(campos_monetarios) {
  cat( "inicio drift_UVA()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD * i.UVA,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_UVA()\n")
}

# %%
drift_dolar_oficial <- function(campos_monetarios) {
  cat( "inicio drift_dolar_oficial()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD / i.dolar_oficial,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_dolar_oficial()\n")
}

# %%
drift_dolar_blue <- function(campos_monetarios) {
  cat( "inicio drift_dolar_blue()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD / i.dolar_blue,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_dolar_blue()\n")
}

# %%
drift_deflacion <- function(campos_monetarios) {
  cat( "inicio drift_deflacion()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD * i.IPC,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_deflacion()\n")
}

# %%
drift_rank_simple <- function(campos_drift) {

  cat( "inicio drift_rank_simple()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[, paste0(campo, "_rank") :=
      (frank(get(campo), ties.method = "random") - 1) / (.N - 1), by = list(foto_mes)]
    dataset[, (campo) := NULL]
  }
  cat( "fin drift_rank_simple()\n")
}

# %%
# El cero se transforma en cero
# los positivos se rankean por su lado
# los negativos se rankean por su lado

drift_rank_cero_fijo <- function(campos_drift) {

  cat( "inicio drift_rank_cero_fijo()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[get(campo) == 0, paste0(campo, "_rank") := 0]
    dataset[get(campo) > 0, paste0(campo, "_rank") :=
      frank(get(campo), ties.method = "random") / .N, by = list(foto_mes)]

    dataset[get(campo) < 0, paste0(campo, "_rank") :=
      -frank(-get(campo), ties.method = "random") / .N, by = list(foto_mes)]
    dataset[, (campo) := NULL]
  }
  cat("\n")
  cat( "fin drift_rank_cero_fijo()\n")
}

# %%
drift_estandarizar <- function(campos_drift) {

  cat( "inicio drift_estandarizar()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[, paste0(campo, "_normal") :=
      (get(campo) -mean(campo, na.rm=TRUE)) / sd(get(campo), na.rm=TRUE),
      by = list(foto_mes)]

    dataset[, (campo) := NULL]
  }
  cat( "fin drift_estandarizar()\n")
}

# %%
# por como armé los nombres de campos,
#  estos son los campos que expresan variables monetarias
campos_monetarios <- colnames(dataset)
campos_monetarios <- campos_monetarios[campos_monetarios %like%
  "^(m|Visa_m|Master_m|vm_m)"]

campos_monetarios
# Out:
#  [1] "mrentabilidad"
#  [2] "mrentabilidad_annual"
#  [3] "mcomisiones"
#  [4] "mactivos_margen"
#  [5] "mpasivos_margen"
#  [6] "mcuenta_corriente_adicional"
#  [7] "mcuenta_corriente"
#  [8] "mcaja_ahorro"
#  [9] "mcaja_ahorro_adicional"
# [10] "mcaja_ahorro_dolares"
# [11] "mcuentas_saldo"
# [12] "mautoservicio"
# [13] "mtarjeta_visa_consumo"
# [14] "mtarjeta_master_consumo"
# [15] "mprestamos_personales"
# [16] "mprestamos_prendarios"
# [17] "mprestamos_hipotecarios"
# [18] "mplazo_fijo_dolares"
# [19] "mplazo_fijo_pesos"
# [20] "minversion1_pesos"
# [21] "minversion1_dolares"
# [22] "minversion2"
# [23] "mpayroll"
# [24] "mpayroll2"
# [25] "mcuenta_debitos_automaticos"
# [26] "mttarjeta_visa_debitos_automaticos"
# [27] "mttarjeta_master_debitos_automaticos"
# [28] "mpagodeservicios"
# [29] "mpagomiscuentas"
# [30] "mcajeros_propios_descuentos"
# [31] "mtarjeta_visa_descuentos"
# [32] "mtarjeta_master_descuentos"
# [33] "mcomisiones_mantenimiento"
# [34] "mcomisiones_otras"
# [35] "mforex_buy"
# [36] "mforex_sell"
# [37] "mtransferencias_recibidas"
# [38] "mtransferencias_emitidas"
# [39] "mextraccion_autoservicio"
# [40] "mcheques_depositados"
# [41] "mcheques_emitidos"
# [42] "mcheques_depositados_rechazados"
# [43] "mcheques_emitidos_rechazados"
# [44] "matm"
# [45] "matm_other"
# [46] "Master_mfinanciacion_limite"
# [47] "Master_msaldototal"
# [48] "Master_msaldopesos"
# [49] "Master_msaldodolares"
# [50] "Master_mconsumospesos"
# [51] "Master_mconsumosdolares"
# [52] "Master_mlimitecompra"
# [53] "Master_madelantopesos"
# [54] "Master_madelantodolares"
# [55] "Master_mpagado"
# [56] "Master_mpagospesos"
# [57] "Master_mpagosdolares"
# [58] "Master_mconsumototal"
# [59] "Master_mpagominimo"
# [60] "Visa_mfinanciacion_limite"
# [61] "Visa_msaldototal"
# [62] "Visa_msaldopesos"
# [63] "Visa_msaldodolares"
# [64] "Visa_mconsumospesos"
# [65] "Visa_mconsumosdolares"
# [66] "Visa_mlimitecompra"
# [67] "Visa_madelantopesos"
# [68] "Visa_madelantodolares"
# [69] "Visa_mpagado"
# [70] "Visa_mpagospesos"
# [71] "Visa_mpagosdolares"
# [72] "Visa_mconsumototal"
# [73] "Visa_mpagominimo"

# %%
# ejecuto el Data Drifting
setorder( dataset, numero_de_cliente, foto_mes )


PARAM$DR$metodo <- "deflacion"

switch(PARAM$DR$metodo,
  "ninguno"        = cat("No hay correccion del data drifting"),
  "rank_simple"    = drift_rank_simple(campos_monetarios),
  "rank_cero_fijo" = drift_rank_cero_fijo(campos_monetarios),
  "deflacion"      = drift_deflacion(campos_monetarios),
  "dolar_blue"     = drift_dolarblue(campos_monetarios),
  "dolar_oficial"  = drift_dolaroficial(campos_monetarios),
  "UVA"            = drift_UVA(campos_monetarios),
  "estandarizar"   = drift_estandarizar(campos_monetarios)
)
# Out:
# inicio drift_deflacion()
# fin drift_deflacion()

# %%
colnames(dataset)
# Out:
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "active_quarter"
#   [4] "cliente_vip"
#   [5] "internet"
#   [6] "cliente_edad"
#   [7] "cliente_antiguedad"
#   [8] "mrentabilidad"
#   [9] "mrentabilidad_annual"
#  [10] "mcomisiones"
#  [11] "mactivos_margen"
#  [12] "mpasivos_margen"
#  [13] "cproductos"
#  [14] "tcuentas"
#  [15] "ccuenta_corriente"
#  [16] "mcuenta_corriente_adicional"
#  [17] "mcuenta_corriente"
#  [18] "ccaja_ahorro"
#  [19] "mcaja_ahorro"
#  [20] "mcaja_ahorro_adicional"
#  [21] "mcaja_ahorro_dolares"
#  [22] "cdescubierto_preacordado"
#  [23] "mcuentas_saldo"
#  [24] "ctarjeta_debito"
#  [25] "ctarjeta_debito_transacciones"
#  [26] "mautoservicio"
#  [27] "ctarjeta_visa"
#  [28] "ctarjeta_visa_transacciones"
#  [29] "mtarjeta_visa_consumo"
#  [30] "ctarjeta_master"
#  [31] "ctarjeta_master_transacciones"
#  [32] "mtarjeta_master_consumo"
#  [33] "cprestamos_personales"
#  [34] "mprestamos_personales"
#  [35] "cprestamos_prendarios"
#  [36] "mprestamos_prendarios"
#  [37] "cprestamos_hipotecarios"
#  [38] "mprestamos_hipotecarios"
#  [39] "cplazo_fijo"
#  [40] "mplazo_fijo_dolares"
#  [41] "mplazo_fijo_pesos"
#  [42] "cinversion1"
#  [43] "minversion1_pesos"
#  [44] "minversion1_dolares"
#  [45] "cinversion2"
#  [46] "minversion2"
#  [47] "cseguro_vida"
#  [48] "cseguro_auto"
#  [49] "cseguro_vivienda"
#  [50] "cseguro_accidentes_personales"
#  [51] "ccaja_seguridad"
#  [52] "cpayroll_trx"
#  [53] "mpayroll"
#  [54] "mpayroll2"
#  [55] "cpayroll2_trx"
#  [56] "ccuenta_debitos_automaticos"
#  [57] "mcuenta_debitos_automaticos"
#  [58] "ctarjeta_visa_debitos_automaticos"
#  [59] "mttarjeta_visa_debitos_automaticos"
#  [60] "ctarjeta_master_debitos_automaticos"
#  [61] "mttarjeta_master_debitos_automaticos"
#  [62] "cpagodeservicios"
#  [63] "mpagodeservicios"
#  [64] "cpagomiscuentas"
#  [65] "mpagomiscuentas"
#  [66] "ccajeros_propios_descuentos"
#  [67] "mcajeros_propios_descuentos"
#  [68] "ctarjeta_visa_descuentos"
#  [69] "mtarjeta_visa_descuentos"
#  [70] "ctarjeta_master_descuentos"
#  [71] "mtarjeta_master_descuentos"
#  [72] "ccomisiones_mantenimiento"
#  [73] "mcomisiones_mantenimiento"
#  [74] "ccomisiones_otras"
#  [75] "mcomisiones_otras"
#  [76] "cforex"
#  [77] "cforex_buy"
#  [78] "mforex_buy"
#  [79] "cforex_sell"
#  [80] "mforex_sell"
#  [81] "ctransferencias_recibidas"
#  [82] "mtransferencias_recibidas"
#  [83] "ctransferencias_emitidas"
#  [84] "mtransferencias_emitidas"
#  [85] "cextraccion_autoservicio"
#  [86] "mextraccion_autoservicio"
#  [87] "ccheques_depositados"
#  [88] "mcheques_depositados"
#  [89] "ccheques_emitidos"
#  [90] "mcheques_emitidos"
#  [91] "ccheques_depositados_rechazados"
#  [92] "mcheques_depositados_rechazados"
#  [93] "ccheques_emitidos_rechazados"
#  [94] "mcheques_emitidos_rechazados"
#  [95] "tcallcenter"
#  [96] "ccallcenter_transacciones"
#  [97] "thomebanking"
#  [98] "chomebanking_transacciones"
#  [99] "ccajas_transacciones"
# [100] "ccajas_consultas"
# [101] "ccajas_depositos"
# [102] "ccajas_extracciones"
# [103] "ccajas_otras"
# [104] "catm_trx"
# [105] "matm"
# [106] "catm_trx_other"
# [107] "matm_other"
# [108] "ctrx_quarter"
# [109] "tmobile_app"
# [110] "cmobile_app_trx"
# [111] "Master_delinquency"
# [112] "Master_status"
# [113] "Master_mfinanciacion_limite"
# [114] "Master_Fvencimiento"
# [115] "Master_Finiciomora"
# [116] "Master_msaldototal"
# [117] "Master_msaldopesos"
# [118] "Master_msaldodolares"
# [119] "Master_mconsumospesos"
# [120] "Master_mconsumosdolares"
# [121] "Master_mlimitecompra"
# [122] "Master_madelantopesos"
# [123] "Master_madelantodolares"
# [124] "Master_fultimo_cierre"
# [125] "Master_mpagado"
# [126] "Master_mpagospesos"
# [127] "Master_mpagosdolares"
# [128] "Master_fechaalta"
# [129] "Master_mconsumototal"
# [130] "Master_cconsumos"
# [131] "Master_cadelantosefectivo"
# [132] "Master_mpagominimo"
# [133] "Visa_delinquency"
# [134] "Visa_status"
# [135] "Visa_mfinanciacion_limite"
# [136] "Visa_Fvencimiento"
# [137] "Visa_Finiciomora"
# [138] "Visa_msaldototal"
# [139] "Visa_msaldopesos"
# [140] "Visa_msaldodolares"
# [141] "Visa_mconsumospesos"
# [142] "Visa_mconsumosdolares"
# [143] "Visa_mlimitecompra"
# [144] "Visa_madelantopesos"
# [145] "Visa_madelantodolares"
# [146] "Visa_fultimo_cierre"
# [147] "Visa_mpagado"
# [148] "Visa_mpagospesos"
# [149] "Visa_mpagosdolares"
# [150] "Visa_fechaalta"
# [151] "Visa_mconsumototal"
# [152] "Visa_cconsumos"
# [153] "Visa_cadelantosefectivo"
# [154] "Visa_mpagominimo"
# [155] "clase_ternaria"

# %% [markdown]
# #### 9.7.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
if( !require("lubridate")) install.packages("lubridate", repos = "http://cran.us.r-project.org")
require("lubridate")
# Out:
# Loading required package: lubridate
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     hour, isoweek, isoyear, mday, minute, month, quarter, second, wday,
#     week, yday, year
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# %%
# Esta es la parte que los alumnos deben desplegar todo su ingenio
# Agregar aqui sus PROPIAS VARIABLES manuales

AgregarVariables_IntraMes <- function(dataset) {
  cat( "inicio AgregarVariables_IntraMes()\n")
  gc(verbose= FALSE)
  # INICIO de la seccion donde se deben hacer cambios con variables nuevas

  # el mes 1,2, ..12
  if( atributos_presentes( c("foto_mes") ))
    dataset[, kmes := foto_mes %% 100]

  # creo un ctr_quarter que tenga en cuenta cuando
  # los clientes hace 3 menos meses que estan
  # ya que seria injusto considerar las transacciones medidas en menor tiempo
  if( atributos_presentes( c("ctrx_quarter") ))
    dataset[, ctrx_quarter_normalizado := as.numeric(ctrx_quarter) ]

  if( atributos_presentes( c("ctrx_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 1, ctrx_quarter_normalizado := ctrx_quarter * 5]

  if( atributos_presentes( c("ctrx_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 2, ctrx_quarter_normalizado := ctrx_quarter * 2]

  if( atributos_presentes( c("ctrx_quarter", "cliente_antiguedad") ))
    dataset[
      cliente_antiguedad == 3,
      ctrx_quarter_normalizado := ctrx_quarter * 1.2
    ]

   if(atributos_presentes(c("foto_mes")))
    dataset[,foto_mes_formato_fecha := as.Date(paste(substr(dataset$foto_mes,1,4),substr(dataset$foto_mes,5,6),"01",sep='-'))]

  #dataset$foto_mes_formato_fecha <<- as.Date(paste(substr(dataset$foto_mes,1,4),substr(dataset$foto_mes,5,6),"01",sep='-'))

  if(atributos_presentes(c("cantidad_total_transacciones"))){
   auxiliarmenos1 <- dataset[,list(numero_de_cliente,foto_mes_formato_fecha, cantidad_total_transacciones)]
   auxiliarmenos2 <- dataset[,list(numero_de_cliente,foto_mes_formato_fecha,cantidad_total_transacciones)]
   # auxiliarmenos1$foto_mes_formato_fecha <- as.Date(auxiliarmenos1$foto_mes_formato_fecha)
   # auxiliarmenos2$foto_mes_formato_fecha <- as.Date(auxiliarmenos2$foto_mes_formato_fecha)
   auxiliarmenos1$foto_mes_formato_fecha <- auxiliarmenos1$foto_mes_formato_fecha  %m-%  months(1)
   auxiliarmenos2$foto_mes_formato_fecha <- auxiliarmenos2$foto_mes_formato_fecha %m-% months(2)
   auxiliarmenos1$codigo <- paste(auxiliarmenos1$numero_de_cliente,auxiliarmenos1$foto_mes_formato_fecha,sep='-')
   auxiliarmenos2$codigo <- paste(auxiliarmenos2$numero_de_cliente,auxiliarmenos2$foto_mes_formato_fecha,sep='-')

   dataset[, codigo := paste(numero_de_cliente, foto_mes_formato_fecha, sep='-') ]

   dataset[ auxiliarmenos1,
            on = "codigo",
            transaccionesmenos1 := i.cantidad_total_transacciones ]

   dataset[ auxiliarmenos2,
            on = "codigo",
            transaccionesmenos2 := i.cantidad_total_transacciones ]

   dataset[, cantidad_total_transacciones_quarter := rowSums(cbind(cantidad_total_transacciones +
    transaccionesmenos1 + transaccionesmenos2),na.rm=T) ]

   dataset[, codigo := NULL ]
   dataset[, transaccionesmenos1 := NULL ]
   dataset[, transaccionesmenos2 := NULL ]
   dataset[, foto_mes_formato_fecha := NULL ]
   rm(auxiliarmenos1)
   rm(auxiliarmenos2)
  }

  if( atributos_presentes( c("cantidad_total_transacciones_quarter") ))
    dataset[, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter]

  if( atributos_presentes( c("cantidad_total_transacciones_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 1, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter * 5]

  if( atributos_presentes( c("cantidad_total_transacciones_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 2, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter * 2]

  if( atributos_presentes( c("cantidad_total_transacciones_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 3, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter * 1.2]

  # variable extraida de una tesis de maestria de Irlanda
  if( atributos_presentes( c("mpayroll", "cliente_edad") ))
    dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

  # se crean los nuevos campos para MasterCard  y Visa,
  #  teniendo en cuenta los NA's
  # varias formas de combinar Visa_status y Master_status
  if( atributos_presentes( c("Master_status", "Visa_status") ))
  {
    dataset[, vm_status01 := pmax(Master_status, Visa_status, na.rm = TRUE)]
    dataset[, vm_status02 := Master_status + Visa_status]

    dataset[, vm_status03 := pmax(
      ifelse(is.na(Master_status), 10, Master_status),
      ifelse(is.na(Visa_status), 10, Visa_status)
    )]

    dataset[, vm_status04 := ifelse(is.na(Master_status), 10, Master_status)
      + ifelse(is.na(Visa_status), 10, Visa_status)]

    dataset[, vm_status05 := ifelse(is.na(Master_status), 10, Master_status)
      + 100 * ifelse(is.na(Visa_status), 10, Visa_status)]

    dataset[, vm_status06 := ifelse(is.na(Visa_status),
      ifelse(is.na(Master_status), 10, Master_status),
      Visa_status
    )]

    dataset[, mv_status07 := ifelse(is.na(Master_status),
      ifelse(is.na(Visa_status), 10, Visa_status),
      Master_status
    )]
  }


  # combino MasterCard y Visa
  if( atributos_presentes( c("Master_mfinanciacion_limite", "Visa_mfinanciacion_limite") ))
    dataset[, vm_mfinanciacion_limite := rowSums(cbind(Master_mfinanciacion_limite, Visa_mfinanciacion_limite), na.rm = TRUE)]

  if( atributos_presentes( c("Master_Fvencimiento", "Visa_Fvencimiento") ))
    dataset[, vm_Fvencimiento := pmin(Master_Fvencimiento, Visa_Fvencimiento, na.rm = TRUE)]

  if( atributos_presentes( c("Master_Finiciomora", "Visa_Finiciomora") ))
    dataset[, vm_Finiciomora := pmin(Master_Finiciomora, Visa_Finiciomora, na.rm = TRUE)]

  if( atributos_presentes( c("Master_msaldototal", "Visa_msaldototal") ))
    dataset[, vm_msaldototal := rowSums(cbind(Master_msaldototal, Visa_msaldototal), na.rm = TRUE)]

  if( atributos_presentes( c("Master_msaldopesos", "Visa_msaldopesos") ))
    dataset[, vm_msaldopesos := rowSums(cbind(Master_msaldopesos, Visa_msaldopesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_msaldodolares", "Visa_msaldodolares") ))
    dataset[, vm_msaldodolares := rowSums(cbind(Master_msaldodolares, Visa_msaldodolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mconsumospesos", "Visa_mconsumospesos") ))
    dataset[, vm_mconsumospesos := rowSums(cbind(Master_mconsumospesos, Visa_mconsumospesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mconsumosdolares", "Visa_mconsumosdolares") ))
    dataset[, vm_mconsumosdolares := rowSums(cbind(Master_mconsumosdolares, Visa_mconsumosdolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mlimitecompra", "Visa_mlimitecompra") ))
    dataset[, vm_mlimitecompra := rowSums(cbind(Master_mlimitecompra, Visa_mlimitecompra), na.rm = TRUE)]

  if( atributos_presentes( c("Master_madelantopesos", "Visa_madelantopesos") ))
    dataset[, vm_madelantopesos := rowSums(cbind(Master_madelantopesos, Visa_madelantopesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_madelantodolares", "Visa_madelantodolares") ))
    dataset[, vm_madelantodolares := rowSums(cbind(Master_madelantodolares, Visa_madelantodolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_fultimo_cierre", "Visa_fultimo_cierre") ))
    dataset[, vm_fultimo_cierre := pmax(Master_fultimo_cierre, Visa_fultimo_cierre, na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagado", "Visa_mpagado") ))
    dataset[, vm_mpagado := rowSums(cbind(Master_mpagado, Visa_mpagado), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagospesos", "Visa_mpagospesos") ))
    dataset[, vm_mpagospesos := rowSums(cbind(Master_mpagospesos, Visa_mpagospesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagosdolares", "Visa_mpagosdolares") ))
    dataset[, vm_mpagosdolares := rowSums(cbind(Master_mpagosdolares, Visa_mpagosdolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_fechaalta", "Visa_fechaalta") ))
    dataset[, vm_fechaalta := pmax(Master_fechaalta, Visa_fechaalta, na.rm = TRUE)]

  if( atributos_presentes( c("Master_mconsumototal", "Visa_mconsumototal") ))
    dataset[, vm_mconsumototal := rowSums(cbind(Master_mconsumototal, Visa_mconsumototal), na.rm = TRUE)]

  if( atributos_presentes( c("Master_cconsumos", "Visa_cconsumos") ))
    dataset[, vm_cconsumos := rowSums(cbind(Master_cconsumos, Visa_cconsumos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_cadelantosefectivo", "Visa_cadelantosefectivo") ))
    dataset[, vm_cadelantosefectivo := rowSums(cbind(Master_cadelantosefectivo, Visa_cadelantosefectivo), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagominimo", "Visa_mpagominimo") ))
    dataset[, vm_mpagominimo := rowSums(cbind(Master_mpagominimo, Visa_mpagominimo), na.rm = TRUE)]

  # a partir de aqui juego con la suma de Mastercard y Visa
  if( atributos_presentes( c("Master_mlimitecompra", "vm_mlimitecompra") ))
    dataset[, vmr_Master_mlimitecompra := Master_mlimitecompra / vm_mlimitecompra]

  if( atributos_presentes( c("Visa_mlimitecompra", "vm_mlimitecompra") ))
    dataset[, vmr_Visa_mlimitecompra := Visa_mlimitecompra / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldototal", "vm_mlimitecompra") ))
    dataset[, vmr_msaldototal := vm_msaldototal / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldopesos", "vm_mlimitecompra") ))
    dataset[, vmr_msaldopesos := vm_msaldopesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldopesos", "vm_msaldototal") ))
    dataset[, vmr_msaldopesos2 := vm_msaldopesos / vm_msaldototal]

  if( atributos_presentes( c("vm_msaldodolares", "vm_mlimitecompra") ))
    dataset[, vmr_msaldodolares := vm_msaldodolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldodolares", "vm_msaldototal") ))
    dataset[, vmr_msaldodolares2 := vm_msaldodolares / vm_msaldototal]

  if( atributos_presentes( c("vm_mconsumospesos", "vm_mlimitecompra") ))
    dataset[, vmr_mconsumospesos := vm_mconsumospesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mconsumosdolares", "vm_mlimitecompra") ))
    dataset[, vmr_mconsumosdolares := vm_mconsumosdolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_madelantopesos", "vm_mlimitecompra") ))
    dataset[, vmr_madelantopesos := vm_madelantopesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_madelantodolares", "vm_mlimitecompra") ))
    dataset[, vmr_madelantodolares := vm_madelantodolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagado", "vm_mlimitecompra") ))
    dataset[, vmr_mpagado := vm_mpagado / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagospesos", "vm_mlimitecompra") ))
    dataset[, vmr_mpagospesos := vm_mpagospesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagosdolares", "vm_mlimitecompra") ))
    dataset[, vmr_mpagosdolares := vm_mpagosdolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mconsumototal", "vm_mlimitecompra") ))
    dataset[, vmr_mconsumototal := vm_mconsumototal / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagominimo", "vm_mlimitecompra") ))
    dataset[, vmr_mpagominimo := vm_mpagominimo / vm_mlimitecompra]

  # Aqui debe usted agregar sus propias nuevas variables

  # valvula de seguridad para evitar valores infinitos
  # paso los infinitos a NULOS
  infinitos <- lapply(
    names(dataset),
    function(.name) dataset[, sum(is.infinite(get(.name)))]
  )

  infinitos_qty <- sum(unlist(infinitos))
  if (infinitos_qty > 0) {
    cat(
      "ATENCION, hay", infinitos_qty,
      "valores infinitos en tu dataset. Seran pasados a NA\n"
    )
    dataset[mapply(is.infinite, dataset)] <<- NA
  }


  # valvula de seguridad para evitar valores NaN  que es 0/0
  # paso los NaN a 0 , decision polemica si las hay
  # se invita a asignar un valor razonable segun la semantica del campo creado
  nans <- lapply(
    names(dataset),
    function(.name) dataset[, sum(is.nan(get(.name)))]
  )

  nans_qty <- sum(unlist(nans))
  if (nans_qty > 0) {
    cat(
      "ATENCION, hay", nans_qty,
      "valores NaN 0/0 en tu dataset. Seran pasados arbitrariamente a 0\n"
    )

    cat("Si no te gusta la decision, modifica a gusto el programa!\n\n")
    dataset[mapply(is.nan, dataset)] <<- 0
  }

  cat( "fin AgregarVariables_IntraMes()\n")
}

# %%
# agrego las variables intra mes

AgregarVariables_IntraMes(dataset)
# Out:
# inicio AgregarVariables_IntraMes()
# ATENCION, hay 105 valores infinitos en tu dataset. Seran pasados a NA
# ATENCION, hay 3328805 valores NaN 0/0 en tu dataset. Seran pasados arbitrariamente a 0
# Si no te gusta la decision, modifica a gusto el programa!
#
# fin AgregarVariables_IntraMes()

# %%
# visualizo las columas del dataset a esta etapa
ncol(dataset)
colnames(dataset)
# Out:
# [1] 202
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "active_quarter"
#   [4] "cliente_vip"
#   [5] "internet"
#   [6] "cliente_edad"
#   [7] "cliente_antiguedad"
#   [8] "mrentabilidad"
#   [9] "mrentabilidad_annual"
#  [10] "mcomisiones"
#  [11] "mactivos_margen"
#  [12] "mpasivos_margen"
#  [13] "cproductos"
#  [14] "tcuentas"
#  [15] "ccuenta_corriente"
#  [16] "mcuenta_corriente_adicional"
#  [17] "mcuenta_corriente"
#  [18] "ccaja_ahorro"
#  [19] "mcaja_ahorro"
#  [20] "mcaja_ahorro_adicional"
#  [21] "mcaja_ahorro_dolares"
#  [22] "cdescubierto_preacordado"
#  [23] "mcuentas_saldo"
#  [24] "ctarjeta_debito"
#  [25] "ctarjeta_debito_transacciones"
#  [26] "mautoservicio"
#  [27] "ctarjeta_visa"
#  [28] "ctarjeta_visa_transacciones"
#  [29] "mtarjeta_visa_consumo"
#  [30] "ctarjeta_master"
#  [31] "ctarjeta_master_transacciones"
#  [32] "mtarjeta_master_consumo"
#  [33] "cprestamos_personales"
#  [34] "mprestamos_personales"
#  [35] "cprestamos_prendarios"
#  [36] "mprestamos_prendarios"
#  [37] "cprestamos_hipotecarios"
#  [38] "mprestamos_hipotecarios"
#  [39] "cplazo_fijo"
#  [40] "mplazo_fijo_dolares"
#  [41] "mplazo_fijo_pesos"
#  [42] "cinversion1"
#  [43] "minversion1_pesos"
#  [44] "minversion1_dolares"
#  [45] "cinversion2"
#  [46] "minversion2"
#  [47] "cseguro_vida"
#  [48] "cseguro_auto"
#  [49] "cseguro_vivienda"
#  [50] "cseguro_accidentes_personales"
#  [51] "ccaja_seguridad"
#  [52] "cpayroll_trx"
#  [53] "mpayroll"
#  [54] "mpayroll2"
#  [55] "cpayroll2_trx"
#  [56] "ccuenta_debitos_automaticos"
#  [57] "mcuenta_debitos_automaticos"
#  [58] "ctarjeta_visa_debitos_automaticos"
#  [59] "mttarjeta_visa_debitos_automaticos"
#  [60] "ctarjeta_master_debitos_automaticos"
#  [61] "mttarjeta_master_debitos_automaticos"
#  [62] "cpagodeservicios"
#  [63] "mpagodeservicios"
#  [64] "cpagomiscuentas"
#  [65] "mpagomiscuentas"
#  [66] "ccajeros_propios_descuentos"
#  [67] "mcajeros_propios_descuentos"
#  [68] "ctarjeta_visa_descuentos"
#  [69] "mtarjeta_visa_descuentos"
#  [70] "ctarjeta_master_descuentos"
#  [71] "mtarjeta_master_descuentos"
#  [72] "ccomisiones_mantenimiento"
#  [73] "mcomisiones_mantenimiento"
#  [74] "ccomisiones_otras"
#  [75] "mcomisiones_otras"
#  [76] "cforex"
#  [77] "cforex_buy"
#  [78] "mforex_buy"
#  [79] "cforex_sell"
#  [80] "mforex_sell"
#  [81] "ctransferencias_recibidas"
#  [82] "mtransferencias_recibidas"
#  [83] "ctransferencias_emitidas"
#  [84] "mtransferencias_emitidas"
#  [85] "cextraccion_autoservicio"
#  [86] "mextraccion_autoservicio"
#  [87] "ccheques_depositados"
#  [88] "mcheques_depositados"
#  [89] "ccheques_emitidos"
#  [90] "mcheques_emitidos"
#  [91] "ccheques_depositados_rechazados"
#  [92] "mcheques_depositados_rechazados"
#  [93] "ccheques_emitidos_rechazados"
#  [94] "mcheques_emitidos_rechazados"
#  [95] "tcallcenter"
#  [96] "ccallcenter_transacciones"
#  [97] "thomebanking"
#  [98] "chomebanking_transacciones"
#  [99] "ccajas_transacciones"
# [100] "ccajas_consultas"
# [101] "ccajas_depositos"
# [102] "ccajas_extracciones"
# [103] "ccajas_otras"
# [104] "catm_trx"
# [105] "matm"
# [106] "catm_trx_other"
# [107] "matm_other"
# [108] "ctrx_quarter"
# [109] "tmobile_app"
# [110] "cmobile_app_trx"
# [111] "Master_delinquency"
# [112] "Master_status"
# [113] "Master_mfinanciacion_limite"
# [114] "Master_Fvencimiento"
# [115] "Master_Finiciomora"
# [116] "Master_msaldototal"
# [117] "Master_msaldopesos"
# [118] "Master_msaldodolares"
# [119] "Master_mconsumospesos"
# [120] "Master_mconsumosdolares"
# [121] "Master_mlimitecompra"
# [122] "Master_madelantopesos"
# [123] "Master_madelantodolares"
# [124] "Master_fultimo_cierre"
# [125] "Master_mpagado"
# [126] "Master_mpagospesos"
# [127] "Master_mpagosdolares"
# [128] "Master_fechaalta"
# [129] "Master_mconsumototal"
# [130] "Master_cconsumos"
# [131] "Master_cadelantosefectivo"
# [132] "Master_mpagominimo"
# [133] "Visa_delinquency"
# [134] "Visa_status"
# [135] "Visa_mfinanciacion_limite"
# [136] "Visa_Fvencimiento"
# [137] "Visa_Finiciomora"
# [138] "Visa_msaldototal"
# [139] "Visa_msaldopesos"
# [140] "Visa_msaldodolares"
# [141] "Visa_mconsumospesos"
# [142] "Visa_mconsumosdolares"
# [143] "Visa_mlimitecompra"
# [144] "Visa_madelantopesos"
# [145] "Visa_madelantodolares"
# [146] "Visa_fultimo_cierre"
# [147] "Visa_mpagado"
# [148] "Visa_mpagospesos"
# [149] "Visa_mpagosdolares"
# [150] "Visa_fechaalta"
# [151] "Visa_mconsumototal"
# [152] "Visa_cconsumos"
# [153] "Visa_cadelantosefectivo"
# [154] "Visa_mpagominimo"
# [155] "clase_ternaria"
# [156] "kmes"
# [157] "ctrx_quarter_normalizado"
# [158] "foto_mes_formato_fecha"
# [159] "mpayroll_sobre_edad"
# [160] "vm_status01"
# [161] "vm_status02"
# [162] "vm_status03"
# [163] "vm_status04"
# [164] "vm_status05"
# [165] "vm_status06"
# [166] "mv_status07"
# [167] "vm_mfinanciacion_limite"
# [168] "vm_Fvencimiento"
# [169] "vm_Finiciomora"
# [170] "vm_msaldototal"
# [171] "vm_msaldopesos"
# [172] "vm_msaldodolares"
# [173] "vm_mconsumospesos"
# [174] "vm_mconsumosdolares"
# [175] "vm_mlimitecompra"
# [176] "vm_madelantopesos"
# [177] "vm_madelantodolares"
# [178] "vm_fultimo_cierre"
# [179] "vm_mpagado"
# [180] "vm_mpagospesos"
# [181] "vm_mpagosdolares"
# [182] "vm_fechaalta"
# [183] "vm_mconsumototal"
# [184] "vm_cconsumos"
# [185] "vm_cadelantosefectivo"
# [186] "vm_mpagominimo"
# [187] "vmr_Master_mlimitecompra"
# [188] "vmr_Visa_mlimitecompra"
# [189] "vmr_msaldototal"
# [190] "vmr_msaldopesos"
# [191] "vmr_msaldopesos2"
# [192] "vmr_msaldodolares"
# [193] "vmr_msaldodolares2"
# [194] "vmr_mconsumospesos"
# [195] "vmr_mconsumosdolares"
# [196] "vmr_madelantopesos"
# [197] "vmr_madelantodolares"
# [198] "vmr_mpagado"
# [199] "vmr_mpagospesos"
# [200] "vmr_mpagosdolares"
# [201] "vmr_mconsumototal"
# [202] "vmr_mpagominimo"

# %% [markdown]
# #### 9.7.1.4  FEhist Feature Engineering historico
#
# El Feature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
if( !require("Rcpp")) install.packages("Rcpp", repos = "http://cran.us.r-project.org")
require("Rcpp")
# Out:
# Loading required package: Rcpp

# %%
# se calculan para los 6 meses previos el minimo, maximo y
#  tendencia calculada con cuadrados minimos
# la formula de calculo de la tendencia puede verse en
#  https://stats.libretexts.org/Bookshelves/Introductory_Statistics/Book%3A_Introductory_Statistics_(Shafer_and_Zhang)/10%3A_Correlation_and_Regression/10.04%3A_The_Least_Squares_Regression_Line
# para la maxíma velocidad esta funcion esta escrita en lenguaje C,
# y no en la porqueria de R o Python

cppFunction("NumericVector fhistC(NumericVector pcolumna, IntegerVector pdesde )
{
  /* Aqui se cargan los valores para la regresion */
  double  x[100] ;
  double  y[100] ;

  int n = pcolumna.size();
  NumericVector out( 5*n );

  for(int i = 0; i < n; i++)
  {
    //lag
    if( pdesde[i]-1 < i )  out[ i + 4*n ]  =  pcolumna[i-1] ;
    else                   out[ i + 4*n ]  =  NA_REAL ;


    int  libre    = 0 ;
    int  xvalor   = 1 ;

    for( int j= pdesde[i]-1;  j<=i; j++ )
    {
       double a = pcolumna[j] ;

       if( !R_IsNA( a ) )
       {
          y[ libre ]= a ;
          x[ libre ]= xvalor ;
          libre++ ;
       }

       xvalor++ ;
    }

    /* Si hay al menos dos valores */
    if( libre > 1 )
    {
      double  xsum  = x[0] ;
      double  ysum  = y[0] ;
      double  xysum = xsum * ysum ;
      double  xxsum = xsum * xsum ;
      double  vmin  = y[0] ;
      double  vmax  = y[0] ;

      for( int h=1; h<libre; h++)
      {
        xsum  += x[h] ;
        ysum  += y[h] ;
        xysum += x[h]*y[h] ;
        xxsum += x[h]*x[h] ;

        if( y[h] < vmin )  vmin = y[h] ;
        if( y[h] > vmax )  vmax = y[h] ;
      }

      out[ i ]  =  (libre*xysum - xsum*ysum)/(libre*xxsum -xsum*xsum) ;
      out[ i + n ]    =  vmin ;
      out[ i + 2*n ]  =  vmax ;
      out[ i + 3*n ]  =  ysum / libre ;
    }
    else
    {
      out[ i       ]  =  NA_REAL ;
      out[ i + n   ]  =  NA_REAL ;
      out[ i + 2*n ]  =  NA_REAL ;
      out[ i + 3*n ]  =  NA_REAL ;
    }
  }

  return  out;
}")

# %%
# calcula la tendencia de las variables cols de los ultimos 6 meses
# la tendencia es la pendiente de la recta que ajusta por cuadrados minimos
# La funcionalidad de ratioavg es autoria de  Daiana Sparta,  UAustral  2021

TendenciaYmuchomas <- function(
    dataset, cols, ventana = 6, tendencia = TRUE,
    minimo = TRUE, maximo = TRUE, promedio = TRUE,
    ratioavg = FALSE, ratiomax = FALSE) {
  gc(verbose= FALSE)
  # Esta es la cantidad de meses que utilizo para la historia
  ventana_regresion <- ventana

  last <- nrow(dataset)

  # creo el vector_desde que indica cada ventana
  # de esta forma se acelera el procesamiento ya que lo hago una sola vez
  vector_ids <- dataset[ , numero_de_cliente ]

  vector_desde <- seq(
    -ventana_regresion + 2,
    nrow(dataset) - ventana_regresion + 1
  )

  vector_desde[1:ventana_regresion] <- 1

  for (i in 2:last) {
    if (vector_ids[i - 1] != vector_ids[i]) {
      vector_desde[i] <- i
    }
  }
  for (i in 2:last) {
    if (vector_desde[i] < vector_desde[i - 1]) {
      vector_desde[i] <- vector_desde[i - 1]
    }
  }

  for (campo in cols) {
    nueva_col <- fhistC(dataset[, get(campo)], vector_desde)

    if (tendencia) {
      dataset[, paste0(campo, "_tend", ventana) :=
        nueva_col[(0 * last + 1):(1 * last)]]
    }

    if (minimo) {
      dataset[, paste0(campo, "_min", ventana) :=
        nueva_col[(1 * last + 1):(2 * last)]]
    }

    if (maximo) {
      dataset[, paste0(campo, "_max", ventana) :=
        nueva_col[(2 * last + 1):(3 * last)]]
    }

    if (promedio) {
      dataset[, paste0(campo, "_avg", ventana) :=
        nueva_col[(3 * last + 1):(4 * last)]]
    }

    if (ratioavg) {
      dataset[, paste0(campo, "_ratioavg", ventana) :=
        get(campo) / nueva_col[(3 * last + 1):(4 * last)]]
    }

    if (ratiomax) {
      dataset[, paste0(campo, "_ratiomax", ventana) :=
        get(campo) / nueva_col[(2 * last + 1):(3 * last)]]
    }
  }
}

# %%
# Feature Engineering Historico

setorder(dataset, numero_de_cliente, foto_mes)

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %%
# parametros de Feature Engineering Historico de Tendencias
PARAM$FE_hist$Tendencias$run <- TRUE
PARAM$FE_hist$Tendencias$ventana <- 6
PARAM$FE_hist$Tendencias$tendencia <- TRUE
PARAM$FE_hist$Tendencias$minimo <- FALSE
PARAM$FE_hist$Tendencias$maximo <- FALSE
PARAM$FE_hist$Tendencias$promedio <- FALSE
PARAM$FE_hist$Tendencias$ratioavg <- FALSE
PARAM$FE_hist$Tendencias$ratiomax <- FALSE

# %%
cols_lagueables <- intersect(cols_lagueables, colnames(dataset))
setorder(dataset, numero_de_cliente, foto_mes)

if( PARAM$FE_hist$Tendencias$run) {
    TendenciaYmuchomas(dataset,
    cols = cols_lagueables,
    ventana = PARAM$FE_hist$Tendencias$ventana, # 6 meses de historia
    tendencia = PARAM$FE_hist$Tendencias$tendencia,
    minimo = PARAM$FE_hist$Tendencias$minimo,
    maximo = PARAM$FE_hist$Tendencias$maximo,
    promedio = PARAM$FE_hist$Tendencias$promedio,
    ratioavg = PARAM$FE_hist$Tendencias$ratioavg,
    ratiomax = PARAM$FE_hist$Tendencias$ratiomax
  )
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 1197
#    [1] "numero_de_cliente"
#    [2] "foto_mes"
#    [3] "active_quarter"
#    [4] "cliente_vip"
#    [5] "internet"
#    [6] "cliente_edad"
#    [7] "cliente_antiguedad"
#    [8] "mrentabilidad"
#    [9] "mrentabilidad_annual"
#   [10] "mcomisiones"
#   [11] "mactivos_margen"
#   [12] "mpasivos_margen"
#   [13] "cproductos"
#   [14] "tcuentas"
#   [15] "ccuenta_corriente"
#   [16] "mcuenta_corriente_adicional"
#   [17] "mcuenta_corriente"
#   [18] "ccaja_ahorro"
#   [19] "mcaja_ahorro"
#   [20] "mcaja_ahorro_adicional"
#   [21] "mcaja_ahorro_dolares"
#   [22] "cdescubierto_preacordado"
#   [23] "mcuentas_saldo"
#   [24] "ctarjeta_debito"
#   [25] "ctarjeta_debito_transacciones"
#   [26] "mautoservicio"
#   [27] "ctarjeta_visa"
#   [28] "ctarjeta_visa_transacciones"
#   [29] "mtarjeta_visa_consumo"
#   [30] "ctarjeta_master"
#   [31] "ctarjeta_master_transacciones"
#   [32] "mtarjeta_master_consumo"
#   [33] "cprestamos_personales"
#   [34] "mprestamos_personales"
#   [35] "cprestamos_prendarios"
#   [36] "mprestamos_prendarios"
#   [37] "cprestamos_hipotecarios"
#   [38] "mprestamos_hipotecarios"
#   [39] "cplazo_fijo"
#   [40] "mplazo_fijo_dolares"
#   [41] "mplazo_fijo_pesos"
#   [42] "cinversion1"
#   [43] "minversion1_pesos"
#   [44] "minversion1_dolares"
#   [45] "cinversion2"
#   [46] "minversion2"
#   [47] "cseguro_vida"
#   [48] "cseguro_auto"
#   [49] "cseguro_vivienda"
#   [50] "cseguro_accidentes_personales"
#   [51] "ccaja_seguridad"
#   [52] "cpayroll_trx"
#   [53] "mpayroll"
#   [54] "mpayroll2"
#   [55] "cpayroll2_trx"
#   [56] "ccuenta_debitos_automaticos"
#   [57] "mcuenta_debitos_automaticos"
#   [58] "ctarjeta_visa_debitos_automaticos"
#   [59] "mttarjeta_visa_debitos_automaticos"
#   [60] "ctarjeta_master_debitos_automaticos"
#   [61] "mttarjeta_master_debitos_automaticos"
#   [62] "cpagodeservicios"
#   [63] "mpagodeservicios"
#   [64] "cpagomiscuentas"
#   [65] "mpagomiscuentas"
#   [66] "ccajeros_propios_descuentos"
#   [67] "mcajeros_propios_descuentos"
#   [68] "ctarjeta_visa_descuentos"
#   [69] "mtarjeta_visa_descuentos"
#   [70] "ctarjeta_master_descuentos"
#   [71] "mtarjeta_master_descuentos"
#   [72] "ccomisiones_mantenimiento"
#   [73] "mcomisiones_mantenimiento"
#   [74] "ccomisiones_otras"
#   [75] "mcomisiones_otras"
#   [76] "cforex"
#   [77] "cforex_buy"
#   [78] "mforex_buy"
#   [79] "cforex_sell"
#   [80] "mforex_sell"
#   [81] "ctransferencias_recibidas"
#   [82] "mtransferencias_recibidas"
#   [83] "ctransferencias_emitidas"
#   [84] "mtransferencias_emitidas"
#   [85] "cextraccion_autoservicio"
#   [86] "mextraccion_autoservicio"
#   [87] "ccheques_depositados"
#   [88] "mcheques_depositados"
#   [89] "ccheques_emitidos"
#   [90] "mcheques_emitidos"
#   [91] "ccheques_depositados_rechazados"
#   [92] "mcheques_depositados_rechazados"
#   [93] "ccheques_emitidos_rechazados"
#   [94] "mcheques_emitidos_rechazados"
#   [95] "tcallcenter"
#   [96] "ccallcenter_transacciones"
#   [97] "thomebanking"
#   [98] "chomebanking_transacciones"
#   [99] "ccajas_transacciones"
#  [100] "ccajas_consultas"
#  [101] "ccajas_depositos"
#  [102] "ccajas_extracciones"
#  [103] "ccajas_otras"
#  [104] "catm_trx"
#  [105] "matm"
#  [106] "catm_trx_other"
#  [107] "matm_other"
#  [108] "ctrx_quarter"
#  [109] "tmobile_app"
#  [110] "cmobile_app_trx"
#  [111] "Master_delinquency"
#  [112] "Master_status"
#  [113] "Master_mfinanciacion_limite"
#  [114] "Master_Fvencimiento"
#  [115] "Master_Finiciomora"
#  [116] "Master_msaldototal"
#  [117] "Master_msaldopesos"
#  [118] "Master_msaldodolares"
#  [119] "Master_mconsumospesos"
#  [120] "Master_mconsumosdolares"
#  [121] "Master_mlimitecompra"
#  [122] "Master_madelantopesos"
#  [123] "Master_madelantodolares"
#  [124] "Master_fultimo_cierre"
#  [125] "Master_mpagado"
#  [126] "Master_mpagospesos"
#  [127] "Master_mpagosdolares"
#  [128] "Master_fechaalta"
#  [129] "Master_mconsumototal"
#  [130] "Master_cconsumos"
#  [131] "Master_cadelantosefectivo"
#  [132] "Master_mpagominimo"
#  [133] "Visa_delinquency"
#  [134] "Visa_status"
#  [135] "Visa_mfinanciacion_limite"
#  [136] "Visa_Fvencimiento"
#  [137] "Visa_Finiciomora"
#  [138] "Visa_msaldototal"
#  [139] "Visa_msaldopesos"
#  [140] "Visa_msaldodolares"
#  [141] "Visa_mconsumospesos"
#  [142] "Visa_mconsumosdolares"
#  [143] "Visa_mlimitecompra"
#  [144] "Visa_madelantopesos"
#  [145] "Visa_madelantodolares"
#  [146] "Visa_fultimo_cierre"
#  [147] "Visa_mpagado"
#  [148] "Visa_mpagospesos"
#  [149] "Visa_mpagosdolares"
#  [150] "Visa_fechaalta"
#  [151] "Visa_mconsumototal"
#  [152] "Visa_cconsumos"
#  [153] "Visa_cadelantosefectivo"
#  [154] "Visa_mpagominimo"
#  [155] "clase_ternaria"
#  [156] "kmes"
#  [157] "ctrx_quarter_normalizado"
#  [158] "foto_mes_formato_fecha"
#  [159] "mpayroll_sobre_edad"
#  [160] "vm_status01"
#  [161] "vm_status02"
#  [162] "vm_status03"
#  [163] "vm_status04"
#  [164] "vm_status05"
#  [165] "vm_status06"
#  [166] "mv_status07"
#  [167] "vm_mfinanciacion_limite"
#  [168] "vm_Fvencimiento"
#  [169] "vm_Finiciomora"
#  [170] "vm_msaldototal"
#  [171] "vm_msaldopesos"
#  [172] "vm_msaldodolares"
#  [173] "vm_mconsumospesos"
#  [174] "vm_mconsumosdolares"
#  [175] "vm_mlimitecompra"
#  [176] "vm_madelantopesos"
#  [177] "vm_madelantodolares"
#  [178] "vm_fultimo_cierre"
#  [179] "vm_mpagado"
#  [180] "vm_mpagospesos"
#  [181] "vm_mpagosdolares"
#  [182] "vm_fechaalta"
#  [183] "vm_mconsumototal"
#  [184] "vm_cconsumos"
#  [185] "vm_cadelantosefectivo"
#  [186] "vm_mpagominimo"
#  [187] "vmr_Master_mlimitecompra"
#  [188] "vmr_Visa_mlimitecompra"
#  [189] "vmr_msaldototal"
#  [190] "vmr_msaldopesos"
#  [191] "vmr_msaldopesos2"
#  [192] "vmr_msaldodolares"
#  [193] "vmr_msaldodolares2"
#  [194] "vmr_mconsumospesos"
#  [195] "vmr_mconsumosdolares"
#  [196] "vmr_madelantopesos"
#  [197] "vmr_madelantodolares"
#  [198] "vmr_mpagado"
#  [199] "vmr_mpagospesos"
#  [200] "vmr_mpagosdolares"
#  [201] "vmr_mconsumototal"
#  [202] "vmr_mpagominimo"
#  [203] "active_quarter_lag1"
#  [204] "cliente_vip_lag1"
#  [205] "internet_lag1"
#  [206] "cliente_edad_lag1"
#  [207] "cliente_antiguedad_lag1"
#  [208] "mrentabilidad_lag1"
#  [209] "mrentabilidad_annual_lag1"
#  [210] "mcomisiones_lag1"
#  [211] "mactivos_margen_lag1"
#  [212] "mpasivos_margen_lag1"
#  [213] "cproductos_lag1"
#  [214] "tcuentas_lag1"
#  [215] "ccuenta_corriente_lag1"
#  [216] "mcuenta_corriente_adicional_lag1"
#  [217] "mcuenta_corriente_lag1"
#  [218] "ccaja_ahorro_lag1"
#  [219] "mcaja_ahorro_lag1"
#  [220] "mcaja_ahorro_adicional_lag1"
#  [221] "mcaja_ahorro_dolares_lag1"
#  [222] "cdescubierto_preacordado_lag1"
#  [223] "mcuentas_saldo_lag1"
#  [224] "ctarjeta_debito_lag1"
#  [225] "ctarjeta_debito_transacciones_lag1"
#  [226] "mautoservicio_lag1"
#  [227] "ctarjeta_visa_lag1"
#  [228] "ctarjeta_visa_transacciones_lag1"
#  [229] "mtarjeta_visa_consumo_lag1"
#  [230] "ctarjeta_master_lag1"
#  [231] "ctarjeta_master_transacciones_lag1"
#  [232] "mtarjeta_master_consumo_lag1"
#  [233] "cprestamos_personales_lag1"
#  [234] "mprestamos_personales_lag1"
#  [235] "cprestamos_prendarios_lag1"
#  [236] "mprestamos_prendarios_lag1"
#  [237] "cprestamos_hipotecarios_lag1"
#  [238] "mprestamos_hipotecarios_lag1"
#  [239] "cplazo_fijo_lag1"
#  [240] "mplazo_fijo_dolares_lag1"
#  [241] "mplazo_fijo_pesos_lag1"
#  [242] "cinversion1_lag1"
#  [243] "minversion1_pesos_lag1"
#  [244] "minversion1_dolares_lag1"
#  [245] "cinversion2_lag1"
#  [246] "minversion2_lag1"
#  [247] "cseguro_vida_lag1"
#  [248] "cseguro_auto_lag1"
#  [249] "cseguro_vivienda_lag1"
#  [250] "cseguro_accidentes_personales_lag1"
#  [251] "ccaja_seguridad_lag1"
#  [252] "cpayroll_trx_lag1"
#  [253] "mpayroll_lag1"
#  [254] "mpayroll2_lag1"
#  [255] "cpayroll2_trx_lag1"
#  [256] "ccuenta_debitos_automaticos_lag1"
#  [257] "mcuenta_debitos_automaticos_lag1"
#  [258] "ctarjeta_visa_debitos_automaticos_lag1"
#  [259] "mttarjeta_visa_debitos_automaticos_lag1"
#  [260] "ctarjeta_master_debitos_automaticos_lag1"
#  [261] "mttarjeta_master_debitos_automaticos_lag1"
#  [262] "cpagodeservicios_lag1"
#  [263] "mpagodeservicios_lag1"
#  [264] "cpagomiscuentas_lag1"
#  [265] "mpagomiscuentas_lag1"
#  [266] "ccajeros_propios_descuentos_lag1"
#  [267] "mcajeros_propios_descuentos_lag1"
#  [268] "ctarjeta_visa_descuentos_lag1"
#  [269] "mtarjeta_visa_descuentos_lag1"
#  [270] "ctarjeta_master_descuentos_lag1"
#  [271] "mtarjeta_master_descuentos_lag1"
#  [272] "ccomisiones_mantenimiento_lag1"
#  [273] "mcomisiones_mantenimiento_lag1"
#  [274] "ccomisiones_otras_lag1"
#  [275] "mcomisiones_otras_lag1"
#  [276] "cforex_lag1"
#  [277] "cforex_buy_lag1"
#  [278] "mforex_buy_lag1"
#  [279] "cforex_sell_lag1"
#  [280] "mforex_sell_lag1"
#  [281] "ctransferencias_recibidas_lag1"
#  [282] "mtransferencias_recibidas_lag1"
#  [283] "ctransferencias_emitidas_lag1"
#  [284] "mtransferencias_emitidas_lag1"
#  [285] "cextraccion_autoservicio_lag1"
#  [286] "mextraccion_autoservicio_lag1"
#  [287] "ccheques_depositados_lag1"
#  [288] "mcheques_depositados_lag1"
#  [289] "ccheques_emitidos_lag1"
#  [290] "mcheques_emitidos_lag1"
#  [291] "ccheques_depositados_rechazados_lag1"
#  [292] "mcheques_depositados_rechazados_lag1"
#  [293] "ccheques_emitidos_rechazados_lag1"
#  [294] "mcheques_emitidos_rechazados_lag1"
#  [295] "tcallcenter_lag1"
#  [296] "ccallcenter_transacciones_lag1"
#  [297] "thomebanking_lag1"
#  [298] "chomebanking_transacciones_lag1"
#  [299] "ccajas_transacciones_lag1"
#  [300] "ccajas_consultas_lag1"
#  [301] "ccajas_depositos_lag1"
#  [302] "ccajas_extracciones_lag1"
#  [303] "ccajas_otras_lag1"
#  [304] "catm_trx_lag1"
#  [305] "matm_lag1"
#  [306] "catm_trx_other_lag1"
#  [307] "matm_other_lag1"
#  [308] "ctrx_quarter_lag1"
#  [309] "tmobile_app_lag1"
#  [310] "cmobile_app_trx_lag1"
#  [311] "Master_delinquency_lag1"
#  [312] "Master_status_lag1"
#  [313] "Master_mfinanciacion_limite_lag1"
#  [314] "Master_Fvencimiento_lag1"
#  [315] "Master_Finiciomora_lag1"
#  [316] "Master_msaldototal_lag1"
#  [317] "Master_msaldopesos_lag1"
#  [318] "Master_msaldodolares_lag1"
#  [319] "Master_mconsumospesos_lag1"
#  [320] "Master_mconsumosdolares_lag1"
#  [321] "Master_mlimitecompra_lag1"
#  [322] "Master_madelantopesos_lag1"
#  [323] "Master_madelantodolares_lag1"
#  [324] "Master_fultimo_cierre_lag1"
#  [325] "Master_mpagado_lag1"
#  [326] "Master_mpagospesos_lag1"
#  [327] "Master_mpagosdolares_lag1"
#  [328] "Master_fechaalta_lag1"
#  [329] "Master_mconsumototal_lag1"
#  [330] "Master_cconsumos_lag1"
#  [331] "Master_cadelantosefectivo_lag1"
#  [332] "Master_mpagominimo_lag1"
#  [333] "Visa_delinquency_lag1"
#  [334] "Visa_status_lag1"
#  [335] "Visa_mfinanciacion_limite_lag1"
#  [336] "Visa_Fvencimiento_lag1"
#  [337] "Visa_Finiciomora_lag1"
#  [338] "Visa_msaldototal_lag1"
#  [339] "Visa_msaldopesos_lag1"
#  [340] "Visa_msaldodolares_lag1"
#  [341] "Visa_mconsumospesos_lag1"
#  [342] "Visa_mconsumosdolares_lag1"
#  [343] "Visa_mlimitecompra_lag1"
#  [344] "Visa_madelantopesos_lag1"
#  [345] "Visa_madelantodolares_lag1"
#  [346] "Visa_fultimo_cierre_lag1"
#  [347] "Visa_mpagado_lag1"
#  [348] "Visa_mpagospesos_lag1"
#  [349] "Visa_mpagosdolares_lag1"
#  [350] "Visa_fechaalta_lag1"
#  [351] "Visa_mconsumototal_lag1"
#  [352] "Visa_cconsumos_lag1"
#  [353] "Visa_cadelantosefectivo_lag1"
#  [354] "Visa_mpagominimo_lag1"
#  [355] "kmes_lag1"
#  [356] "ctrx_quarter_normalizado_lag1"
#  [357] "foto_mes_formato_fecha_lag1"
#  [358] "mpayroll_sobre_edad_lag1"
#  [359] "vm_status01_lag1"
#  [360] "vm_status02_lag1"
#  [361] "vm_status03_lag1"
#  [362] "vm_status04_lag1"
#  [363] "vm_status05_lag1"
#  [364] "vm_status06_lag1"
#  [365] "mv_status07_lag1"
#  [366] "vm_mfinanciacion_limite_lag1"
#  [367] "vm_Fvencimiento_lag1"
#  [368] "vm_Finiciomora_lag1"
#  [369] "vm_msaldototal_lag1"
#  [370] "vm_msaldopesos_lag1"
#  [371] "vm_msaldodolares_lag1"
#  [372] "vm_mconsumospesos_lag1"
#  [373] "vm_mconsumosdolares_lag1"
#  [374] "vm_mlimitecompra_lag1"
#  [375] "vm_madelantopesos_lag1"
#  [376] "vm_madelantodolares_lag1"
#  [377] "vm_fultimo_cierre_lag1"
#  [378] "vm_mpagado_lag1"
#  [379] "vm_mpagospesos_lag1"
#  [380] "vm_mpagosdolares_lag1"
#  [381] "vm_fechaalta_lag1"
#  [382] "vm_mconsumototal_lag1"
#  [383] "vm_cconsumos_lag1"
#  [384] "vm_cadelantosefectivo_lag1"
#  [385] "vm_mpagominimo_lag1"
#  [386] "vmr_Master_mlimitecompra_lag1"
#  [387] "vmr_Visa_mlimitecompra_lag1"
#  [388] "vmr_msaldototal_lag1"
#  [389] "vmr_msaldopesos_lag1"
#  [390] "vmr_msaldopesos2_lag1"
#  [391] "vmr_msaldodolares_lag1"
#  [392] "vmr_msaldodolares2_lag1"
#  [393] "vmr_mconsumospesos_lag1"
#  [394] "vmr_mconsumosdolares_lag1"
#  [395] "vmr_madelantopesos_lag1"
#  [396] "vmr_madelantodolares_lag1"
#  [397] "vmr_mpagado_lag1"
#  [398] "vmr_mpagospesos_lag1"
#  [399] "vmr_mpagosdolares_lag1"
#  [400] "vmr_mconsumototal_lag1"
#  [401] "vmr_mpagominimo_lag1"
#  [402] "active_quarter_lag2"
#  [403] "cliente_vip_lag2"
#  [404] "internet_lag2"
#  [405] "cliente_edad_lag2"
#  [406] "cliente_antiguedad_lag2"
#  [407] "mrentabilidad_lag2"
#  [408] "mrentabilidad_annual_lag2"
#  [409] "mcomisiones_lag2"
#  [410] "mactivos_margen_lag2"
#  [411] "mpasivos_margen_lag2"
#  [412] "cproductos_lag2"
#  [413] "tcuentas_lag2"
#  [414] "ccuenta_corriente_lag2"
#  [415] "mcuenta_corriente_adicional_lag2"
#  [416] "mcuenta_corriente_lag2"
#  [417] "ccaja_ahorro_lag2"
#  [418] "mcaja_ahorro_lag2"
#  [419] "mcaja_ahorro_adicional_lag2"
#  [420] "mcaja_ahorro_dolares_lag2"
#  [421] "cdescubierto_preacordado_lag2"
#  [422] "mcuentas_saldo_lag2"
#  [423] "ctarjeta_debito_lag2"
#  [424] "ctarjeta_debito_transacciones_lag2"
#  [425] "mautoservicio_lag2"
#  [426] "ctarjeta_visa_lag2"
#  [427] "ctarjeta_visa_transacciones_lag2"
#  [428] "mtarjeta_visa_consumo_lag2"
#  [429] "ctarjeta_master_lag2"
#  [430] "ctarjeta_master_transacciones_lag2"
#  [431] "mtarjeta_master_consumo_lag2"
#  [432] "cprestamos_personales_lag2"
#  [433] "mprestamos_personales_lag2"
#  [434] "cprestamos_prendarios_lag2"
#  [435] "mprestamos_prendarios_lag2"
#  [436] "cprestamos_hipotecarios_lag2"
#  [437] "mprestamos_hipotecarios_lag2"
#  [438] "cplazo_fijo_lag2"
#  [439] "mplazo_fijo_dolares_lag2"
#  [440] "mplazo_fijo_pesos_lag2"
#  [441] "cinversion1_lag2"
#  [442] "minversion1_pesos_lag2"
#  [443] "minversion1_dolares_lag2"
#  [444] "cinversion2_lag2"
#  [445] "minversion2_lag2"
#  [446] "cseguro_vida_lag2"
#  [447] "cseguro_auto_lag2"
#  [448] "cseguro_vivienda_lag2"
#  [449] "cseguro_accidentes_personales_lag2"
#  [450] "ccaja_seguridad_lag2"
#  [451] "cpayroll_trx_lag2"
#  [452] "mpayroll_lag2"
#  [453] "mpayroll2_lag2"
#  [454] "cpayroll2_trx_lag2"
#  [455] "ccuenta_debitos_automaticos_lag2"
#  [456] "mcuenta_debitos_automaticos_lag2"
#  [457] "ctarjeta_visa_debitos_automaticos_lag2"
#  [458] "mttarjeta_visa_debitos_automaticos_lag2"
#  [459] "ctarjeta_master_debitos_automaticos_lag2"
#  [460] "mttarjeta_master_debitos_automaticos_lag2"
#  [461] "cpagodeservicios_lag2"
#  [462] "mpagodeservicios_lag2"
#  [463] "cpagomiscuentas_lag2"
#  [464] "mpagomiscuentas_lag2"
#  [465] "ccajeros_propios_descuentos_lag2"
#  [466] "mcajeros_propios_descuentos_lag2"
#  [467] "ctarjeta_visa_descuentos_lag2"
#  [468] "mtarjeta_visa_descuentos_lag2"
#  [469] "ctarjeta_master_descuentos_lag2"
#  [470] "mtarjeta_master_descuentos_lag2"
#  [471] "ccomisiones_mantenimiento_lag2"
#  [472] "mcomisiones_mantenimiento_lag2"
#  [473] "ccomisiones_otras_lag2"
#  [474] "mcomisiones_otras_lag2"
#  [475] "cforex_lag2"
#  [476] "cforex_buy_lag2"
#  [477] "mforex_buy_lag2"
#  [478] "cforex_sell_lag2"
#  [479] "mforex_sell_lag2"
#  [480] "ctransferencias_recibidas_lag2"
#  [481] "mtransferencias_recibidas_lag2"
#  [482] "ctransferencias_emitidas_lag2"
#  [483] "mtransferencias_emitidas_lag2"
#  [484] "cextraccion_autoservicio_lag2"
#  [485] "mextraccion_autoservicio_lag2"
#  [486] "ccheques_depositados_lag2"
#  [487] "mcheques_depositados_lag2"
#  [488] "ccheques_emitidos_lag2"
#  [489] "mcheques_emitidos_lag2"
#  [490] "ccheques_depositados_rechazados_lag2"
#  [491] "mcheques_depositados_rechazados_lag2"
#  [492] "ccheques_emitidos_rechazados_lag2"
#  [493] "mcheques_emitidos_rechazados_lag2"
#  [494] "tcallcenter_lag2"
#  [495] "ccallcenter_transacciones_lag2"
#  [496] "thomebanking_lag2"
#  [497] "chomebanking_transacciones_lag2"
#  [498] "ccajas_transacciones_lag2"
#  [499] "ccajas_consultas_lag2"
#  [500] "ccajas_depositos_lag2"
#  [501] "ccajas_extracciones_lag2"
#  [502] "ccajas_otras_lag2"
#  [503] "catm_trx_lag2"
#  [504] "matm_lag2"
#  [505] "catm_trx_other_lag2"
#  [506] "matm_other_lag2"
#  [507] "ctrx_quarter_lag2"
#  [508] "tmobile_app_lag2"
#  [509] "cmobile_app_trx_lag2"
#  [510] "Master_delinquency_lag2"
#  [511] "Master_status_lag2"
#  [512] "Master_mfinanciacion_limite_lag2"
#  [513] "Master_Fvencimiento_lag2"
#  [514] "Master_Finiciomora_lag2"
#  [515] "Master_msaldototal_lag2"
#  [516] "Master_msaldopesos_lag2"
#  [517] "Master_msaldodolares_lag2"
#  [518] "Master_mconsumospesos_lag2"
#  [519] "Master_mconsumosdolares_lag2"
#  [520] "Master_mlimitecompra_lag2"
#  [521] "Master_madelantopesos_lag2"
#  [522] "Master_madelantodolares_lag2"
#  [523] "Master_fultimo_cierre_lag2"
#  [524] "Master_mpagado_lag2"
#  [525] "Master_mpagospesos_lag2"
#  [526] "Master_mpagosdolares_lag2"
#  [527] "Master_fechaalta_lag2"
#  [528] "Master_mconsumototal_lag2"
#  [529] "Master_cconsumos_lag2"
#  [530] "Master_cadelantosefectivo_lag2"
#  [531] "Master_mpagominimo_lag2"
#  [532] "Visa_delinquency_lag2"
#  [533] "Visa_status_lag2"
#  [534] "Visa_mfinanciacion_limite_lag2"
#  [535] "Visa_Fvencimiento_lag2"
#  [536] "Visa_Finiciomora_lag2"
#  [537] "Visa_msaldototal_lag2"
#  [538] "Visa_msaldopesos_lag2"
#  [539] "Visa_msaldodolares_lag2"
#  [540] "Visa_mconsumospesos_lag2"
#  [541] "Visa_mconsumosdolares_lag2"
#  [542] "Visa_mlimitecompra_lag2"
#  [543] "Visa_madelantopesos_lag2"
#  [544] "Visa_madelantodolares_lag2"
#  [545] "Visa_fultimo_cierre_lag2"
#  [546] "Visa_mpagado_lag2"
#  [547] "Visa_mpagospesos_lag2"
#  [548] "Visa_mpagosdolares_lag2"
#  [549] "Visa_fechaalta_lag2"
#  [550] "Visa_mconsumototal_lag2"
#  [551] "Visa_cconsumos_lag2"
#  [552] "Visa_cadelantosefectivo_lag2"
#  [553] "Visa_mpagominimo_lag2"
#  [554] "kmes_lag2"
#  [555] "ctrx_quarter_normalizado_lag2"
#  [556] "foto_mes_formato_fecha_lag2"
#  [557] "mpayroll_sobre_edad_lag2"
#  [558] "vm_status01_lag2"
#  [559] "vm_status02_lag2"
#  [560] "vm_status03_lag2"
#  [561] "vm_status04_lag2"
#  [562] "vm_status05_lag2"
#  [563] "vm_status06_lag2"
#  [564] "mv_status07_lag2"
#  [565] "vm_mfinanciacion_limite_lag2"
#  [566] "vm_Fvencimiento_lag2"
#  [567] "vm_Finiciomora_lag2"
#  [568] "vm_msaldototal_lag2"
#  [569] "vm_msaldopesos_lag2"
#  [570] "vm_msaldodolares_lag2"
#  [571] "vm_mconsumospesos_lag2"
#  [572] "vm_mconsumosdolares_lag2"
#  [573] "vm_mlimitecompra_lag2"
#  [574] "vm_madelantopesos_lag2"
#  [575] "vm_madelantodolares_lag2"
#  [576] "vm_fultimo_cierre_lag2"
#  [577] "vm_mpagado_lag2"
#  [578] "vm_mpagospesos_lag2"
#  [579] "vm_mpagosdolares_lag2"
#  [580] "vm_fechaalta_lag2"
#  [581] "vm_mconsumototal_lag2"
#  [582] "vm_cconsumos_lag2"
#  [583] "vm_cadelantosefectivo_lag2"
#  [584] "vm_mpagominimo_lag2"
#  [585] "vmr_Master_mlimitecompra_lag2"
#  [586] "vmr_Visa_mlimitecompra_lag2"
#  [587] "vmr_msaldototal_lag2"
#  [588] "vmr_msaldopesos_lag2"
#  [589] "vmr_msaldopesos2_lag2"
#  [590] "vmr_msaldodolares_lag2"
#  [591] "vmr_msaldodolares2_lag2"
#  [592] "vmr_mconsumospesos_lag2"
#  [593] "vmr_mconsumosdolares_lag2"
#  [594] "vmr_madelantopesos_lag2"
#  [595] "vmr_madelantodolares_lag2"
#  [596] "vmr_mpagado_lag2"
#  [597] "vmr_mpagospesos_lag2"
#  [598] "vmr_mpagosdolares_lag2"
#  [599] "vmr_mconsumototal_lag2"
#  [600] "vmr_mpagominimo_lag2"
#  [601] "active_quarter_delta1"
#  [602] "active_quarter_delta2"
#  [603] "cliente_vip_delta1"
#  [604] "cliente_vip_delta2"
#  [605] "internet_delta1"
#  [606] "internet_delta2"
#  [607] "cliente_edad_delta1"
#  [608] "cliente_edad_delta2"
#  [609] "cliente_antiguedad_delta1"
#  [610] "cliente_antiguedad_delta2"
#  [611] "mrentabilidad_delta1"
#  [612] "mrentabilidad_delta2"
#  [613] "mrentabilidad_annual_delta1"
#  [614] "mrentabilidad_annual_delta2"
#  [615] "mcomisiones_delta1"
#  [616] "mcomisiones_delta2"
#  [617] "mactivos_margen_delta1"
#  [618] "mactivos_margen_delta2"
#  [619] "mpasivos_margen_delta1"
#  [620] "mpasivos_margen_delta2"
#  [621] "cproductos_delta1"
#  [622] "cproductos_delta2"
#  [623] "tcuentas_delta1"
#  [624] "tcuentas_delta2"
#  [625] "ccuenta_corriente_delta1"
#  [626] "ccuenta_corriente_delta2"
#  [627] "mcuenta_corriente_adicional_delta1"
#  [628] "mcuenta_corriente_adicional_delta2"
#  [629] "mcuenta_corriente_delta1"
#  [630] "mcuenta_corriente_delta2"
#  [631] "ccaja_ahorro_delta1"
#  [632] "ccaja_ahorro_delta2"
#  [633] "mcaja_ahorro_delta1"
#  [634] "mcaja_ahorro_delta2"
#  [635] "mcaja_ahorro_adicional_delta1"
#  [636] "mcaja_ahorro_adicional_delta2"
#  [637] "mcaja_ahorro_dolares_delta1"
#  [638] "mcaja_ahorro_dolares_delta2"
#  [639] "cdescubierto_preacordado_delta1"
#  [640] "cdescubierto_preacordado_delta2"
#  [641] "mcuentas_saldo_delta1"
#  [642] "mcuentas_saldo_delta2"
#  [643] "ctarjeta_debito_delta1"
#  [644] "ctarjeta_debito_delta2"
#  [645] "ctarjeta_debito_transacciones_delta1"
#  [646] "ctarjeta_debito_transacciones_delta2"
#  [647] "mautoservicio_delta1"
#  [648] "mautoservicio_delta2"
#  [649] "ctarjeta_visa_delta1"
#  [650] "ctarjeta_visa_delta2"
#  [651] "ctarjeta_visa_transacciones_delta1"
#  [652] "ctarjeta_visa_transacciones_delta2"
#  [653] "mtarjeta_visa_consumo_delta1"
#  [654] "mtarjeta_visa_consumo_delta2"
#  [655] "ctarjeta_master_delta1"
#  [656] "ctarjeta_master_delta2"
#  [657] "ctarjeta_master_transacciones_delta1"
#  [658] "ctarjeta_master_transacciones_delta2"
#  [659] "mtarjeta_master_consumo_delta1"
#  [660] "mtarjeta_master_consumo_delta2"
#  [661] "cprestamos_personales_delta1"
#  [662] "cprestamos_personales_delta2"
#  [663] "mprestamos_personales_delta1"
#  [664] "mprestamos_personales_delta2"
#  [665] "cprestamos_prendarios_delta1"
#  [666] "cprestamos_prendarios_delta2"
#  [667] "mprestamos_prendarios_delta1"
#  [668] "mprestamos_prendarios_delta2"
#  [669] "cprestamos_hipotecarios_delta1"
#  [670] "cprestamos_hipotecarios_delta2"
#  [671] "mprestamos_hipotecarios_delta1"
#  [672] "mprestamos_hipotecarios_delta2"
#  [673] "cplazo_fijo_delta1"
#  [674] "cplazo_fijo_delta2"
#  [675] "mplazo_fijo_dolares_delta1"
#  [676] "mplazo_fijo_dolares_delta2"
#  [677] "mplazo_fijo_pesos_delta1"
#  [678] "mplazo_fijo_pesos_delta2"
#  [679] "cinversion1_delta1"
#  [680] "cinversion1_delta2"
#  [681] "minversion1_pesos_delta1"
#  [682] "minversion1_pesos_delta2"
#  [683] "minversion1_dolares_delta1"
#  [684] "minversion1_dolares_delta2"
#  [685] "cinversion2_delta1"
#  [686] "cinversion2_delta2"
#  [687] "minversion2_delta1"
#  [688] "minversion2_delta2"
#  [689] "cseguro_vida_delta1"
#  [690] "cseguro_vida_delta2"
#  [691] "cseguro_auto_delta1"
#  [692] "cseguro_auto_delta2"
#  [693] "cseguro_vivienda_delta1"
#  [694] "cseguro_vivienda_delta2"
#  [695] "cseguro_accidentes_personales_delta1"
#  [696] "cseguro_accidentes_personales_delta2"
#  [697] "ccaja_seguridad_delta1"
#  [698] "ccaja_seguridad_delta2"
#  [699] "cpayroll_trx_delta1"
#  [700] "cpayroll_trx_delta2"
#  [701] "mpayroll_delta1"
#  [702] "mpayroll_delta2"
#  [703] "mpayroll2_delta1"
#  [704] "mpayroll2_delta2"
#  [705] "cpayroll2_trx_delta1"
#  [706] "cpayroll2_trx_delta2"
#  [707] "ccuenta_debitos_automaticos_delta1"
#  [708] "ccuenta_debitos_automaticos_delta2"
#  [709] "mcuenta_debitos_automaticos_delta1"
#  [710] "mcuenta_debitos_automaticos_delta2"
#  [711] "ctarjeta_visa_debitos_automaticos_delta1"
#  [712] "ctarjeta_visa_debitos_automaticos_delta2"
#  [713] "mttarjeta_visa_debitos_automaticos_delta1"
#  [714] "mttarjeta_visa_debitos_automaticos_delta2"
#  [715] "ctarjeta_master_debitos_automaticos_delta1"
#  [716] "ctarjeta_master_debitos_automaticos_delta2"
#  [717] "mttarjeta_master_debitos_automaticos_delta1"
#  [718] "mttarjeta_master_debitos_automaticos_delta2"
#  [719] "cpagodeservicios_delta1"
#  [720] "cpagodeservicios_delta2"
#  [721] "mpagodeservicios_delta1"
#  [722] "mpagodeservicios_delta2"
#  [723] "cpagomiscuentas_delta1"
#  [724] "cpagomiscuentas_delta2"
#  [725] "mpagomiscuentas_delta1"
#  [726] "mpagomiscuentas_delta2"
#  [727] "ccajeros_propios_descuentos_delta1"
#  [728] "ccajeros_propios_descuentos_delta2"
#  [729] "mcajeros_propios_descuentos_delta1"
#  [730] "mcajeros_propios_descuentos_delta2"
#  [731] "ctarjeta_visa_descuentos_delta1"
#  [732] "ctarjeta_visa_descuentos_delta2"
#  [733] "mtarjeta_visa_descuentos_delta1"
#  [734] "mtarjeta_visa_descuentos_delta2"
#  [735] "ctarjeta_master_descuentos_delta1"
#  [736] "ctarjeta_master_descuentos_delta2"
#  [737] "mtarjeta_master_descuentos_delta1"
#  [738] "mtarjeta_master_descuentos_delta2"
#  [739] "ccomisiones_mantenimiento_delta1"
#  [740] "ccomisiones_mantenimiento_delta2"
#  [741] "mcomisiones_mantenimiento_delta1"
#  [742] "mcomisiones_mantenimiento_delta2"
#  [743] "ccomisiones_otras_delta1"
#  [744] "ccomisiones_otras_delta2"
#  [745] "mcomisiones_otras_delta1"
#  [746] "mcomisiones_otras_delta2"
#  [747] "cforex_delta1"
#  [748] "cforex_delta2"
#  [749] "cforex_buy_delta1"
#  [750] "cforex_buy_delta2"
#  [751] "mforex_buy_delta1"
#  [752] "mforex_buy_delta2"
#  [753] "cforex_sell_delta1"
#  [754] "cforex_sell_delta2"
#  [755] "mforex_sell_delta1"
#  [756] "mforex_sell_delta2"
#  [757] "ctransferencias_recibidas_delta1"
#  [758] "ctransferencias_recibidas_delta2"
#  [759] "mtransferencias_recibidas_delta1"
#  [760] "mtransferencias_recibidas_delta2"
#  [761] "ctransferencias_emitidas_delta1"
#  [762] "ctransferencias_emitidas_delta2"
#  [763] "mtransferencias_emitidas_delta1"
#  [764] "mtransferencias_emitidas_delta2"
#  [765] "cextraccion_autoservicio_delta1"
#  [766] "cextraccion_autoservicio_delta2"
#  [767] "mextraccion_autoservicio_delta1"
#  [768] "mextraccion_autoservicio_delta2"
#  [769] "ccheques_depositados_delta1"
#  [770] "ccheques_depositados_delta2"
#  [771] "mcheques_depositados_delta1"
#  [772] "mcheques_depositados_delta2"
#  [773] "ccheques_emitidos_delta1"
#  [774] "ccheques_emitidos_delta2"
#  [775] "mcheques_emitidos_delta1"
#  [776] "mcheques_emitidos_delta2"
#  [777] "ccheques_depositados_rechazados_delta1"
#  [778] "ccheques_depositados_rechazados_delta2"
#  [779] "mcheques_depositados_rechazados_delta1"
#  [780] "mcheques_depositados_rechazados_delta2"
#  [781] "ccheques_emitidos_rechazados_delta1"
#  [782] "ccheques_emitidos_rechazados_delta2"
#  [783] "mcheques_emitidos_rechazados_delta1"
#  [784] "mcheques_emitidos_rechazados_delta2"
#  [785] "tcallcenter_delta1"
#  [786] "tcallcenter_delta2"
#  [787] "ccallcenter_transacciones_delta1"
#  [788] "ccallcenter_transacciones_delta2"
#  [789] "thomebanking_delta1"
#  [790] "thomebanking_delta2"
#  [791] "chomebanking_transacciones_delta1"
#  [792] "chomebanking_transacciones_delta2"
#  [793] "ccajas_transacciones_delta1"
#  [794] "ccajas_transacciones_delta2"
#  [795] "ccajas_consultas_delta1"
#  [796] "ccajas_consultas_delta2"
#  [797] "ccajas_depositos_delta1"
#  [798] "ccajas_depositos_delta2"
#  [799] "ccajas_extracciones_delta1"
#  [800] "ccajas_extracciones_delta2"
#  [801] "ccajas_otras_delta1"
#  [802] "ccajas_otras_delta2"
#  [803] "catm_trx_delta1"
#  [804] "catm_trx_delta2"
#  [805] "matm_delta1"
#  [806] "matm_delta2"
#  [807] "catm_trx_other_delta1"
#  [808] "catm_trx_other_delta2"
#  [809] "matm_other_delta1"
#  [810] "matm_other_delta2"
#  [811] "ctrx_quarter_delta1"
#  [812] "ctrx_quarter_delta2"
#  [813] "tmobile_app_delta1"
#  [814] "tmobile_app_delta2"
#  [815] "cmobile_app_trx_delta1"
#  [816] "cmobile_app_trx_delta2"
#  [817] "Master_delinquency_delta1"
#  [818] "Master_delinquency_delta2"
#  [819] "Master_status_delta1"
#  [820] "Master_status_delta2"
#  [821] "Master_mfinanciacion_limite_delta1"
#  [822] "Master_mfinanciacion_limite_delta2"
#  [823] "Master_Fvencimiento_delta1"
#  [824] "Master_Fvencimiento_delta2"
#  [825] "Master_Finiciomora_delta1"
#  [826] "Master_Finiciomora_delta2"
#  [827] "Master_msaldototal_delta1"
#  [828] "Master_msaldototal_delta2"
#  [829] "Master_msaldopesos_delta1"
#  [830] "Master_msaldopesos_delta2"
#  [831] "Master_msaldodolares_delta1"
#  [832] "Master_msaldodolares_delta2"
#  [833] "Master_mconsumospesos_delta1"
#  [834] "Master_mconsumospesos_delta2"
#  [835] "Master_mconsumosdolares_delta1"
#  [836] "Master_mconsumosdolares_delta2"
#  [837] "Master_mlimitecompra_delta1"
#  [838] "Master_mlimitecompra_delta2"
#  [839] "Master_madelantopesos_delta1"
#  [840] "Master_madelantopesos_delta2"
#  [841] "Master_madelantodolares_delta1"
#  [842] "Master_madelantodolares_delta2"
#  [843] "Master_fultimo_cierre_delta1"
#  [844] "Master_fultimo_cierre_delta2"
#  [845] "Master_mpagado_delta1"
#  [846] "Master_mpagado_delta2"
#  [847] "Master_mpagospesos_delta1"
#  [848] "Master_mpagospesos_delta2"
#  [849] "Master_mpagosdolares_delta1"
#  [850] "Master_mpagosdolares_delta2"
#  [851] "Master_fechaalta_delta1"
#  [852] "Master_fechaalta_delta2"
#  [853] "Master_mconsumototal_delta1"
#  [854] "Master_mconsumototal_delta2"
#  [855] "Master_cconsumos_delta1"
#  [856] "Master_cconsumos_delta2"
#  [857] "Master_cadelantosefectivo_delta1"
#  [858] "Master_cadelantosefectivo_delta2"
#  [859] "Master_mpagominimo_delta1"
#  [860] "Master_mpagominimo_delta2"
#  [861] "Visa_delinquency_delta1"
#  [862] "Visa_delinquency_delta2"
#  [863] "Visa_status_delta1"
#  [864] "Visa_status_delta2"
#  [865] "Visa_mfinanciacion_limite_delta1"
#  [866] "Visa_mfinanciacion_limite_delta2"
#  [867] "Visa_Fvencimiento_delta1"
#  [868] "Visa_Fvencimiento_delta2"
#  [869] "Visa_Finiciomora_delta1"
#  [870] "Visa_Finiciomora_delta2"
#  [871] "Visa_msaldototal_delta1"
#  [872] "Visa_msaldototal_delta2"
#  [873] "Visa_msaldopesos_delta1"
#  [874] "Visa_msaldopesos_delta2"
#  [875] "Visa_msaldodolares_delta1"
#  [876] "Visa_msaldodolares_delta2"
#  [877] "Visa_mconsumospesos_delta1"
#  [878] "Visa_mconsumospesos_delta2"
#  [879] "Visa_mconsumosdolares_delta1"
#  [880] "Visa_mconsumosdolares_delta2"
#  [881] "Visa_mlimitecompra_delta1"
#  [882] "Visa_mlimitecompra_delta2"
#  [883] "Visa_madelantopesos_delta1"
#  [884] "Visa_madelantopesos_delta2"
#  [885] "Visa_madelantodolares_delta1"
#  [886] "Visa_madelantodolares_delta2"
#  [887] "Visa_fultimo_cierre_delta1"
#  [888] "Visa_fultimo_cierre_delta2"
#  [889] "Visa_mpagado_delta1"
#  [890] "Visa_mpagado_delta2"
#  [891] "Visa_mpagospesos_delta1"
#  [892] "Visa_mpagospesos_delta2"
#  [893] "Visa_mpagosdolares_delta1"
#  [894] "Visa_mpagosdolares_delta2"
#  [895] "Visa_fechaalta_delta1"
#  [896] "Visa_fechaalta_delta2"
#  [897] "Visa_mconsumototal_delta1"
#  [898] "Visa_mconsumototal_delta2"
#  [899] "Visa_cconsumos_delta1"
#  [900] "Visa_cconsumos_delta2"
#  [901] "Visa_cadelantosefectivo_delta1"
#  [902] "Visa_cadelantosefectivo_delta2"
#  [903] "Visa_mpagominimo_delta1"
#  [904] "Visa_mpagominimo_delta2"
#  [905] "kmes_delta1"
#  [906] "kmes_delta2"
#  [907] "ctrx_quarter_normalizado_delta1"
#  [908] "ctrx_quarter_normalizado_delta2"
#  [909] "foto_mes_formato_fecha_delta1"
#  [910] "foto_mes_formato_fecha_delta2"
#  [911] "mpayroll_sobre_edad_delta1"
#  [912] "mpayroll_sobre_edad_delta2"
#  [913] "vm_status01_delta1"
#  [914] "vm_status01_delta2"
#  [915] "vm_status02_delta1"
#  [916] "vm_status02_delta2"
#  [917] "vm_status03_delta1"
#  [918] "vm_status03_delta2"
#  [919] "vm_status04_delta1"
#  [920] "vm_status04_delta2"
#  [921] "vm_status05_delta1"
#  [922] "vm_status05_delta2"
#  [923] "vm_status06_delta1"
#  [924] "vm_status06_delta2"
#  [925] "mv_status07_delta1"
#  [926] "mv_status07_delta2"
#  [927] "vm_mfinanciacion_limite_delta1"
#  [928] "vm_mfinanciacion_limite_delta2"
#  [929] "vm_Fvencimiento_delta1"
#  [930] "vm_Fvencimiento_delta2"
#  [931] "vm_Finiciomora_delta1"
#  [932] "vm_Finiciomora_delta2"
#  [933] "vm_msaldototal_delta1"
#  [934] "vm_msaldototal_delta2"
#  [935] "vm_msaldopesos_delta1"
#  [936] "vm_msaldopesos_delta2"
#  [937] "vm_msaldodolares_delta1"
#  [938] "vm_msaldodolares_delta2"
#  [939] "vm_mconsumospesos_delta1"
#  [940] "vm_mconsumospesos_delta2"
#  [941] "vm_mconsumosdolares_delta1"
#  [942] "vm_mconsumosdolares_delta2"
#  [943] "vm_mlimitecompra_delta1"
#  [944] "vm_mlimitecompra_delta2"
#  [945] "vm_madelantopesos_delta1"
#  [946] "vm_madelantopesos_delta2"
#  [947] "vm_madelantodolares_delta1"
#  [948] "vm_madelantodolares_delta2"
#  [949] "vm_fultimo_cierre_delta1"
#  [950] "vm_fultimo_cierre_delta2"
#  [951] "vm_mpagado_delta1"
#  [952] "vm_mpagado_delta2"
#  [953] "vm_mpagospesos_delta1"
#  [954] "vm_mpagospesos_delta2"
#  [955] "vm_mpagosdolares_delta1"
#  [956] "vm_mpagosdolares_delta2"
#  [957] "vm_fechaalta_delta1"
#  [958] "vm_fechaalta_delta2"
#  [959] "vm_mconsumototal_delta1"
#  [960] "vm_mconsumototal_delta2"
#  [961] "vm_cconsumos_delta1"
#  [962] "vm_cconsumos_delta2"
#  [963] "vm_cadelantosefectivo_delta1"
#  [964] "vm_cadelantosefectivo_delta2"
#  [965] "vm_mpagominimo_delta1"
#  [966] "vm_mpagominimo_delta2"
#  [967] "vmr_Master_mlimitecompra_delta1"
#  [968] "vmr_Master_mlimitecompra_delta2"
#  [969] "vmr_Visa_mlimitecompra_delta1"
#  [970] "vmr_Visa_mlimitecompra_delta2"
#  [971] "vmr_msaldototal_delta1"
#  [972] "vmr_msaldototal_delta2"
#  [973] "vmr_msaldopesos_delta1"
#  [974] "vmr_msaldopesos_delta2"
#  [975] "vmr_msaldopesos2_delta1"
#  [976] "vmr_msaldopesos2_delta2"
#  [977] "vmr_msaldodolares_delta1"
#  [978] "vmr_msaldodolares_delta2"
#  [979] "vmr_msaldodolares2_delta1"
#  [980] "vmr_msaldodolares2_delta2"
#  [981] "vmr_mconsumospesos_delta1"
#  [982] "vmr_mconsumospesos_delta2"
#  [983] "vmr_mconsumosdolares_delta1"
#  [984] "vmr_mconsumosdolares_delta2"
#  [985] "vmr_madelantopesos_delta1"
#  [986] "vmr_madelantopesos_delta2"
#  [987] "vmr_madelantodolares_delta1"
#  [988] "vmr_madelantodolares_delta2"
#  [989] "vmr_mpagado_delta1"
#  [990] "vmr_mpagado_delta2"
#  [991] "vmr_mpagospesos_delta1"
#  [992] "vmr_mpagospesos_delta2"
#  [993] "vmr_mpagosdolares_delta1"
#  [994] "vmr_mpagosdolares_delta2"
#  [995] "vmr_mconsumototal_delta1"
#  [996] "vmr_mconsumototal_delta2"
#  [997] "vmr_mpagominimo_delta1"
#  [998] "vmr_mpagominimo_delta2"
#  [999] "active_quarter_tend6"
# [1000] "cliente_vip_tend6"
# [1001] "internet_tend6"
# [1002] "cliente_edad_tend6"
# [1003] "cliente_antiguedad_tend6"
# [1004] "mrentabilidad_tend6"
# [1005] "mrentabilidad_annual_tend6"
# [1006] "mcomisiones_tend6"
# [1007] "mactivos_margen_tend6"
# [1008] "mpasivos_margen_tend6"
# [1009] "cproductos_tend6"
# [1010] "tcuentas_tend6"
# [1011] "ccuenta_corriente_tend6"
# [1012] "mcuenta_corriente_adicional_tend6"
# [1013] "mcuenta_corriente_tend6"
# [1014] "ccaja_ahorro_tend6"
# [1015] "mcaja_ahorro_tend6"
# [1016] "mcaja_ahorro_adicional_tend6"
# [1017] "mcaja_ahorro_dolares_tend6"
# [1018] "cdescubierto_preacordado_tend6"
# [1019] "mcuentas_saldo_tend6"
# [1020] "ctarjeta_debito_tend6"
# [1021] "ctarjeta_debito_transacciones_tend6"
# [1022] "mautoservicio_tend6"
# [1023] "ctarjeta_visa_tend6"
# [1024] "ctarjeta_visa_transacciones_tend6"
# [1025] "mtarjeta_visa_consumo_tend6"
# [1026] "ctarjeta_master_tend6"
# [1027] "ctarjeta_master_transacciones_tend6"
# [1028] "mtarjeta_master_consumo_tend6"
# [1029] "cprestamos_personales_tend6"
# [1030] "mprestamos_personales_tend6"
# [1031] "cprestamos_prendarios_tend6"
# [1032] "mprestamos_prendarios_tend6"
# [1033] "cprestamos_hipotecarios_tend6"
# [1034] "mprestamos_hipotecarios_tend6"
# [1035] "cplazo_fijo_tend6"
# [1036] "mplazo_fijo_dolares_tend6"
# [1037] "mplazo_fijo_pesos_tend6"
# [1038] "cinversion1_tend6"
# [1039] "minversion1_pesos_tend6"
# [1040] "minversion1_dolares_tend6"
# [1041] "cinversion2_tend6"
# [1042] "minversion2_tend6"
# [1043] "cseguro_vida_tend6"
# [1044] "cseguro_auto_tend6"
# [1045] "cseguro_vivienda_tend6"
# [1046] "cseguro_accidentes_personales_tend6"
# [1047] "ccaja_seguridad_tend6"
# [1048] "cpayroll_trx_tend6"
# [1049] "mpayroll_tend6"
# [1050] "mpayroll2_tend6"
# [1051] "cpayroll2_trx_tend6"
# [1052] "ccuenta_debitos_automaticos_tend6"
# [1053] "mcuenta_debitos_automaticos_tend6"
# [1054] "ctarjeta_visa_debitos_automaticos_tend6"
# [1055] "mttarjeta_visa_debitos_automaticos_tend6"
# [1056] "ctarjeta_master_debitos_automaticos_tend6"
# [1057] "mttarjeta_master_debitos_automaticos_tend6"
# [1058] "cpagodeservicios_tend6"
# [1059] "mpagodeservicios_tend6"
# [1060] "cpagomiscuentas_tend6"
# [1061] "mpagomiscuentas_tend6"
# [1062] "ccajeros_propios_descuentos_tend6"
# [1063] "mcajeros_propios_descuentos_tend6"
# [1064] "ctarjeta_visa_descuentos_tend6"
# [1065] "mtarjeta_visa_descuentos_tend6"
# [1066] "ctarjeta_master_descuentos_tend6"
# [1067] "mtarjeta_master_descuentos_tend6"
# [1068] "ccomisiones_mantenimiento_tend6"
# [1069] "mcomisiones_mantenimiento_tend6"
# [1070] "ccomisiones_otras_tend6"
# [1071] "mcomisiones_otras_tend6"
# [1072] "cforex_tend6"
# [1073] "cforex_buy_tend6"
# [1074] "mforex_buy_tend6"
# [1075] "cforex_sell_tend6"
# [1076] "mforex_sell_tend6"
# [1077] "ctransferencias_recibidas_tend6"
# [1078] "mtransferencias_recibidas_tend6"
# [1079] "ctransferencias_emitidas_tend6"
# [1080] "mtransferencias_emitidas_tend6"
# [1081] "cextraccion_autoservicio_tend6"
# [1082] "mextraccion_autoservicio_tend6"
# [1083] "ccheques_depositados_tend6"
# [1084] "mcheques_depositados_tend6"
# [1085] "ccheques_emitidos_tend6"
# [1086] "mcheques_emitidos_tend6"
# [1087] "ccheques_depositados_rechazados_tend6"
# [1088] "mcheques_depositados_rechazados_tend6"
# [1089] "ccheques_emitidos_rechazados_tend6"
# [1090] "mcheques_emitidos_rechazados_tend6"
# [1091] "tcallcenter_tend6"
# [1092] "ccallcenter_transacciones_tend6"
# [1093] "thomebanking_tend6"
# [1094] "chomebanking_transacciones_tend6"
# [1095] "ccajas_transacciones_tend6"
# [1096] "ccajas_consultas_tend6"
# [1097] "ccajas_depositos_tend6"
# [1098] "ccajas_extracciones_tend6"
# [1099] "ccajas_otras_tend6"
# [1100] "catm_trx_tend6"
# [1101] "matm_tend6"
# [1102] "catm_trx_other_tend6"
# [1103] "matm_other_tend6"
# [1104] "ctrx_quarter_tend6"
# [1105] "tmobile_app_tend6"
# [1106] "cmobile_app_trx_tend6"
# [1107] "Master_delinquency_tend6"
# [1108] "Master_status_tend6"
# [1109] "Master_mfinanciacion_limite_tend6"
# [1110] "Master_Fvencimiento_tend6"
# [1111] "Master_Finiciomora_tend6"
# [1112] "Master_msaldototal_tend6"
# [1113] "Master_msaldopesos_tend6"
# [1114] "Master_msaldodolares_tend6"
# [1115] "Master_mconsumospesos_tend6"
# [1116] "Master_mconsumosdolares_tend6"
# [1117] "Master_mlimitecompra_tend6"
# [1118] "Master_madelantopesos_tend6"
# [1119] "Master_madelantodolares_tend6"
# [1120] "Master_fultimo_cierre_tend6"
# [1121] "Master_mpagado_tend6"
# [1122] "Master_mpagospesos_tend6"
# [1123] "Master_mpagosdolares_tend6"
# [1124] "Master_fechaalta_tend6"
# [1125] "Master_mconsumototal_tend6"
# [1126] "Master_cconsumos_tend6"
# [1127] "Master_cadelantosefectivo_tend6"
# [1128] "Master_mpagominimo_tend6"
# [1129] "Visa_delinquency_tend6"
# [1130] "Visa_status_tend6"
# [1131] "Visa_mfinanciacion_limite_tend6"
# [1132] "Visa_Fvencimiento_tend6"
# [1133] "Visa_Finiciomora_tend6"
# [1134] "Visa_msaldototal_tend6"
# [1135] "Visa_msaldopesos_tend6"
# [1136] "Visa_msaldodolares_tend6"
# [1137] "Visa_mconsumospesos_tend6"
# [1138] "Visa_mconsumosdolares_tend6"
# [1139] "Visa_mlimitecompra_tend6"
# [1140] "Visa_madelantopesos_tend6"
# [1141] "Visa_madelantodolares_tend6"
# [1142] "Visa_fultimo_cierre_tend6"
# [1143] "Visa_mpagado_tend6"
# [1144] "Visa_mpagospesos_tend6"
# [1145] "Visa_mpagosdolares_tend6"
# [1146] "Visa_fechaalta_tend6"
# [1147] "Visa_mconsumototal_tend6"
# [1148] "Visa_cconsumos_tend6"
# [1149] "Visa_cadelantosefectivo_tend6"
# [1150] "Visa_mpagominimo_tend6"
# [1151] "kmes_tend6"
# [1152] "ctrx_quarter_normalizado_tend6"
# [1153] "foto_mes_formato_fecha_tend6"
# [1154] "mpayroll_sobre_edad_tend6"
# [1155] "vm_status01_tend6"
# [1156] "vm_status02_tend6"
# [1157] "vm_status03_tend6"
# [1158] "vm_status04_tend6"
# [1159] "vm_status05_tend6"
# [1160] "vm_status06_tend6"
# [1161] "mv_status07_tend6"
# [1162] "vm_mfinanciacion_limite_tend6"
# [1163] "vm_Fvencimiento_tend6"
# [1164] "vm_Finiciomora_tend6"
# [1165] "vm_msaldototal_tend6"
# [1166] "vm_msaldopesos_tend6"
# [1167] "vm_msaldodolares_tend6"
# [1168] "vm_mconsumospesos_tend6"
# [1169] "vm_mconsumosdolares_tend6"
# [1170] "vm_mlimitecompra_tend6"
# [1171] "vm_madelantopesos_tend6"
# [1172] "vm_madelantodolares_tend6"
# [1173] "vm_fultimo_cierre_tend6"
# [1174] "vm_mpagado_tend6"
# [1175] "vm_mpagospesos_tend6"
# [1176] "vm_mpagosdolares_tend6"
# [1177] "vm_fechaalta_tend6"
# [1178] "vm_mconsumototal_tend6"
# [1179] "vm_cconsumos_tend6"
# [1180] "vm_cadelantosefectivo_tend6"
# [1181] "vm_mpagominimo_tend6"
# [1182] "vmr_Master_mlimitecompra_tend6"
# [1183] "vmr_Visa_mlimitecompra_tend6"
# [1184] "vmr_msaldototal_tend6"
# [1185] "vmr_msaldopesos_tend6"
# [1186] "vmr_msaldopesos2_tend6"
# [1187] "vmr_msaldodolares_tend6"
# [1188] "vmr_msaldodolares2_tend6"
# [1189] "vmr_mconsumospesos_tend6"
# [1190] "vmr_mconsumosdolares_tend6"
# [1191] "vmr_madelantopesos_tend6"
# [1192] "vmr_madelantodolares_tend6"
# [1193] "vmr_mpagado_tend6"
# [1194] "vmr_mpagospesos_tend6"
# [1195] "vmr_mpagosdolares_tend6"
# [1196] "vmr_mconsumototal_tend6"
# [1197] "vmr_mpagominimo_tend6"

# %% [markdown]
# #### 9.7.1.5  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest

# %%
if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")
# Out:
# Loading required package: lightgbm

# %%
AgregaVarRandomForest <- function() {

  cat( "inicio AgregaVarRandomForest()\n")
  gc(verbose= FALSE)
  dataset[, clase01 := 0L ]
  dataset[ clase_ternaria %in% PARAM$FE_rf$train$clase01_valor1,
      clase01 := 1L ]

  campos_buenos <- setdiff(
    colnames(dataset),
    c( "clase_ternaria", "clase01")
  )

  dataset[, entrenamiento :=
    as.integer( foto_mes %in% PARAM$FE_rf$train$training )]

  dtrain <- lgb.Dataset(
    data = data.matrix(dataset[entrenamiento == TRUE, campos_buenos, with = FALSE]),
    label = dataset[entrenamiento == TRUE, clase01],
    free_raw_data = FALSE
  )

  modelo <- lgb.train(
     data = dtrain,
     param = PARAM$FE_rf$lgb_param,
     verbose = -100
  )

  cat( "Fin construccion RandomForest\n" )
  # grabo el modelo, achivo .model
  lgb.save(modelo, file="modelo.model" )

  qarbolitos <- copy(PARAM$FE_rf$lgb_param$num_iterations)

  periodos <- dataset[ , unique( foto_mes ) ]

  for( periodo in  periodos )
  {
    cat( "periodo = ", periodo, "\n" )
    datamatrix <- data.matrix(dataset[ foto_mes== periodo, campos_buenos, with = FALSE])

    cat( "Inicio prediccion\n" )
    prediccion <- predict(
        modelo,
        datamatrix,
        type = "leaf"
    )
    cat( "Fin prediccion\n" )

    for( arbolito in 1:qarbolitos )
    {
       cat( arbolito, " " )
       hojas_arbol <- unique(prediccion[ , arbolito])

       for (pos in 1:length(hojas_arbol)) {
         # el numero de nodo de la hoja, estan salteados
         nodo_id <- hojas_arbol[pos]
         dataset[ foto_mes== periodo, paste0(
            "rf_", sprintf("%03d", arbolito),
             "_", sprintf("%03d", nodo_id)
          ) :=  as.integer( nodo_id == prediccion[ , arbolito]) ]

       }

       rm( hojas_arbol )
    }
    cat( "\n" )

    rm( prediccion )
    rm( datamatrix )
    gc(verbose= FALSE)
  }

  gc(verbose= FALSE)

  # borro clase01 , no debe ensuciar el dataset
  dataset[ , clase01 := NULL ]

}

# %%
# Parametros de Feature Engineering  a partir de hojas de Random Forest

# Estos CUATRO parametros son los que se deben modificar
PARAM$FE_rf$arbolitos= 20
PARAM$FE_rf$hojas_por_arbol= 16
PARAM$FE_rf$datos_por_hoja= 100
PARAM$FE_rf$mtry_ratio= 0.2

# Estos son quasi fijos
PARAM$FE_rf$train$clase01_valor1 <- c( "BAJA+2", "BAJA+1")
PARAM$FE_rf$train$training <- c( 202101, 202102, 202103)

# Estos TAMBIEN son quasi fijos
PARAM$FE_rf$lgb_param <-list(
    # parametros que se pueden cambiar
    num_iterations = PARAM$FE_rf$arbolitos,
    num_leaves  = PARAM$FE_rf$hojas_por_arbol,
    min_data_in_leaf = PARAM$FE_rf$datos_por_hoja,
    feature_fraction_bynode  = PARAM$FE_rf$mtry_ratio,

    # para que LightGBM emule Random Forest
    boosting = "rf",
    bagging_fraction = ( 1.0 - 1.0/exp(1.0) ),
    bagging_freq = 1.0,
    feature_fraction = 1.0,

    # genericos de LightGBM
    max_bin = 31L,
    objective = "binary",
    first_metric_only = TRUE,
    boost_from_average = TRUE,
    feature_pre_filter = FALSE,
    force_row_wise = TRUE,
    verbosity = -100,
    max_depth = -1L,
    min_gain_to_split = 0.0,
    min_sum_hessian_in_leaf = 0.001,
    lambda_l1 = 0.0,
    lambda_l2 = 0.0,

    pos_bagging_fraction = 1.0,
    neg_bagging_fraction = 1.0,
    is_unbalance = FALSE,
    scale_pos_weight = 1.0,

    drop_rate = 0.1,
    max_drop = 50,
    skip_drop = 0.5,

    extra_trees = FALSE
  )

# %%
# Feature Engineering agregando variables de Random Forest
# AgregaVarRandomForest()

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 1197
#    [1] "numero_de_cliente"
#    [2] "foto_mes"
#    [3] "active_quarter"
#    [4] "cliente_vip"
#    [5] "internet"
#    [6] "cliente_edad"
#    [7] "cliente_antiguedad"
#    [8] "mrentabilidad"
#    [9] "mrentabilidad_annual"
#   [10] "mcomisiones"
#   [11] "mactivos_margen"
#   [12] "mpasivos_margen"
#   [13] "cproductos"
#   [14] "tcuentas"
#   [15] "ccuenta_corriente"
#   [16] "mcuenta_corriente_adicional"
#   [17] "mcuenta_corriente"
#   [18] "ccaja_ahorro"
#   [19] "mcaja_ahorro"
#   [20] "mcaja_ahorro_adicional"
#   [21] "mcaja_ahorro_dolares"
#   [22] "cdescubierto_preacordado"
#   [23] "mcuentas_saldo"
#   [24] "ctarjeta_debito"
#   [25] "ctarjeta_debito_transacciones"
#   [26] "mautoservicio"
#   [27] "ctarjeta_visa"
#   [28] "ctarjeta_visa_transacciones"
#   [29] "mtarjeta_visa_consumo"
#   [30] "ctarjeta_master"
#   [31] "ctarjeta_master_transacciones"
#   [32] "mtarjeta_master_consumo"
#   [33] "cprestamos_personales"
#   [34] "mprestamos_personales"
#   [35] "cprestamos_prendarios"
#   [36] "mprestamos_prendarios"
#   [37] "cprestamos_hipotecarios"
#   [38] "mprestamos_hipotecarios"
#   [39] "cplazo_fijo"
#   [40] "mplazo_fijo_dolares"
#   [41] "mplazo_fijo_pesos"
#   [42] "cinversion1"
#   [43] "minversion1_pesos"
#   [44] "minversion1_dolares"
#   [45] "cinversion2"
#   [46] "minversion2"
#   [47] "cseguro_vida"
#   [48] "cseguro_auto"
#   [49] "cseguro_vivienda"
#   [50] "cseguro_accidentes_personales"
#   [51] "ccaja_seguridad"
#   [52] "cpayroll_trx"
#   [53] "mpayroll"
#   [54] "mpayroll2"
#   [55] "cpayroll2_trx"
#   [56] "ccuenta_debitos_automaticos"
#   [57] "mcuenta_debitos_automaticos"
#   [58] "ctarjeta_visa_debitos_automaticos"
#   [59] "mttarjeta_visa_debitos_automaticos"
#   [60] "ctarjeta_master_debitos_automaticos"
#   [61] "mttarjeta_master_debitos_automaticos"
#   [62] "cpagodeservicios"
#   [63] "mpagodeservicios"
#   [64] "cpagomiscuentas"
#   [65] "mpagomiscuentas"
#   [66] "ccajeros_propios_descuentos"
#   [67] "mcajeros_propios_descuentos"
#   [68] "ctarjeta_visa_descuentos"
#   [69] "mtarjeta_visa_descuentos"
#   [70] "ctarjeta_master_descuentos"
#   [71] "mtarjeta_master_descuentos"
#   [72] "ccomisiones_mantenimiento"
#   [73] "mcomisiones_mantenimiento"
#   [74] "ccomisiones_otras"
#   [75] "mcomisiones_otras"
#   [76] "cforex"
#   [77] "cforex_buy"
#   [78] "mforex_buy"
#   [79] "cforex_sell"
#   [80] "mforex_sell"
#   [81] "ctransferencias_recibidas"
#   [82] "mtransferencias_recibidas"
#   [83] "ctransferencias_emitidas"
#   [84] "mtransferencias_emitidas"
#   [85] "cextraccion_autoservicio"
#   [86] "mextraccion_autoservicio"
#   [87] "ccheques_depositados"
#   [88] "mcheques_depositados"
#   [89] "ccheques_emitidos"
#   [90] "mcheques_emitidos"
#   [91] "ccheques_depositados_rechazados"
#   [92] "mcheques_depositados_rechazados"
#   [93] "ccheques_emitidos_rechazados"
#   [94] "mcheques_emitidos_rechazados"
#   [95] "tcallcenter"
#   [96] "ccallcenter_transacciones"
#   [97] "thomebanking"
#   [98] "chomebanking_transacciones"
#   [99] "ccajas_transacciones"
#  [100] "ccajas_consultas"
#  [101] "ccajas_depositos"
#  [102] "ccajas_extracciones"
#  [103] "ccajas_otras"
#  [104] "catm_trx"
#  [105] "matm"
#  [106] "catm_trx_other"
#  [107] "matm_other"
#  [108] "ctrx_quarter"
#  [109] "tmobile_app"
#  [110] "cmobile_app_trx"
#  [111] "Master_delinquency"
#  [112] "Master_status"
#  [113] "Master_mfinanciacion_limite"
#  [114] "Master_Fvencimiento"
#  [115] "Master_Finiciomora"
#  [116] "Master_msaldototal"
#  [117] "Master_msaldopesos"
#  [118] "Master_msaldodolares"
#  [119] "Master_mconsumospesos"
#  [120] "Master_mconsumosdolares"
#  [121] "Master_mlimitecompra"
#  [122] "Master_madelantopesos"
#  [123] "Master_madelantodolares"
#  [124] "Master_fultimo_cierre"
#  [125] "Master_mpagado"
#  [126] "Master_mpagospesos"
#  [127] "Master_mpagosdolares"
#  [128] "Master_fechaalta"
#  [129] "Master_mconsumototal"
#  [130] "Master_cconsumos"
#  [131] "Master_cadelantosefectivo"
#  [132] "Master_mpagominimo"
#  [133] "Visa_delinquency"
#  [134] "Visa_status"
#  [135] "Visa_mfinanciacion_limite"
#  [136] "Visa_Fvencimiento"
#  [137] "Visa_Finiciomora"
#  [138] "Visa_msaldototal"
#  [139] "Visa_msaldopesos"
#  [140] "Visa_msaldodolares"
#  [141] "Visa_mconsumospesos"
#  [142] "Visa_mconsumosdolares"
#  [143] "Visa_mlimitecompra"
#  [144] "Visa_madelantopesos"
#  [145] "Visa_madelantodolares"
#  [146] "Visa_fultimo_cierre"
#  [147] "Visa_mpagado"
#  [148] "Visa_mpagospesos"
#  [149] "Visa_mpagosdolares"
#  [150] "Visa_fechaalta"
#  [151] "Visa_mconsumototal"
#  [152] "Visa_cconsumos"
#  [153] "Visa_cadelantosefectivo"
#  [154] "Visa_mpagominimo"
#  [155] "clase_ternaria"
#  [156] "kmes"
#  [157] "ctrx_quarter_normalizado"
#  [158] "foto_mes_formato_fecha"
#  [159] "mpayroll_sobre_edad"
#  [160] "vm_status01"
#  [161] "vm_status02"
#  [162] "vm_status03"
#  [163] "vm_status04"
#  [164] "vm_status05"
#  [165] "vm_status06"
#  [166] "mv_status07"
#  [167] "vm_mfinanciacion_limite"
#  [168] "vm_Fvencimiento"
#  [169] "vm_Finiciomora"
#  [170] "vm_msaldototal"
#  [171] "vm_msaldopesos"
#  [172] "vm_msaldodolares"
#  [173] "vm_mconsumospesos"
#  [174] "vm_mconsumosdolares"
#  [175] "vm_mlimitecompra"
#  [176] "vm_madelantopesos"
#  [177] "vm_madelantodolares"
#  [178] "vm_fultimo_cierre"
#  [179] "vm_mpagado"
#  [180] "vm_mpagospesos"
#  [181] "vm_mpagosdolares"
#  [182] "vm_fechaalta"
#  [183] "vm_mconsumototal"
#  [184] "vm_cconsumos"
#  [185] "vm_cadelantosefectivo"
#  [186] "vm_mpagominimo"
#  [187] "vmr_Master_mlimitecompra"
#  [188] "vmr_Visa_mlimitecompra"
#  [189] "vmr_msaldototal"
#  [190] "vmr_msaldopesos"
#  [191] "vmr_msaldopesos2"
#  [192] "vmr_msaldodolares"
#  [193] "vmr_msaldodolares2"
#  [194] "vmr_mconsumospesos"
#  [195] "vmr_mconsumosdolares"
#  [196] "vmr_madelantopesos"
#  [197] "vmr_madelantodolares"
#  [198] "vmr_mpagado"
#  [199] "vmr_mpagospesos"
#  [200] "vmr_mpagosdolares"
#  [201] "vmr_mconsumototal"
#  [202] "vmr_mpagominimo"
#  [203] "active_quarter_lag1"
#  [204] "cliente_vip_lag1"
#  [205] "internet_lag1"
#  [206] "cliente_edad_lag1"
#  [207] "cliente_antiguedad_lag1"
#  [208] "mrentabilidad_lag1"
#  [209] "mrentabilidad_annual_lag1"
#  [210] "mcomisiones_lag1"
#  [211] "mactivos_margen_lag1"
#  [212] "mpasivos_margen_lag1"
#  [213] "cproductos_lag1"
#  [214] "tcuentas_lag1"
#  [215] "ccuenta_corriente_lag1"
#  [216] "mcuenta_corriente_adicional_lag1"
#  [217] "mcuenta_corriente_lag1"
#  [218] "ccaja_ahorro_lag1"
#  [219] "mcaja_ahorro_lag1"
#  [220] "mcaja_ahorro_adicional_lag1"
#  [221] "mcaja_ahorro_dolares_lag1"
#  [222] "cdescubierto_preacordado_lag1"
#  [223] "mcuentas_saldo_lag1"
#  [224] "ctarjeta_debito_lag1"
#  [225] "ctarjeta_debito_transacciones_lag1"
#  [226] "mautoservicio_lag1"
#  [227] "ctarjeta_visa_lag1"
#  [228] "ctarjeta_visa_transacciones_lag1"
#  [229] "mtarjeta_visa_consumo_lag1"
#  [230] "ctarjeta_master_lag1"
#  [231] "ctarjeta_master_transacciones_lag1"
#  [232] "mtarjeta_master_consumo_lag1"
#  [233] "cprestamos_personales_lag1"
#  [234] "mprestamos_personales_lag1"
#  [235] "cprestamos_prendarios_lag1"
#  [236] "mprestamos_prendarios_lag1"
#  [237] "cprestamos_hipotecarios_lag1"
#  [238] "mprestamos_hipotecarios_lag1"
#  [239] "cplazo_fijo_lag1"
#  [240] "mplazo_fijo_dolares_lag1"
#  [241] "mplazo_fijo_pesos_lag1"
#  [242] "cinversion1_lag1"
#  [243] "minversion1_pesos_lag1"
#  [244] "minversion1_dolares_lag1"
#  [245] "cinversion2_lag1"
#  [246] "minversion2_lag1"
#  [247] "cseguro_vida_lag1"
#  [248] "cseguro_auto_lag1"
#  [249] "cseguro_vivienda_lag1"
#  [250] "cseguro_accidentes_personales_lag1"
#  [251] "ccaja_seguridad_lag1"
#  [252] "cpayroll_trx_lag1"
#  [253] "mpayroll_lag1"
#  [254] "mpayroll2_lag1"
#  [255] "cpayroll2_trx_lag1"
#  [256] "ccuenta_debitos_automaticos_lag1"
#  [257] "mcuenta_debitos_automaticos_lag1"
#  [258] "ctarjeta_visa_debitos_automaticos_lag1"
#  [259] "mttarjeta_visa_debitos_automaticos_lag1"
#  [260] "ctarjeta_master_debitos_automaticos_lag1"
#  [261] "mttarjeta_master_debitos_automaticos_lag1"
#  [262] "cpagodeservicios_lag1"
#  [263] "mpagodeservicios_lag1"
#  [264] "cpagomiscuentas_lag1"
#  [265] "mpagomiscuentas_lag1"
#  [266] "ccajeros_propios_descuentos_lag1"
#  [267] "mcajeros_propios_descuentos_lag1"
#  [268] "ctarjeta_visa_descuentos_lag1"
#  [269] "mtarjeta_visa_descuentos_lag1"
#  [270] "ctarjeta_master_descuentos_lag1"
#  [271] "mtarjeta_master_descuentos_lag1"
#  [272] "ccomisiones_mantenimiento_lag1"
#  [273] "mcomisiones_mantenimiento_lag1"
#  [274] "ccomisiones_otras_lag1"
#  [275] "mcomisiones_otras_lag1"
#  [276] "cforex_lag1"
#  [277] "cforex_buy_lag1"
#  [278] "mforex_buy_lag1"
#  [279] "cforex_sell_lag1"
#  [280] "mforex_sell_lag1"
#  [281] "ctransferencias_recibidas_lag1"
#  [282] "mtransferencias_recibidas_lag1"
#  [283] "ctransferencias_emitidas_lag1"
#  [284] "mtransferencias_emitidas_lag1"
#  [285] "cextraccion_autoservicio_lag1"
#  [286] "mextraccion_autoservicio_lag1"
#  [287] "ccheques_depositados_lag1"
#  [288] "mcheques_depositados_lag1"
#  [289] "ccheques_emitidos_lag1"
#  [290] "mcheques_emitidos_lag1"
#  [291] "ccheques_depositados_rechazados_lag1"
#  [292] "mcheques_depositados_rechazados_lag1"
#  [293] "ccheques_emitidos_rechazados_lag1"
#  [294] "mcheques_emitidos_rechazados_lag1"
#  [295] "tcallcenter_lag1"
#  [296] "ccallcenter_transacciones_lag1"
#  [297] "thomebanking_lag1"
#  [298] "chomebanking_transacciones_lag1"
#  [299] "ccajas_transacciones_lag1"
#  [300] "ccajas_consultas_lag1"
#  [301] "ccajas_depositos_lag1"
#  [302] "ccajas_extracciones_lag1"
#  [303] "ccajas_otras_lag1"
#  [304] "catm_trx_lag1"
#  [305] "matm_lag1"
#  [306] "catm_trx_other_lag1"
#  [307] "matm_other_lag1"
#  [308] "ctrx_quarter_lag1"
#  [309] "tmobile_app_lag1"
#  [310] "cmobile_app_trx_lag1"
#  [311] "Master_delinquency_lag1"
#  [312] "Master_status_lag1"
#  [313] "Master_mfinanciacion_limite_lag1"
#  [314] "Master_Fvencimiento_lag1"
#  [315] "Master_Finiciomora_lag1"
#  [316] "Master_msaldototal_lag1"
#  [317] "Master_msaldopesos_lag1"
#  [318] "Master_msaldodolares_lag1"
#  [319] "Master_mconsumospesos_lag1"
#  [320] "Master_mconsumosdolares_lag1"
#  [321] "Master_mlimitecompra_lag1"
#  [322] "Master_madelantopesos_lag1"
#  [323] "Master_madelantodolares_lag1"
#  [324] "Master_fultimo_cierre_lag1"
#  [325] "Master_mpagado_lag1"
#  [326] "Master_mpagospesos_lag1"
#  [327] "Master_mpagosdolares_lag1"
#  [328] "Master_fechaalta_lag1"
#  [329] "Master_mconsumototal_lag1"
#  [330] "Master_cconsumos_lag1"
#  [331] "Master_cadelantosefectivo_lag1"
#  [332] "Master_mpagominimo_lag1"
#  [333] "Visa_delinquency_lag1"
#  [334] "Visa_status_lag1"
#  [335] "Visa_mfinanciacion_limite_lag1"
#  [336] "Visa_Fvencimiento_lag1"
#  [337] "Visa_Finiciomora_lag1"
#  [338] "Visa_msaldototal_lag1"
#  [339] "Visa_msaldopesos_lag1"
#  [340] "Visa_msaldodolares_lag1"
#  [341] "Visa_mconsumospesos_lag1"
#  [342] "Visa_mconsumosdolares_lag1"
#  [343] "Visa_mlimitecompra_lag1"
#  [344] "Visa_madelantopesos_lag1"
#  [345] "Visa_madelantodolares_lag1"
#  [346] "Visa_fultimo_cierre_lag1"
#  [347] "Visa_mpagado_lag1"
#  [348] "Visa_mpagospesos_lag1"
#  [349] "Visa_mpagosdolares_lag1"
#  [350] "Visa_fechaalta_lag1"
#  [351] "Visa_mconsumototal_lag1"
#  [352] "Visa_cconsumos_lag1"
#  [353] "Visa_cadelantosefectivo_lag1"
#  [354] "Visa_mpagominimo_lag1"
#  [355] "kmes_lag1"
#  [356] "ctrx_quarter_normalizado_lag1"
#  [357] "foto_mes_formato_fecha_lag1"
#  [358] "mpayroll_sobre_edad_lag1"
#  [359] "vm_status01_lag1"
#  [360] "vm_status02_lag1"
#  [361] "vm_status03_lag1"
#  [362] "vm_status04_lag1"
#  [363] "vm_status05_lag1"
#  [364] "vm_status06_lag1"
#  [365] "mv_status07_lag1"
#  [366] "vm_mfinanciacion_limite_lag1"
#  [367] "vm_Fvencimiento_lag1"
#  [368] "vm_Finiciomora_lag1"
#  [369] "vm_msaldototal_lag1"
#  [370] "vm_msaldopesos_lag1"
#  [371] "vm_msaldodolares_lag1"
#  [372] "vm_mconsumospesos_lag1"
#  [373] "vm_mconsumosdolares_lag1"
#  [374] "vm_mlimitecompra_lag1"
#  [375] "vm_madelantopesos_lag1"
#  [376] "vm_madelantodolares_lag1"
#  [377] "vm_fultimo_cierre_lag1"
#  [378] "vm_mpagado_lag1"
#  [379] "vm_mpagospesos_lag1"
#  [380] "vm_mpagosdolares_lag1"
#  [381] "vm_fechaalta_lag1"
#  [382] "vm_mconsumototal_lag1"
#  [383] "vm_cconsumos_lag1"
#  [384] "vm_cadelantosefectivo_lag1"
#  [385] "vm_mpagominimo_lag1"
#  [386] "vmr_Master_mlimitecompra_lag1"
#  [387] "vmr_Visa_mlimitecompra_lag1"
#  [388] "vmr_msaldototal_lag1"
#  [389] "vmr_msaldopesos_lag1"
#  [390] "vmr_msaldopesos2_lag1"
#  [391] "vmr_msaldodolares_lag1"
#  [392] "vmr_msaldodolares2_lag1"
#  [393] "vmr_mconsumospesos_lag1"
#  [394] "vmr_mconsumosdolares_lag1"
#  [395] "vmr_madelantopesos_lag1"
#  [396] "vmr_madelantodolares_lag1"
#  [397] "vmr_mpagado_lag1"
#  [398] "vmr_mpagospesos_lag1"
#  [399] "vmr_mpagosdolares_lag1"
#  [400] "vmr_mconsumototal_lag1"
#  [401] "vmr_mpagominimo_lag1"
#  [402] "active_quarter_lag2"
#  [403] "cliente_vip_lag2"
#  [404] "internet_lag2"
#  [405] "cliente_edad_lag2"
#  [406] "cliente_antiguedad_lag2"
#  [407] "mrentabilidad_lag2"
#  [408] "mrentabilidad_annual_lag2"
#  [409] "mcomisiones_lag2"
#  [410] "mactivos_margen_lag2"
#  [411] "mpasivos_margen_lag2"
#  [412] "cproductos_lag2"
#  [413] "tcuentas_lag2"
#  [414] "ccuenta_corriente_lag2"
#  [415] "mcuenta_corriente_adicional_lag2"
#  [416] "mcuenta_corriente_lag2"
#  [417] "ccaja_ahorro_lag2"
#  [418] "mcaja_ahorro_lag2"
#  [419] "mcaja_ahorro_adicional_lag2"
#  [420] "mcaja_ahorro_dolares_lag2"
#  [421] "cdescubierto_preacordado_lag2"
#  [422] "mcuentas_saldo_lag2"
#  [423] "ctarjeta_debito_lag2"
#  [424] "ctarjeta_debito_transacciones_lag2"
#  [425] "mautoservicio_lag2"
#  [426] "ctarjeta_visa_lag2"
#  [427] "ctarjeta_visa_transacciones_lag2"
#  [428] "mtarjeta_visa_consumo_lag2"
#  [429] "ctarjeta_master_lag2"
#  [430] "ctarjeta_master_transacciones_lag2"
#  [431] "mtarjeta_master_consumo_lag2"
#  [432] "cprestamos_personales_lag2"
#  [433] "mprestamos_personales_lag2"
#  [434] "cprestamos_prendarios_lag2"
#  [435] "mprestamos_prendarios_lag2"
#  [436] "cprestamos_hipotecarios_lag2"
#  [437] "mprestamos_hipotecarios_lag2"
#  [438] "cplazo_fijo_lag2"
#  [439] "mplazo_fijo_dolares_lag2"
#  [440] "mplazo_fijo_pesos_lag2"
#  [441] "cinversion1_lag2"
#  [442] "minversion1_pesos_lag2"
#  [443] "minversion1_dolares_lag2"
#  [444] "cinversion2_lag2"
#  [445] "minversion2_lag2"
#  [446] "cseguro_vida_lag2"
#  [447] "cseguro_auto_lag2"
#  [448] "cseguro_vivienda_lag2"
#  [449] "cseguro_accidentes_personales_lag2"
#  [450] "ccaja_seguridad_lag2"
#  [451] "cpayroll_trx_lag2"
#  [452] "mpayroll_lag2"
#  [453] "mpayroll2_lag2"
#  [454] "cpayroll2_trx_lag2"
#  [455] "ccuenta_debitos_automaticos_lag2"
#  [456] "mcuenta_debitos_automaticos_lag2"
#  [457] "ctarjeta_visa_debitos_automaticos_lag2"
#  [458] "mttarjeta_visa_debitos_automaticos_lag2"
#  [459] "ctarjeta_master_debitos_automaticos_lag2"
#  [460] "mttarjeta_master_debitos_automaticos_lag2"
#  [461] "cpagodeservicios_lag2"
#  [462] "mpagodeservicios_lag2"
#  [463] "cpagomiscuentas_lag2"
#  [464] "mpagomiscuentas_lag2"
#  [465] "ccajeros_propios_descuentos_lag2"
#  [466] "mcajeros_propios_descuentos_lag2"
#  [467] "ctarjeta_visa_descuentos_lag2"
#  [468] "mtarjeta_visa_descuentos_lag2"
#  [469] "ctarjeta_master_descuentos_lag2"
#  [470] "mtarjeta_master_descuentos_lag2"
#  [471] "ccomisiones_mantenimiento_lag2"
#  [472] "mcomisiones_mantenimiento_lag2"
#  [473] "ccomisiones_otras_lag2"
#  [474] "mcomisiones_otras_lag2"
#  [475] "cforex_lag2"
#  [476] "cforex_buy_lag2"
#  [477] "mforex_buy_lag2"
#  [478] "cforex_sell_lag2"
#  [479] "mforex_sell_lag2"
#  [480] "ctransferencias_recibidas_lag2"
#  [481] "mtransferencias_recibidas_lag2"
#  [482] "ctransferencias_emitidas_lag2"
#  [483] "mtransferencias_emitidas_lag2"
#  [484] "cextraccion_autoservicio_lag2"
#  [485] "mextraccion_autoservicio_lag2"
#  [486] "ccheques_depositados_lag2"
#  [487] "mcheques_depositados_lag2"
#  [488] "ccheques_emitidos_lag2"
#  [489] "mcheques_emitidos_lag2"
#  [490] "ccheques_depositados_rechazados_lag2"
#  [491] "mcheques_depositados_rechazados_lag2"
#  [492] "ccheques_emitidos_rechazados_lag2"
#  [493] "mcheques_emitidos_rechazados_lag2"
#  [494] "tcallcenter_lag2"
#  [495] "ccallcenter_transacciones_lag2"
#  [496] "thomebanking_lag2"
#  [497] "chomebanking_transacciones_lag2"
#  [498] "ccajas_transacciones_lag2"
#  [499] "ccajas_consultas_lag2"
#  [500] "ccajas_depositos_lag2"
#  [501] "ccajas_extracciones_lag2"
#  [502] "ccajas_otras_lag2"
#  [503] "catm_trx_lag2"
#  [504] "matm_lag2"
#  [505] "catm_trx_other_lag2"
#  [506] "matm_other_lag2"
#  [507] "ctrx_quarter_lag2"
#  [508] "tmobile_app_lag2"
#  [509] "cmobile_app_trx_lag2"
#  [510] "Master_delinquency_lag2"
#  [511] "Master_status_lag2"
#  [512] "Master_mfinanciacion_limite_lag2"
#  [513] "Master_Fvencimiento_lag2"
#  [514] "Master_Finiciomora_lag2"
#  [515] "Master_msaldototal_lag2"
#  [516] "Master_msaldopesos_lag2"
#  [517] "Master_msaldodolares_lag2"
#  [518] "Master_mconsumospesos_lag2"
#  [519] "Master_mconsumosdolares_lag2"
#  [520] "Master_mlimitecompra_lag2"
#  [521] "Master_madelantopesos_lag2"
#  [522] "Master_madelantodolares_lag2"
#  [523] "Master_fultimo_cierre_lag2"
#  [524] "Master_mpagado_lag2"
#  [525] "Master_mpagospesos_lag2"
#  [526] "Master_mpagosdolares_lag2"
#  [527] "Master_fechaalta_lag2"
#  [528] "Master_mconsumototal_lag2"
#  [529] "Master_cconsumos_lag2"
#  [530] "Master_cadelantosefectivo_lag2"
#  [531] "Master_mpagominimo_lag2"
#  [532] "Visa_delinquency_lag2"
#  [533] "Visa_status_lag2"
#  [534] "Visa_mfinanciacion_limite_lag2"
#  [535] "Visa_Fvencimiento_lag2"
#  [536] "Visa_Finiciomora_lag2"
#  [537] "Visa_msaldototal_lag2"
#  [538] "Visa_msaldopesos_lag2"
#  [539] "Visa_msaldodolares_lag2"
#  [540] "Visa_mconsumospesos_lag2"
#  [541] "Visa_mconsumosdolares_lag2"
#  [542] "Visa_mlimitecompra_lag2"
#  [543] "Visa_madelantopesos_lag2"
#  [544] "Visa_madelantodolares_lag2"
#  [545] "Visa_fultimo_cierre_lag2"
#  [546] "Visa_mpagado_lag2"
#  [547] "Visa_mpagospesos_lag2"
#  [548] "Visa_mpagosdolares_lag2"
#  [549] "Visa_fechaalta_lag2"
#  [550] "Visa_mconsumototal_lag2"
#  [551] "Visa_cconsumos_lag2"
#  [552] "Visa_cadelantosefectivo_lag2"
#  [553] "Visa_mpagominimo_lag2"
#  [554] "kmes_lag2"
#  [555] "ctrx_quarter_normalizado_lag2"
#  [556] "foto_mes_formato_fecha_lag2"
#  [557] "mpayroll_sobre_edad_lag2"
#  [558] "vm_status01_lag2"
#  [559] "vm_status02_lag2"
#  [560] "vm_status03_lag2"
#  [561] "vm_status04_lag2"
#  [562] "vm_status05_lag2"
#  [563] "vm_status06_lag2"
#  [564] "mv_status07_lag2"
#  [565] "vm_mfinanciacion_limite_lag2"
#  [566] "vm_Fvencimiento_lag2"
#  [567] "vm_Finiciomora_lag2"
#  [568] "vm_msaldototal_lag2"
#  [569] "vm_msaldopesos_lag2"
#  [570] "vm_msaldodolares_lag2"
#  [571] "vm_mconsumospesos_lag2"
#  [572] "vm_mconsumosdolares_lag2"
#  [573] "vm_mlimitecompra_lag2"
#  [574] "vm_madelantopesos_lag2"
#  [575] "vm_madelantodolares_lag2"
#  [576] "vm_fultimo_cierre_lag2"
#  [577] "vm_mpagado_lag2"
#  [578] "vm_mpagospesos_lag2"
#  [579] "vm_mpagosdolares_lag2"
#  [580] "vm_fechaalta_lag2"
#  [581] "vm_mconsumototal_lag2"
#  [582] "vm_cconsumos_lag2"
#  [583] "vm_cadelantosefectivo_lag2"
#  [584] "vm_mpagominimo_lag2"
#  [585] "vmr_Master_mlimitecompra_lag2"
#  [586] "vmr_Visa_mlimitecompra_lag2"
#  [587] "vmr_msaldototal_lag2"
#  [588] "vmr_msaldopesos_lag2"
#  [589] "vmr_msaldopesos2_lag2"
#  [590] "vmr_msaldodolares_lag2"
#  [591] "vmr_msaldodolares2_lag2"
#  [592] "vmr_mconsumospesos_lag2"
#  [593] "vmr_mconsumosdolares_lag2"
#  [594] "vmr_madelantopesos_lag2"
#  [595] "vmr_madelantodolares_lag2"
#  [596] "vmr_mpagado_lag2"
#  [597] "vmr_mpagospesos_lag2"
#  [598] "vmr_mpagosdolares_lag2"
#  [599] "vmr_mconsumototal_lag2"
#  [600] "vmr_mpagominimo_lag2"
#  [601] "active_quarter_delta1"
#  [602] "active_quarter_delta2"
#  [603] "cliente_vip_delta1"
#  [604] "cliente_vip_delta2"
#  [605] "internet_delta1"
#  [606] "internet_delta2"
#  [607] "cliente_edad_delta1"
#  [608] "cliente_edad_delta2"
#  [609] "cliente_antiguedad_delta1"
#  [610] "cliente_antiguedad_delta2"
#  [611] "mrentabilidad_delta1"
#  [612] "mrentabilidad_delta2"
#  [613] "mrentabilidad_annual_delta1"
#  [614] "mrentabilidad_annual_delta2"
#  [615] "mcomisiones_delta1"
#  [616] "mcomisiones_delta2"
#  [617] "mactivos_margen_delta1"
#  [618] "mactivos_margen_delta2"
#  [619] "mpasivos_margen_delta1"
#  [620] "mpasivos_margen_delta2"
#  [621] "cproductos_delta1"
#  [622] "cproductos_delta2"
#  [623] "tcuentas_delta1"
#  [624] "tcuentas_delta2"
#  [625] "ccuenta_corriente_delta1"
#  [626] "ccuenta_corriente_delta2"
#  [627] "mcuenta_corriente_adicional_delta1"
#  [628] "mcuenta_corriente_adicional_delta2"
#  [629] "mcuenta_corriente_delta1"
#  [630] "mcuenta_corriente_delta2"
#  [631] "ccaja_ahorro_delta1"
#  [632] "ccaja_ahorro_delta2"
#  [633] "mcaja_ahorro_delta1"
#  [634] "mcaja_ahorro_delta2"
#  [635] "mcaja_ahorro_adicional_delta1"
#  [636] "mcaja_ahorro_adicional_delta2"
#  [637] "mcaja_ahorro_dolares_delta1"
#  [638] "mcaja_ahorro_dolares_delta2"
#  [639] "cdescubierto_preacordado_delta1"
#  [640] "cdescubierto_preacordado_delta2"
#  [641] "mcuentas_saldo_delta1"
#  [642] "mcuentas_saldo_delta2"
#  [643] "ctarjeta_debito_delta1"
#  [644] "ctarjeta_debito_delta2"
#  [645] "ctarjeta_debito_transacciones_delta1"
#  [646] "ctarjeta_debito_transacciones_delta2"
#  [647] "mautoservicio_delta1"
#  [648] "mautoservicio_delta2"
#  [649] "ctarjeta_visa_delta1"
#  [650] "ctarjeta_visa_delta2"
#  [651] "ctarjeta_visa_transacciones_delta1"
#  [652] "ctarjeta_visa_transacciones_delta2"
#  [653] "mtarjeta_visa_consumo_delta1"
#  [654] "mtarjeta_visa_consumo_delta2"
#  [655] "ctarjeta_master_delta1"
#  [656] "ctarjeta_master_delta2"
#  [657] "ctarjeta_master_transacciones_delta1"
#  [658] "ctarjeta_master_transacciones_delta2"
#  [659] "mtarjeta_master_consumo_delta1"
#  [660] "mtarjeta_master_consumo_delta2"
#  [661] "cprestamos_personales_delta1"
#  [662] "cprestamos_personales_delta2"
#  [663] "mprestamos_personales_delta1"
#  [664] "mprestamos_personales_delta2"
#  [665] "cprestamos_prendarios_delta1"
#  [666] "cprestamos_prendarios_delta2"
#  [667] "mprestamos_prendarios_delta1"
#  [668] "mprestamos_prendarios_delta2"
#  [669] "cprestamos_hipotecarios_delta1"
#  [670] "cprestamos_hipotecarios_delta2"
#  [671] "mprestamos_hipotecarios_delta1"
#  [672] "mprestamos_hipotecarios_delta2"
#  [673] "cplazo_fijo_delta1"
#  [674] "cplazo_fijo_delta2"
#  [675] "mplazo_fijo_dolares_delta1"
#  [676] "mplazo_fijo_dolares_delta2"
#  [677] "mplazo_fijo_pesos_delta1"
#  [678] "mplazo_fijo_pesos_delta2"
#  [679] "cinversion1_delta1"
#  [680] "cinversion1_delta2"
#  [681] "minversion1_pesos_delta1"
#  [682] "minversion1_pesos_delta2"
#  [683] "minversion1_dolares_delta1"
#  [684] "minversion1_dolares_delta2"
#  [685] "cinversion2_delta1"
#  [686] "cinversion2_delta2"
#  [687] "minversion2_delta1"
#  [688] "minversion2_delta2"
#  [689] "cseguro_vida_delta1"
#  [690] "cseguro_vida_delta2"
#  [691] "cseguro_auto_delta1"
#  [692] "cseguro_auto_delta2"
#  [693] "cseguro_vivienda_delta1"
#  [694] "cseguro_vivienda_delta2"
#  [695] "cseguro_accidentes_personales_delta1"
#  [696] "cseguro_accidentes_personales_delta2"
#  [697] "ccaja_seguridad_delta1"
#  [698] "ccaja_seguridad_delta2"
#  [699] "cpayroll_trx_delta1"
#  [700] "cpayroll_trx_delta2"
#  [701] "mpayroll_delta1"
#  [702] "mpayroll_delta2"
#  [703] "mpayroll2_delta1"
#  [704] "mpayroll2_delta2"
#  [705] "cpayroll2_trx_delta1"
#  [706] "cpayroll2_trx_delta2"
#  [707] "ccuenta_debitos_automaticos_delta1"
#  [708] "ccuenta_debitos_automaticos_delta2"
#  [709] "mcuenta_debitos_automaticos_delta1"
#  [710] "mcuenta_debitos_automaticos_delta2"
#  [711] "ctarjeta_visa_debitos_automaticos_delta1"
#  [712] "ctarjeta_visa_debitos_automaticos_delta2"
#  [713] "mttarjeta_visa_debitos_automaticos_delta1"
#  [714] "mttarjeta_visa_debitos_automaticos_delta2"
#  [715] "ctarjeta_master_debitos_automaticos_delta1"
#  [716] "ctarjeta_master_debitos_automaticos_delta2"
#  [717] "mttarjeta_master_debitos_automaticos_delta1"
#  [718] "mttarjeta_master_debitos_automaticos_delta2"
#  [719] "cpagodeservicios_delta1"
#  [720] "cpagodeservicios_delta2"
#  [721] "mpagodeservicios_delta1"
#  [722] "mpagodeservicios_delta2"
#  [723] "cpagomiscuentas_delta1"
#  [724] "cpagomiscuentas_delta2"
#  [725] "mpagomiscuentas_delta1"
#  [726] "mpagomiscuentas_delta2"
#  [727] "ccajeros_propios_descuentos_delta1"
#  [728] "ccajeros_propios_descuentos_delta2"
#  [729] "mcajeros_propios_descuentos_delta1"
#  [730] "mcajeros_propios_descuentos_delta2"
#  [731] "ctarjeta_visa_descuentos_delta1"
#  [732] "ctarjeta_visa_descuentos_delta2"
#  [733] "mtarjeta_visa_descuentos_delta1"
#  [734] "mtarjeta_visa_descuentos_delta2"
#  [735] "ctarjeta_master_descuentos_delta1"
#  [736] "ctarjeta_master_descuentos_delta2"
#  [737] "mtarjeta_master_descuentos_delta1"
#  [738] "mtarjeta_master_descuentos_delta2"
#  [739] "ccomisiones_mantenimiento_delta1"
#  [740] "ccomisiones_mantenimiento_delta2"
#  [741] "mcomisiones_mantenimiento_delta1"
#  [742] "mcomisiones_mantenimiento_delta2"
#  [743] "ccomisiones_otras_delta1"
#  [744] "ccomisiones_otras_delta2"
#  [745] "mcomisiones_otras_delta1"
#  [746] "mcomisiones_otras_delta2"
#  [747] "cforex_delta1"
#  [748] "cforex_delta2"
#  [749] "cforex_buy_delta1"
#  [750] "cforex_buy_delta2"
#  [751] "mforex_buy_delta1"
#  [752] "mforex_buy_delta2"
#  [753] "cforex_sell_delta1"
#  [754] "cforex_sell_delta2"
#  [755] "mforex_sell_delta1"
#  [756] "mforex_sell_delta2"
#  [757] "ctransferencias_recibidas_delta1"
#  [758] "ctransferencias_recibidas_delta2"
#  [759] "mtransferencias_recibidas_delta1"
#  [760] "mtransferencias_recibidas_delta2"
#  [761] "ctransferencias_emitidas_delta1"
#  [762] "ctransferencias_emitidas_delta2"
#  [763] "mtransferencias_emitidas_delta1"
#  [764] "mtransferencias_emitidas_delta2"
#  [765] "cextraccion_autoservicio_delta1"
#  [766] "cextraccion_autoservicio_delta2"
#  [767] "mextraccion_autoservicio_delta1"
#  [768] "mextraccion_autoservicio_delta2"
#  [769] "ccheques_depositados_delta1"
#  [770] "ccheques_depositados_delta2"
#  [771] "mcheques_depositados_delta1"
#  [772] "mcheques_depositados_delta2"
#  [773] "ccheques_emitidos_delta1"
#  [774] "ccheques_emitidos_delta2"
#  [775] "mcheques_emitidos_delta1"
#  [776] "mcheques_emitidos_delta2"
#  [777] "ccheques_depositados_rechazados_delta1"
#  [778] "ccheques_depositados_rechazados_delta2"
#  [779] "mcheques_depositados_rechazados_delta1"
#  [780] "mcheques_depositados_rechazados_delta2"
#  [781] "ccheques_emitidos_rechazados_delta1"
#  [782] "ccheques_emitidos_rechazados_delta2"
#  [783] "mcheques_emitidos_rechazados_delta1"
#  [784] "mcheques_emitidos_rechazados_delta2"
#  [785] "tcallcenter_delta1"
#  [786] "tcallcenter_delta2"
#  [787] "ccallcenter_transacciones_delta1"
#  [788] "ccallcenter_transacciones_delta2"
#  [789] "thomebanking_delta1"
#  [790] "thomebanking_delta2"
#  [791] "chomebanking_transacciones_delta1"
#  [792] "chomebanking_transacciones_delta2"
#  [793] "ccajas_transacciones_delta1"
#  [794] "ccajas_transacciones_delta2"
#  [795] "ccajas_consultas_delta1"
#  [796] "ccajas_consultas_delta2"
#  [797] "ccajas_depositos_delta1"
#  [798] "ccajas_depositos_delta2"
#  [799] "ccajas_extracciones_delta1"
#  [800] "ccajas_extracciones_delta2"
#  [801] "ccajas_otras_delta1"
#  [802] "ccajas_otras_delta2"
#  [803] "catm_trx_delta1"
#  [804] "catm_trx_delta2"
#  [805] "matm_delta1"
#  [806] "matm_delta2"
#  [807] "catm_trx_other_delta1"
#  [808] "catm_trx_other_delta2"
#  [809] "matm_other_delta1"
#  [810] "matm_other_delta2"
#  [811] "ctrx_quarter_delta1"
#  [812] "ctrx_quarter_delta2"
#  [813] "tmobile_app_delta1"
#  [814] "tmobile_app_delta2"
#  [815] "cmobile_app_trx_delta1"
#  [816] "cmobile_app_trx_delta2"
#  [817] "Master_delinquency_delta1"
#  [818] "Master_delinquency_delta2"
#  [819] "Master_status_delta1"
#  [820] "Master_status_delta2"
#  [821] "Master_mfinanciacion_limite_delta1"
#  [822] "Master_mfinanciacion_limite_delta2"
#  [823] "Master_Fvencimiento_delta1"
#  [824] "Master_Fvencimiento_delta2"
#  [825] "Master_Finiciomora_delta1"
#  [826] "Master_Finiciomora_delta2"
#  [827] "Master_msaldototal_delta1"
#  [828] "Master_msaldototal_delta2"
#  [829] "Master_msaldopesos_delta1"
#  [830] "Master_msaldopesos_delta2"
#  [831] "Master_msaldodolares_delta1"
#  [832] "Master_msaldodolares_delta2"
#  [833] "Master_mconsumospesos_delta1"
#  [834] "Master_mconsumospesos_delta2"
#  [835] "Master_mconsumosdolares_delta1"
#  [836] "Master_mconsumosdolares_delta2"
#  [837] "Master_mlimitecompra_delta1"
#  [838] "Master_mlimitecompra_delta2"
#  [839] "Master_madelantopesos_delta1"
#  [840] "Master_madelantopesos_delta2"
#  [841] "Master_madelantodolares_delta1"
#  [842] "Master_madelantodolares_delta2"
#  [843] "Master_fultimo_cierre_delta1"
#  [844] "Master_fultimo_cierre_delta2"
#  [845] "Master_mpagado_delta1"
#  [846] "Master_mpagado_delta2"
#  [847] "Master_mpagospesos_delta1"
#  [848] "Master_mpagospesos_delta2"
#  [849] "Master_mpagosdolares_delta1"
#  [850] "Master_mpagosdolares_delta2"
#  [851] "Master_fechaalta_delta1"
#  [852] "Master_fechaalta_delta2"
#  [853] "Master_mconsumototal_delta1"
#  [854] "Master_mconsumototal_delta2"
#  [855] "Master_cconsumos_delta1"
#  [856] "Master_cconsumos_delta2"
#  [857] "Master_cadelantosefectivo_delta1"
#  [858] "Master_cadelantosefectivo_delta2"
#  [859] "Master_mpagominimo_delta1"
#  [860] "Master_mpagominimo_delta2"
#  [861] "Visa_delinquency_delta1"
#  [862] "Visa_delinquency_delta2"
#  [863] "Visa_status_delta1"
#  [864] "Visa_status_delta2"
#  [865] "Visa_mfinanciacion_limite_delta1"
#  [866] "Visa_mfinanciacion_limite_delta2"
#  [867] "Visa_Fvencimiento_delta1"
#  [868] "Visa_Fvencimiento_delta2"
#  [869] "Visa_Finiciomora_delta1"
#  [870] "Visa_Finiciomora_delta2"
#  [871] "Visa_msaldototal_delta1"
#  [872] "Visa_msaldototal_delta2"
#  [873] "Visa_msaldopesos_delta1"
#  [874] "Visa_msaldopesos_delta2"
#  [875] "Visa_msaldodolares_delta1"
#  [876] "Visa_msaldodolares_delta2"
#  [877] "Visa_mconsumospesos_delta1"
#  [878] "Visa_mconsumospesos_delta2"
#  [879] "Visa_mconsumosdolares_delta1"
#  [880] "Visa_mconsumosdolares_delta2"
#  [881] "Visa_mlimitecompra_delta1"
#  [882] "Visa_mlimitecompra_delta2"
#  [883] "Visa_madelantopesos_delta1"
#  [884] "Visa_madelantopesos_delta2"
#  [885] "Visa_madelantodolares_delta1"
#  [886] "Visa_madelantodolares_delta2"
#  [887] "Visa_fultimo_cierre_delta1"
#  [888] "Visa_fultimo_cierre_delta2"
#  [889] "Visa_mpagado_delta1"
#  [890] "Visa_mpagado_delta2"
#  [891] "Visa_mpagospesos_delta1"
#  [892] "Visa_mpagospesos_delta2"
#  [893] "Visa_mpagosdolares_delta1"
#  [894] "Visa_mpagosdolares_delta2"
#  [895] "Visa_fechaalta_delta1"
#  [896] "Visa_fechaalta_delta2"
#  [897] "Visa_mconsumototal_delta1"
#  [898] "Visa_mconsumototal_delta2"
#  [899] "Visa_cconsumos_delta1"
#  [900] "Visa_cconsumos_delta2"
#  [901] "Visa_cadelantosefectivo_delta1"
#  [902] "Visa_cadelantosefectivo_delta2"
#  [903] "Visa_mpagominimo_delta1"
#  [904] "Visa_mpagominimo_delta2"
#  [905] "kmes_delta1"
#  [906] "kmes_delta2"
#  [907] "ctrx_quarter_normalizado_delta1"
#  [908] "ctrx_quarter_normalizado_delta2"
#  [909] "foto_mes_formato_fecha_delta1"
#  [910] "foto_mes_formato_fecha_delta2"
#  [911] "mpayroll_sobre_edad_delta1"
#  [912] "mpayroll_sobre_edad_delta2"
#  [913] "vm_status01_delta1"
#  [914] "vm_status01_delta2"
#  [915] "vm_status02_delta1"
#  [916] "vm_status02_delta2"
#  [917] "vm_status03_delta1"
#  [918] "vm_status03_delta2"
#  [919] "vm_status04_delta1"
#  [920] "vm_status04_delta2"
#  [921] "vm_status05_delta1"
#  [922] "vm_status05_delta2"
#  [923] "vm_status06_delta1"
#  [924] "vm_status06_delta2"
#  [925] "mv_status07_delta1"
#  [926] "mv_status07_delta2"
#  [927] "vm_mfinanciacion_limite_delta1"
#  [928] "vm_mfinanciacion_limite_delta2"
#  [929] "vm_Fvencimiento_delta1"
#  [930] "vm_Fvencimiento_delta2"
#  [931] "vm_Finiciomora_delta1"
#  [932] "vm_Finiciomora_delta2"
#  [933] "vm_msaldototal_delta1"
#  [934] "vm_msaldototal_delta2"
#  [935] "vm_msaldopesos_delta1"
#  [936] "vm_msaldopesos_delta2"
#  [937] "vm_msaldodolares_delta1"
#  [938] "vm_msaldodolares_delta2"
#  [939] "vm_mconsumospesos_delta1"
#  [940] "vm_mconsumospesos_delta2"
#  [941] "vm_mconsumosdolares_delta1"
#  [942] "vm_mconsumosdolares_delta2"
#  [943] "vm_mlimitecompra_delta1"
#  [944] "vm_mlimitecompra_delta2"
#  [945] "vm_madelantopesos_delta1"
#  [946] "vm_madelantopesos_delta2"
#  [947] "vm_madelantodolares_delta1"
#  [948] "vm_madelantodolares_delta2"
#  [949] "vm_fultimo_cierre_delta1"
#  [950] "vm_fultimo_cierre_delta2"
#  [951] "vm_mpagado_delta1"
#  [952] "vm_mpagado_delta2"
#  [953] "vm_mpagospesos_delta1"
#  [954] "vm_mpagospesos_delta2"
#  [955] "vm_mpagosdolares_delta1"
#  [956] "vm_mpagosdolares_delta2"
#  [957] "vm_fechaalta_delta1"
#  [958] "vm_fechaalta_delta2"
#  [959] "vm_mconsumototal_delta1"
#  [960] "vm_mconsumototal_delta2"
#  [961] "vm_cconsumos_delta1"
#  [962] "vm_cconsumos_delta2"
#  [963] "vm_cadelantosefectivo_delta1"
#  [964] "vm_cadelantosefectivo_delta2"
#  [965] "vm_mpagominimo_delta1"
#  [966] "vm_mpagominimo_delta2"
#  [967] "vmr_Master_mlimitecompra_delta1"
#  [968] "vmr_Master_mlimitecompra_delta2"
#  [969] "vmr_Visa_mlimitecompra_delta1"
#  [970] "vmr_Visa_mlimitecompra_delta2"
#  [971] "vmr_msaldototal_delta1"
#  [972] "vmr_msaldototal_delta2"
#  [973] "vmr_msaldopesos_delta1"
#  [974] "vmr_msaldopesos_delta2"
#  [975] "vmr_msaldopesos2_delta1"
#  [976] "vmr_msaldopesos2_delta2"
#  [977] "vmr_msaldodolares_delta1"
#  [978] "vmr_msaldodolares_delta2"
#  [979] "vmr_msaldodolares2_delta1"
#  [980] "vmr_msaldodolares2_delta2"
#  [981] "vmr_mconsumospesos_delta1"
#  [982] "vmr_mconsumospesos_delta2"
#  [983] "vmr_mconsumosdolares_delta1"
#  [984] "vmr_mconsumosdolares_delta2"
#  [985] "vmr_madelantopesos_delta1"
#  [986] "vmr_madelantopesos_delta2"
#  [987] "vmr_madelantodolares_delta1"
#  [988] "vmr_madelantodolares_delta2"
#  [989] "vmr_mpagado_delta1"
#  [990] "vmr_mpagado_delta2"
#  [991] "vmr_mpagospesos_delta1"
#  [992] "vmr_mpagospesos_delta2"
#  [993] "vmr_mpagosdolares_delta1"
#  [994] "vmr_mpagosdolares_delta2"
#  [995] "vmr_mconsumototal_delta1"
#  [996] "vmr_mconsumototal_delta2"
#  [997] "vmr_mpagominimo_delta1"
#  [998] "vmr_mpagominimo_delta2"
#  [999] "active_quarter_tend6"
# [1000] "cliente_vip_tend6"
# [1001] "internet_tend6"
# [1002] "cliente_edad_tend6"
# [1003] "cliente_antiguedad_tend6"
# [1004] "mrentabilidad_tend6"
# [1005] "mrentabilidad_annual_tend6"
# [1006] "mcomisiones_tend6"
# [1007] "mactivos_margen_tend6"
# [1008] "mpasivos_margen_tend6"
# [1009] "cproductos_tend6"
# [1010] "tcuentas_tend6"
# [1011] "ccuenta_corriente_tend6"
# [1012] "mcuenta_corriente_adicional_tend6"
# [1013] "mcuenta_corriente_tend6"
# [1014] "ccaja_ahorro_tend6"
# [1015] "mcaja_ahorro_tend6"
# [1016] "mcaja_ahorro_adicional_tend6"
# [1017] "mcaja_ahorro_dolares_tend6"
# [1018] "cdescubierto_preacordado_tend6"
# [1019] "mcuentas_saldo_tend6"
# [1020] "ctarjeta_debito_tend6"
# [1021] "ctarjeta_debito_transacciones_tend6"
# [1022] "mautoservicio_tend6"
# [1023] "ctarjeta_visa_tend6"
# [1024] "ctarjeta_visa_transacciones_tend6"
# [1025] "mtarjeta_visa_consumo_tend6"
# [1026] "ctarjeta_master_tend6"
# [1027] "ctarjeta_master_transacciones_tend6"
# [1028] "mtarjeta_master_consumo_tend6"
# [1029] "cprestamos_personales_tend6"
# [1030] "mprestamos_personales_tend6"
# [1031] "cprestamos_prendarios_tend6"
# [1032] "mprestamos_prendarios_tend6"
# [1033] "cprestamos_hipotecarios_tend6"
# [1034] "mprestamos_hipotecarios_tend6"
# [1035] "cplazo_fijo_tend6"
# [1036] "mplazo_fijo_dolares_tend6"
# [1037] "mplazo_fijo_pesos_tend6"
# [1038] "cinversion1_tend6"
# [1039] "minversion1_pesos_tend6"
# [1040] "minversion1_dolares_tend6"
# [1041] "cinversion2_tend6"
# [1042] "minversion2_tend6"
# [1043] "cseguro_vida_tend6"
# [1044] "cseguro_auto_tend6"
# [1045] "cseguro_vivienda_tend6"
# [1046] "cseguro_accidentes_personales_tend6"
# [1047] "ccaja_seguridad_tend6"
# [1048] "cpayroll_trx_tend6"
# [1049] "mpayroll_tend6"
# [1050] "mpayroll2_tend6"
# [1051] "cpayroll2_trx_tend6"
# [1052] "ccuenta_debitos_automaticos_tend6"
# [1053] "mcuenta_debitos_automaticos_tend6"
# [1054] "ctarjeta_visa_debitos_automaticos_tend6"
# [1055] "mttarjeta_visa_debitos_automaticos_tend6"
# [1056] "ctarjeta_master_debitos_automaticos_tend6"
# [1057] "mttarjeta_master_debitos_automaticos_tend6"
# [1058] "cpagodeservicios_tend6"
# [1059] "mpagodeservicios_tend6"
# [1060] "cpagomiscuentas_tend6"
# [1061] "mpagomiscuentas_tend6"
# [1062] "ccajeros_propios_descuentos_tend6"
# [1063] "mcajeros_propios_descuentos_tend6"
# [1064] "ctarjeta_visa_descuentos_tend6"
# [1065] "mtarjeta_visa_descuentos_tend6"
# [1066] "ctarjeta_master_descuentos_tend6"
# [1067] "mtarjeta_master_descuentos_tend6"
# [1068] "ccomisiones_mantenimiento_tend6"
# [1069] "mcomisiones_mantenimiento_tend6"
# [1070] "ccomisiones_otras_tend6"
# [1071] "mcomisiones_otras_tend6"
# [1072] "cforex_tend6"
# [1073] "cforex_buy_tend6"
# [1074] "mforex_buy_tend6"
# [1075] "cforex_sell_tend6"
# [1076] "mforex_sell_tend6"
# [1077] "ctransferencias_recibidas_tend6"
# [1078] "mtransferencias_recibidas_tend6"
# [1079] "ctransferencias_emitidas_tend6"
# [1080] "mtransferencias_emitidas_tend6"
# [1081] "cextraccion_autoservicio_tend6"
# [1082] "mextraccion_autoservicio_tend6"
# [1083] "ccheques_depositados_tend6"
# [1084] "mcheques_depositados_tend6"
# [1085] "ccheques_emitidos_tend6"
# [1086] "mcheques_emitidos_tend6"
# [1087] "ccheques_depositados_rechazados_tend6"
# [1088] "mcheques_depositados_rechazados_tend6"
# [1089] "ccheques_emitidos_rechazados_tend6"
# [1090] "mcheques_emitidos_rechazados_tend6"
# [1091] "tcallcenter_tend6"
# [1092] "ccallcenter_transacciones_tend6"
# [1093] "thomebanking_tend6"
# [1094] "chomebanking_transacciones_tend6"
# [1095] "ccajas_transacciones_tend6"
# [1096] "ccajas_consultas_tend6"
# [1097] "ccajas_depositos_tend6"
# [1098] "ccajas_extracciones_tend6"
# [1099] "ccajas_otras_tend6"
# [1100] "catm_trx_tend6"
# [1101] "matm_tend6"
# [1102] "catm_trx_other_tend6"
# [1103] "matm_other_tend6"
# [1104] "ctrx_quarter_tend6"
# [1105] "tmobile_app_tend6"
# [1106] "cmobile_app_trx_tend6"
# [1107] "Master_delinquency_tend6"
# [1108] "Master_status_tend6"
# [1109] "Master_mfinanciacion_limite_tend6"
# [1110] "Master_Fvencimiento_tend6"
# [1111] "Master_Finiciomora_tend6"
# [1112] "Master_msaldototal_tend6"
# [1113] "Master_msaldopesos_tend6"
# [1114] "Master_msaldodolares_tend6"
# [1115] "Master_mconsumospesos_tend6"
# [1116] "Master_mconsumosdolares_tend6"
# [1117] "Master_mlimitecompra_tend6"
# [1118] "Master_madelantopesos_tend6"
# [1119] "Master_madelantodolares_tend6"
# [1120] "Master_fultimo_cierre_tend6"
# [1121] "Master_mpagado_tend6"
# [1122] "Master_mpagospesos_tend6"
# [1123] "Master_mpagosdolares_tend6"
# [1124] "Master_fechaalta_tend6"
# [1125] "Master_mconsumototal_tend6"
# [1126] "Master_cconsumos_tend6"
# [1127] "Master_cadelantosefectivo_tend6"
# [1128] "Master_mpagominimo_tend6"
# [1129] "Visa_delinquency_tend6"
# [1130] "Visa_status_tend6"
# [1131] "Visa_mfinanciacion_limite_tend6"
# [1132] "Visa_Fvencimiento_tend6"
# [1133] "Visa_Finiciomora_tend6"
# [1134] "Visa_msaldototal_tend6"
# [1135] "Visa_msaldopesos_tend6"
# [1136] "Visa_msaldodolares_tend6"
# [1137] "Visa_mconsumospesos_tend6"
# [1138] "Visa_mconsumosdolares_tend6"
# [1139] "Visa_mlimitecompra_tend6"
# [1140] "Visa_madelantopesos_tend6"
# [1141] "Visa_madelantodolares_tend6"
# [1142] "Visa_fultimo_cierre_tend6"
# [1143] "Visa_mpagado_tend6"
# [1144] "Visa_mpagospesos_tend6"
# [1145] "Visa_mpagosdolares_tend6"
# [1146] "Visa_fechaalta_tend6"
# [1147] "Visa_mconsumototal_tend6"
# [1148] "Visa_cconsumos_tend6"
# [1149] "Visa_cadelantosefectivo_tend6"
# [1150] "Visa_mpagominimo_tend6"
# [1151] "kmes_tend6"
# [1152] "ctrx_quarter_normalizado_tend6"
# [1153] "foto_mes_formato_fecha_tend6"
# [1154] "mpayroll_sobre_edad_tend6"
# [1155] "vm_status01_tend6"
# [1156] "vm_status02_tend6"
# [1157] "vm_status03_tend6"
# [1158] "vm_status04_tend6"
# [1159] "vm_status05_tend6"
# [1160] "vm_status06_tend6"
# [1161] "mv_status07_tend6"
# [1162] "vm_mfinanciacion_limite_tend6"
# [1163] "vm_Fvencimiento_tend6"
# [1164] "vm_Finiciomora_tend6"
# [1165] "vm_msaldototal_tend6"
# [1166] "vm_msaldopesos_tend6"
# [1167] "vm_msaldodolares_tend6"
# [1168] "vm_mconsumospesos_tend6"
# [1169] "vm_mconsumosdolares_tend6"
# [1170] "vm_mlimitecompra_tend6"
# [1171] "vm_madelantopesos_tend6"
# [1172] "vm_madelantodolares_tend6"
# [1173] "vm_fultimo_cierre_tend6"
# [1174] "vm_mpagado_tend6"
# [1175] "vm_mpagospesos_tend6"
# [1176] "vm_mpagosdolares_tend6"
# [1177] "vm_fechaalta_tend6"
# [1178] "vm_mconsumototal_tend6"
# [1179] "vm_cconsumos_tend6"
# [1180] "vm_cadelantosefectivo_tend6"
# [1181] "vm_mpagominimo_tend6"
# [1182] "vmr_Master_mlimitecompra_tend6"
# [1183] "vmr_Visa_mlimitecompra_tend6"
# [1184] "vmr_msaldototal_tend6"
# [1185] "vmr_msaldopesos_tend6"
# [1186] "vmr_msaldopesos2_tend6"
# [1187] "vmr_msaldodolares_tend6"
# [1188] "vmr_msaldodolares2_tend6"
# [1189] "vmr_mconsumospesos_tend6"
# [1190] "vmr_mconsumosdolares_tend6"
# [1191] "vmr_madelantopesos_tend6"
# [1192] "vmr_madelantodolares_tend6"
# [1193] "vmr_mpagado_tend6"
# [1194] "vmr_mpagospesos_tend6"
# [1195] "vmr_mpagosdolares_tend6"
# [1196] "vmr_mconsumototal_tend6"
# [1197] "vmr_mpagominimo_tend6"

# %% [markdown]
# #### 9.7.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr*

# %% [markdown]
# El objetivo de esta etapa NO es mejorar el modelo predictivo

# %% [markdown]
# El objetivo es eliminar campos poco importantes para hacer espacio a nuevos campos, debido a las restricciones de memoria RAM.

# %%
VPOS_CORTE <- c()

fganancia_lgbm_meseta <- function(probs, datos) {
  vlabels <- get_field(datos, "label")
  vpesos <- get_field(datos, "weight")

  tbl <- as.data.table(list(
    "prob" = probs,
    "gan" = ifelse(vlabels == 1 & vpesos > 1, PARAM$CN$train$gan1, PARAM$CN$train$gan0)
  ))

  setorder(tbl, -prob)
  tbl[, posicion := .I]
  tbl[, gan_acum := cumsum(gan)]
  setorder(tbl, -gan_acum) # voy por la meseta

  gan <- mean(tbl[1:500, gan_acum]) # meseta de tamaño 500

  pos_meseta <- tbl[1:500, median(posicion)]
  VPOS_CORTE <<- c(VPOS_CORTE, pos_meseta)

  return(list(
    "name" = "ganancia",
    "value" = gan,
    "higher_better" = TRUE
  ))
}

# %%
# Elimina del dataset las variables que estan por debajo
#  de la capa geologica de canaritos
# se llama varias veces, luego de agregar muchas variables nuevas,
#  para ir reduciendo la cantidad de variables
# y así hacer lugar a nuevas variables importantes

GVEZ <- 1

campitos <- c( "numero_de_cliente", "foto_mes", "clase_ternaria" )

CanaritosAsesinos <- function(
  canaritos_ratio,
  canaritos_desvios,
  canaritos_semilla) {

  cat( "inicio CanaritosAsesinos()\n")
  gc(verbose= FALSE)
  dataset[, clase01 := 0L ]
  dataset[ clase_ternaria %in% PARAM$CN$train$clase01_valor1,
      clase01 := 1L ]

  set.seed(canaritos_semilla, kind = "L'Ecuyer-CMRG")
  for (i in 1:(ncol(dataset) * canaritos_ratio)) {
    dataset[, paste0("canarito", i) := runif(nrow(dataset))]
  }

  campos_buenos <- setdiff(
    colnames(dataset),
    c( campitos, "clase01")
  )

  azar <- runif(nrow(dataset))

  dataset[, entrenamiento :=
    as.integer( foto_mes %in% PARAM$CN$train$training &
      (clase01 == 1 | azar < PARAM$CN$train$undersampling))]

  dtrain <- lgb.Dataset(
    data = data.matrix(dataset[entrenamiento == TRUE, campos_buenos, with = FALSE]),
    label = dataset[entrenamiento == TRUE, clase01],
    weight = dataset[
      entrenamiento == TRUE,
      ifelse(clase_ternaria %in% PARAM$CN$train$positivos, 1.0000001, 1.0)
    ],
    free_raw_data = FALSE
  )

  dvalid <- lgb.Dataset(
    data = data.matrix(dataset[foto_mes %in% PARAM$CN$train$validation, campos_buenos, with = FALSE]),
    label = dataset[foto_mes %in% PARAM$CN$train$validation, clase01],
    weight = dataset[
      foto_mes %in% PARAM$CN$train$validation,
      ifelse( clase_ternaria %in% PARAM$CN$train$positivos, 1.0000001, 1.0)
    ],
    free_raw_data = FALSE
  )


  param <- list(
    objective = "binary",
    metric = "custom",
    first_metric_only = TRUE,
    boost_from_average = TRUE,
    feature_pre_filter = FALSE,
    verbosity = -100,
    seed = canaritos_semilla,
    max_depth = -1, # -1 significa no limitar,  por ahora lo dejo fijo
    min_gain_to_split = 0.0, # por ahora, lo dejo fijo
    lambda_l1 = 0.0, # por ahora, lo dejo fijo
    lambda_l2 = 0.0, # por ahora, lo dejo fijo
    max_bin = 31, # por ahora, lo dejo fijo
    num_iterations = 9999, # un numero grande, lo limita early_stopping_rounds
    force_row_wise = TRUE, # para que los alumnos no se atemoricen con  warning
    learning_rate = 0.065,
    feature_fraction = 1.0, # lo seteo en 1
    min_data_in_leaf = 260,
    num_leaves = 60,
    early_stopping_rounds = 200,
    num_threads = 1
  )

  set.seed(canaritos_semilla, kind = "L'Ecuyer-CMRG")
  modelo <- lgb.train(
    data = dtrain,
    valids = list(valid = dvalid),
    eval = fganancia_lgbm_meseta,
    param = param,
    verbose = -100
  )

  tb_importancia <- lgb.importance(model = modelo)
  tb_importancia[, pos := .I]

  fwrite(tb_importancia,
    file = paste0("impo_", GVEZ, ".txt"),
    sep = "\t"
  )

  GVEZ <<- GVEZ + 1

  umbral <- tb_importancia[
    Feature %like% "canarito",
    median(pos) + canaritos_desvios * sd(pos)
  ] # Atencion corto en la mediana mas desvios!!

  col_utiles <- tb_importancia[
    pos < umbral & !(Feature %like% "canarito"),
    Feature
  ]

  col_utiles <- unique(c(
    col_utiles,
    c(campitos, "mes")
  ))

  col_inutiles <- setdiff(colnames(dataset), col_utiles)

  dataset[, (col_inutiles) := NULL]

  cat( "fin CanaritosAsesinos()\n")

  return( tb_importancia )
}

# %%
# Estos DOS parametros son los que se deben modificar
PARAM$CN$ratio <- 0.2
PARAM$CN$desvios <- 2


# Parametros quasi fijos
# Parametros de un LightGBM que se genera para estimar la column importance
PARAM$CN$train$clase01_valor1 <- c( "BAJA+2", "BAJA+1")
PARAM$CN$train$positivos <- c( "BAJA+2")
PARAM$CN$train$training <- c( 202101, 202102, 202103)
PARAM$CN$train$validation <- c( 202105 )
PARAM$CN$train$undersampling <- 0.1
PARAM$CN$train$gan1 <- 0.975
PARAM$CN$train$gan0 <- -0.025

# %%
# la llamada a Canaritos Asesinos
tb_importancia <- CanaritosAsesinos(
  canaritos_ratio = PARAM$CN$ratio,
  canaritos_desvios = PARAM$CN$desvios,
  canaritos_semilla = PARAM$semilla_primigenia
)
# Out:
# inicio CanaritosAsesinos()
# fin CanaritosAsesinos()

# %%
# grabo la importancia, ver el archivo directamente en la carpeta

fwrite( tb_importancia,
  file="canaritos.txt",
  sep="\t"
)

# %%
# verifico
ncol(dataset)
colnames(dataset)
# Out:
# [1] 446
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "internet"
#   [4] "cliente_edad"
#   [5] "cliente_antiguedad"
#   [6] "mrentabilidad"
#   [7] "mrentabilidad_annual"
#   [8] "mcomisiones"
#   [9] "mactivos_margen"
#  [10] "mpasivos_margen"
#  [11] "cproductos"
#  [12] "mcuenta_corriente"
#  [13] "ccaja_ahorro"
#  [14] "mcaja_ahorro"
#  [15] "mcaja_ahorro_dolares"
#  [16] "cdescubierto_preacordado"
#  [17] "mcuentas_saldo"
#  [18] "ctarjeta_debito"
#  [19] "ctarjeta_debito_transacciones"
#  [20] "mautoservicio"
#  [21] "ctarjeta_visa_transacciones"
#  [22] "mtarjeta_visa_consumo"
#  [23] "ctarjeta_master"
#  [24] "ctarjeta_master_transacciones"
#  [25] "mtarjeta_master_consumo"
#  [26] "cprestamos_personales"
#  [27] "mprestamos_personales"
#  [28] "mprestamos_prendarios"
#  [29] "cplazo_fijo"
#  [30] "mplazo_fijo_dolares"
#  [31] "minversion2"
#  [32] "cseguro_vida"
#  [33] "ccaja_seguridad"
#  [34] "cpayroll_trx"
#  [35] "mpayroll"
#  [36] "ccuenta_debitos_automaticos"
#  [37] "mcuenta_debitos_automaticos"
#  [38] "ctarjeta_visa_debitos_automaticos"
#  [39] "mttarjeta_visa_debitos_automaticos"
#  [40] "cpagomiscuentas"
#  [41] "mpagomiscuentas"
#  [42] "ccomisiones_mantenimiento"
#  [43] "mcomisiones_mantenimiento"
#  [44] "ccomisiones_otras"
#  [45] "mcomisiones_otras"
#  [46] "ctransferencias_recibidas"
#  [47] "mtransferencias_recibidas"
#  [48] "tcallcenter"
#  [49] "ccallcenter_transacciones"
#  [50] "thomebanking"
#  [51] "chomebanking_transacciones"
#  [52] "ccajas_consultas"
#  [53] "ctrx_quarter"
#  [54] "Master_status"
#  [55] "Master_mfinanciacion_limite"
#  [56] "Master_Fvencimiento"
#  [57] "Master_msaldototal"
#  [58] "Master_mconsumospesos"
#  [59] "Master_mconsumosdolares"
#  [60] "Master_fultimo_cierre"
#  [61] "Master_mpagospesos"
#  [62] "Master_fechaalta"
#  [63] "Master_cconsumos"
#  [64] "Master_cadelantosefectivo"
#  [65] "Visa_status"
#  [66] "Visa_Fvencimiento"
#  [67] "Visa_msaldototal"
#  [68] "Visa_msaldopesos"
#  [69] "Visa_msaldodolares"
#  [70] "Visa_mpagado"
#  [71] "Visa_mpagospesos"
#  [72] "Visa_fechaalta"
#  [73] "Visa_cconsumos"
#  [74] "Visa_mpagominimo"
#  [75] "clase_ternaria"
#  [76] "ctrx_quarter_normalizado"
#  [77] "mpayroll_sobre_edad"
#  [78] "vm_status01"
#  [79] "vm_status04"
#  [80] "vm_mfinanciacion_limite"
#  [81] "vm_Fvencimiento"
#  [82] "vm_msaldototal"
#  [83] "vm_msaldopesos"
#  [84] "vm_mconsumospesos"
#  [85] "vm_mpagospesos"
#  [86] "vm_fechaalta"
#  [87] "vm_cconsumos"
#  [88] "vm_mpagominimo"
#  [89] "vmr_Visa_mlimitecompra"
#  [90] "vmr_msaldopesos"
#  [91] "vmr_msaldopesos2"
#  [92] "vmr_mpagado"
#  [93] "vmr_mpagospesos"
#  [94] "vmr_mpagosdolares"
#  [95] "vmr_mpagominimo"
#  [96] "active_quarter_lag1"
#  [97] "internet_lag1"
#  [98] "cliente_edad_lag1"
#  [99] "cliente_antiguedad_lag1"
# [100] "mrentabilidad_lag1"
# [101] "mrentabilidad_annual_lag1"
# [102] "mcomisiones_lag1"
# [103] "mactivos_margen_lag1"
# [104] "mpasivos_margen_lag1"
# [105] "cproductos_lag1"
# [106] "mcuenta_corriente_lag1"
# [107] "mcaja_ahorro_lag1"
# [108] "mcaja_ahorro_adicional_lag1"
# [109] "mcaja_ahorro_dolares_lag1"
# [110] "mcuentas_saldo_lag1"
# [111] "mautoservicio_lag1"
# [112] "ctarjeta_visa_transacciones_lag1"
# [113] "mtarjeta_visa_consumo_lag1"
# [114] "mprestamos_personales_lag1"
# [115] "mprestamos_prendarios_lag1"
# [116] "mplazo_fijo_dolares_lag1"
# [117] "cpayroll_trx_lag1"
# [118] "mpayroll_lag1"
# [119] "mcuenta_debitos_automaticos_lag1"
# [120] "ctarjeta_visa_debitos_automaticos_lag1"
# [121] "mttarjeta_visa_debitos_automaticos_lag1"
# [122] "ccomisiones_mantenimiento_lag1"
# [123] "mcomisiones_mantenimiento_lag1"
# [124] "ccomisiones_otras_lag1"
# [125] "mcomisiones_otras_lag1"
# [126] "ctransferencias_recibidas_lag1"
# [127] "mtransferencias_recibidas_lag1"
# [128] "mtransferencias_emitidas_lag1"
# [129] "ccallcenter_transacciones_lag1"
# [130] "thomebanking_lag1"
# [131] "chomebanking_transacciones_lag1"
# [132] "ctrx_quarter_lag1"
# [133] "Master_mfinanciacion_limite_lag1"
# [134] "Master_Fvencimiento_lag1"
# [135] "Master_mconsumospesos_lag1"
# [136] "Master_mlimitecompra_lag1"
# [137] "Master_fechaalta_lag1"
# [138] "Visa_Fvencimiento_lag1"
# [139] "Visa_msaldototal_lag1"
# [140] "Visa_mconsumospesos_lag1"
# [141] "Visa_mconsumosdolares_lag1"
# [142] "Visa_fultimo_cierre_lag1"
# [143] "Visa_mpagado_lag1"
# [144] "Visa_mpagospesos_lag1"
# [145] "Visa_mpagosdolares_lag1"
# [146] "Visa_fechaalta_lag1"
# [147] "Visa_cconsumos_lag1"
# [148] "Visa_mpagominimo_lag1"
# [149] "ctrx_quarter_normalizado_lag1"
# [150] "vm_mfinanciacion_limite_lag1"
# [151] "vm_Fvencimiento_lag1"
# [152] "vm_msaldopesos_lag1"
# [153] "vm_fultimo_cierre_lag1"
# [154] "vm_fechaalta_lag1"
# [155] "vm_cconsumos_lag1"
# [156] "vm_mpagominimo_lag1"
# [157] "vmr_Master_mlimitecompra_lag1"
# [158] "vmr_Visa_mlimitecompra_lag1"
# [159] "vmr_msaldototal_lag1"
# [160] "vmr_msaldopesos2_lag1"
# [161] "vmr_mconsumospesos_lag1"
# [162] "vmr_mpagospesos_lag1"
# [163] "vmr_mpagominimo_lag1"
# [164] "internet_lag2"
# [165] "cliente_edad_lag2"
# [166] "cliente_antiguedad_lag2"
# [167] "mrentabilidad_lag2"
# [168] "mrentabilidad_annual_lag2"
# [169] "mcomisiones_lag2"
# [170] "mactivos_margen_lag2"
# [171] "mpasivos_margen_lag2"
# [172] "cproductos_lag2"
# [173] "mcuenta_corriente_lag2"
# [174] "ccaja_ahorro_lag2"
# [175] "mcaja_ahorro_lag2"
# [176] "mcaja_ahorro_dolares_lag2"
# [177] "mcuentas_saldo_lag2"
# [178] "ctarjeta_debito_transacciones_lag2"
# [179] "mautoservicio_lag2"
# [180] "ctarjeta_visa_transacciones_lag2"
# [181] "mprestamos_personales_lag2"
# [182] "ccaja_seguridad_lag2"
# [183] "cpayroll_trx_lag2"
# [184] "mpayroll_lag2"
# [185] "mcuenta_debitos_automaticos_lag2"
# [186] "ctarjeta_visa_debitos_automaticos_lag2"
# [187] "mttarjeta_visa_debitos_automaticos_lag2"
# [188] "mpagomiscuentas_lag2"
# [189] "ctarjeta_visa_descuentos_lag2"
# [190] "mtarjeta_visa_descuentos_lag2"
# [191] "ccomisiones_mantenimiento_lag2"
# [192] "mcomisiones_mantenimiento_lag2"
# [193] "mcomisiones_otras_lag2"
# [194] "ctransferencias_recibidas_lag2"
# [195] "mtransferencias_recibidas_lag2"
# [196] "mtransferencias_emitidas_lag2"
# [197] "mcheques_depositados_lag2"
# [198] "ccheques_emitidos_lag2"
# [199] "mcheques_emitidos_lag2"
# [200] "tcallcenter_lag2"
# [201] "ccallcenter_transacciones_lag2"
# [202] "chomebanking_transacciones_lag2"
# [203] "ctrx_quarter_lag2"
# [204] "cmobile_app_trx_lag2"
# [205] "Master_mfinanciacion_limite_lag2"
# [206] "Master_Fvencimiento_lag2"
# [207] "Master_mconsumospesos_lag2"
# [208] "Master_fultimo_cierre_lag2"
# [209] "Master_mpagospesos_lag2"
# [210] "Master_fechaalta_lag2"
# [211] "Visa_Fvencimiento_lag2"
# [212] "Visa_msaldototal_lag2"
# [213] "Visa_msaldopesos_lag2"
# [214] "Visa_mconsumospesos_lag2"
# [215] "Visa_fultimo_cierre_lag2"
# [216] "Visa_mpagado_lag2"
# [217] "Visa_mpagospesos_lag2"
# [218] "Visa_fechaalta_lag2"
# [219] "Visa_cconsumos_lag2"
# [220] "Visa_mpagominimo_lag2"
# [221] "ctrx_quarter_normalizado_lag2"
# [222] "mpayroll_sobre_edad_lag2"
# [223] "vm_mfinanciacion_limite_lag2"
# [224] "vm_Fvencimiento_lag2"
# [225] "vm_mconsumospesos_lag2"
# [226] "vm_fultimo_cierre_lag2"
# [227] "vm_mpagospesos_lag2"
# [228] "vm_fechaalta_lag2"
# [229] "vm_cconsumos_lag2"
# [230] "vm_mpagominimo_lag2"
# [231] "vmr_Visa_mlimitecompra_lag2"
# [232] "vmr_msaldototal_lag2"
# [233] "vmr_msaldopesos_lag2"
# [234] "vmr_msaldopesos2_lag2"
# [235] "vmr_msaldodolares_lag2"
# [236] "vmr_mpagospesos_lag2"
# [237] "vmr_mpagominimo_lag2"
# [238] "mrentabilidad_delta1"
# [239] "mrentabilidad_delta2"
# [240] "mrentabilidad_annual_delta1"
# [241] "mrentabilidad_annual_delta2"
# [242] "mcomisiones_delta1"
# [243] "mcomisiones_delta2"
# [244] "mactivos_margen_delta1"
# [245] "mactivos_margen_delta2"
# [246] "mpasivos_margen_delta1"
# [247] "mpasivos_margen_delta2"
# [248] "cproductos_delta1"
# [249] "cproductos_delta2"
# [250] "mcuenta_corriente_delta1"
# [251] "mcuenta_corriente_delta2"
# [252] "mcaja_ahorro_delta1"
# [253] "mcaja_ahorro_delta2"
# [254] "mcaja_ahorro_dolares_delta1"
# [255] "mcaja_ahorro_dolares_delta2"
# [256] "mcuentas_saldo_delta1"
# [257] "mcuentas_saldo_delta2"
# [258] "ctarjeta_debito_transacciones_delta1"
# [259] "ctarjeta_debito_transacciones_delta2"
# [260] "mautoservicio_delta2"
# [261] "ctarjeta_visa_transacciones_delta1"
# [262] "ctarjeta_visa_transacciones_delta2"
# [263] "mtarjeta_visa_consumo_delta2"
# [264] "mprestamos_personales_delta1"
# [265] "mprestamos_personales_delta2"
# [266] "cplazo_fijo_delta2"
# [267] "mplazo_fijo_dolares_delta1"
# [268] "mpayroll_delta1"
# [269] "mpayroll_delta2"
# [270] "mcuenta_debitos_automaticos_delta1"
# [271] "mcuenta_debitos_automaticos_delta2"
# [272] "mttarjeta_visa_debitos_automaticos_delta2"
# [273] "mttarjeta_master_debitos_automaticos_delta2"
# [274] "cpagomiscuentas_delta2"
# [275] "mpagomiscuentas_delta1"
# [276] "mpagomiscuentas_delta2"
# [277] "ccomisiones_mantenimiento_delta1"
# [278] "ccomisiones_mantenimiento_delta2"
# [279] "mcomisiones_mantenimiento_delta1"
# [280] "mcomisiones_mantenimiento_delta2"
# [281] "mcomisiones_otras_delta2"
# [282] "mtransferencias_recibidas_delta1"
# [283] "mtransferencias_recibidas_delta2"
# [284] "ctransferencias_emitidas_delta2"
# [285] "cextraccion_autoservicio_delta2"
# [286] "mextraccion_autoservicio_delta2"
# [287] "tcallcenter_delta2"
# [288] "ccallcenter_transacciones_delta1"
# [289] "ccallcenter_transacciones_delta2"
# [290] "thomebanking_delta1"
# [291] "thomebanking_delta2"
# [292] "chomebanking_transacciones_delta1"
# [293] "chomebanking_transacciones_delta2"
# [294] "ccajas_otras_delta1"
# [295] "matm_delta2"
# [296] "matm_other_delta2"
# [297] "ctrx_quarter_delta1"
# [298] "ctrx_quarter_delta2"
# [299] "tmobile_app_delta2"
# [300] "Master_status_delta2"
# [301] "Master_mfinanciacion_limite_delta1"
# [302] "Master_mfinanciacion_limite_delta2"
# [303] "Master_Fvencimiento_delta2"
# [304] "Master_msaldototal_delta2"
# [305] "Master_mconsumospesos_delta1"
# [306] "Master_fultimo_cierre_delta1"
# [307] "Master_cconsumos_delta1"
# [308] "Master_cconsumos_delta2"
# [309] "Master_mpagominimo_delta2"
# [310] "Visa_mfinanciacion_limite_delta2"
# [311] "Visa_msaldototal_delta1"
# [312] "Visa_msaldopesos_delta1"
# [313] "Visa_msaldopesos_delta2"
# [314] "Visa_msaldodolares_delta2"
# [315] "Visa_mconsumospesos_delta2"
# [316] "Visa_mlimitecompra_delta1"
# [317] "Visa_mpagado_delta2"
# [318] "Visa_mpagospesos_delta1"
# [319] "Visa_mpagospesos_delta2"
# [320] "Visa_cconsumos_delta1"
# [321] "Visa_cconsumos_delta2"
# [322] "Visa_mpagominimo_delta1"
# [323] "Visa_mpagominimo_delta2"
# [324] "ctrx_quarter_normalizado_delta1"
# [325] "mpayroll_sobre_edad_delta1"
# [326] "vm_status01_delta2"
# [327] "vm_status04_delta1"
# [328] "vm_status04_delta2"
# [329] "vm_status06_delta2"
# [330] "mv_status07_delta1"
# [331] "mv_status07_delta2"
# [332] "vm_mfinanciacion_limite_delta1"
# [333] "vm_mfinanciacion_limite_delta2"
# [334] "vm_msaldototal_delta1"
# [335] "vm_msaldopesos_delta1"
# [336] "vm_msaldopesos_delta2"
# [337] "vm_fultimo_cierre_delta2"
# [338] "vm_mpagospesos_delta2"
# [339] "vm_cconsumos_delta1"
# [340] "vm_mpagominimo_delta1"
# [341] "vm_mpagominimo_delta2"
# [342] "vmr_Visa_mlimitecompra_delta1"
# [343] "vmr_msaldototal_delta1"
# [344] "vmr_msaldototal_delta2"
# [345] "vmr_msaldopesos_delta1"
# [346] "vmr_msaldopesos_delta2"
# [347] "vmr_msaldodolares_delta2"
# [348] "vmr_mpagado_delta2"
# [349] "vmr_mpagospesos_delta2"
# [350] "vmr_mpagominimo_delta1"
# [351] "vmr_mpagominimo_delta2"
# [352] "internet_tend6"
# [353] "mrentabilidad_tend6"
# [354] "mrentabilidad_annual_tend6"
# [355] "mcomisiones_tend6"
# [356] "mactivos_margen_tend6"
# [357] "mpasivos_margen_tend6"
# [358] "cproductos_tend6"
# [359] "mcuenta_corriente_tend6"
# [360] "mcaja_ahorro_tend6"
# [361] "mcaja_ahorro_dolares_tend6"
# [362] "cdescubierto_preacordado_tend6"
# [363] "mcuentas_saldo_tend6"
# [364] "ctarjeta_debito_transacciones_tend6"
# [365] "ctarjeta_visa_transacciones_tend6"
# [366] "mtarjeta_visa_consumo_tend6"
# [367] "ctarjeta_master_tend6"
# [368] "ctarjeta_master_transacciones_tend6"
# [369] "cprestamos_personales_tend6"
# [370] "mprestamos_personales_tend6"
# [371] "cplazo_fijo_tend6"
# [372] "mpayroll_tend6"
# [373] "ccuenta_debitos_automaticos_tend6"
# [374] "mcuenta_debitos_automaticos_tend6"
# [375] "ctarjeta_visa_debitos_automaticos_tend6"
# [376] "mttarjeta_visa_debitos_automaticos_tend6"
# [377] "cpagomiscuentas_tend6"
# [378] "mpagomiscuentas_tend6"
# [379] "ccomisiones_mantenimiento_tend6"
# [380] "mcomisiones_mantenimiento_tend6"
# [381] "ccomisiones_otras_tend6"
# [382] "mcomisiones_otras_tend6"
# [383] "ctransferencias_recibidas_tend6"
# [384] "mtransferencias_recibidas_tend6"
# [385] "ctransferencias_emitidas_tend6"
# [386] "mtransferencias_emitidas_tend6"
# [387] "mextraccion_autoservicio_tend6"
# [388] "ccheques_depositados_tend6"
# [389] "mcheques_depositados_tend6"
# [390] "tcallcenter_tend6"
# [391] "ccallcenter_transacciones_tend6"
# [392] "thomebanking_tend6"
# [393] "chomebanking_transacciones_tend6"
# [394] "ccajas_transacciones_tend6"
# [395] "ccajas_consultas_tend6"
# [396] "ccajas_extracciones_tend6"
# [397] "ccajas_otras_tend6"
# [398] "matm_tend6"
# [399] "catm_trx_other_tend6"
# [400] "ctrx_quarter_tend6"
# [401] "cmobile_app_trx_tend6"
# [402] "Master_mfinanciacion_limite_tend6"
# [403] "Master_msaldototal_tend6"
# [404] "Master_msaldopesos_tend6"
# [405] "Master_mconsumosdolares_tend6"
# [406] "Master_cconsumos_tend6"
# [407] "Master_mpagominimo_tend6"
# [408] "Visa_delinquency_tend6"
# [409] "Visa_status_tend6"
# [410] "Visa_mfinanciacion_limite_tend6"
# [411] "Visa_Fvencimiento_tend6"
# [412] "Visa_msaldototal_tend6"
# [413] "Visa_msaldopesos_tend6"
# [414] "Visa_mconsumospesos_tend6"
# [415] "Visa_mconsumosdolares_tend6"
# [416] "Visa_mlimitecompra_tend6"
# [417] "Visa_mpagospesos_tend6"
# [418] "Visa_mpagosdolares_tend6"
# [419] "Visa_cconsumos_tend6"
# [420] "Visa_mpagominimo_tend6"
# [421] "kmes_tend6"
# [422] "ctrx_quarter_normalizado_tend6"
# [423] "mpayroll_sobre_edad_tend6"
# [424] "vm_status01_tend6"
# [425] "vm_status02_tend6"
# [426] "vm_status03_tend6"
# [427] "vm_status04_tend6"
# [428] "vm_status05_tend6"
# [429] "vm_mfinanciacion_limite_tend6"
# [430] "vm_msaldototal_tend6"
# [431] "vm_msaldopesos_tend6"
# [432] "vm_mconsumospesos_tend6"
# [433] "vm_mlimitecompra_tend6"
# [434] "vm_mpagado_tend6"
# [435] "vm_mpagospesos_tend6"
# [436] "vm_mpagominimo_tend6"
# [437] "vmr_Master_mlimitecompra_tend6"
# [438] "vmr_Visa_mlimitecompra_tend6"
# [439] "vmr_msaldototal_tend6"
# [440] "vmr_msaldopesos_tend6"
# [441] "vmr_msaldopesos2_tend6"
# [442] "vmr_msaldodolares_tend6"
# [443] "vmr_msaldodolares2_tend6"
# [444] "vmr_mconsumospesos_tend6"
# [445] "vmr_mpagado_tend6"
# [446] "vmr_mpagospesos_tend6"

# %% [markdown]
# ### 9.7.2 Modelado

# %% [markdown]
# #### 9.7.2.1 Training Strategy

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 201901, 202107 ] sin undersampling de los CONTINUA
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 201901, 202105 ]  donde se consideran el 20% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005, 202006,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105
)

PARAM$trainingstrategy$training_pct <- 0.2


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 164479

# %% [markdown]
# ####  9.7.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **40**

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# 40 es el minimo razonable,  un buen analista Sr aumentara este valor
PARAM$hipeparametertuning$num_interations <- 40

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  extra_trees= FALSE,

  num_leaves= 128,
  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  # min_gain_to_split= 0.0, # min_gain_to_split >= 0.0
  min_data_in_leaf= 0,
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  # lambda_l1= 0.0, # lambda_l1 >= 0.0
  # lambda_l2= 0.0, # lambda_l2 >= 0.0

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  max_bin= 31,
  early_stopping_rounds= 0
)

# %%
PARAM$hipeparametertuning$hs <- makeParamSet(
  makeNumericParam("num_iterations", lower=2.0, upper=10.0, trafo=function(x) round(2^x)),
  makeNumericParam("num_leaves", lower=2.0, upper=11.0, trafo=function(x) round(2^x)),
  makeNumericParam("learning_rate", lower=-7.0, upper=-0.1, trafo=function(x) 2^x),
  makeNumericParam("feature_fraction", lower=0.05, upper=1.0),
  makeNumericParam("min_sum_hessian_in_leaf", lower=-10.0, upper=10.0, trafo=function(x) 2^x),  # <- tal cual estaba, sin tocar
  makeNumericParam("lambda_l1", lower=0, upper=1000),
  makeNumericParam("lambda_l2", lower=0, upper=1000),
  makeNumericParam("min_gain_to_split", lower=0, upper=10)
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[x$num_iterations]]


  message(format(Sys.time(), "%a %b %d %X %Y  "),
    toString(x),
    " AUC ", AUC
  )

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Jul 22 23:57:42 2026  20, 15, 0.0445909124790026, 0.818762145513617, 0.104722284720815, 267.542527564824, 378.581672832949, 8.8153760542274 AUC 0.905802662324587
#
# Wed Jul 22 23:57:51 2026  36, 38, 0.130997913916577, 0.603438436015031, 61.4730805729566, 928.136961648704, 205.609366490796, 3.198814801372 AUC 0.920907547376884
#
# Wed Jul 22 23:58:27 2026  175, 23, 0.203597433477634, 0.264595041576792, 0.0191441291632917, 211.675909208969, 490.644496288804, 7.61683133341743 AUC 0.928872745629169
#
# Wed Jul 22 23:58:30 2026  11, 187, 0.148088818522424, 0.747669761033394, 0.512682873052405, 685.098933900143, 181.339510105287, 2.21631631256461 AUC 0.911527831183662
#
# Wed Jul 22 23:58:34 2026  9, 1432, 0.172653537543451, 0.315307253209067, 0.0400625480376301, 527.838241136424, 791.172705394605, 4.72708998279639 AUC 0.906640590650273
#
# Wed Jul 22 23:58:58 2026  346, 206, 0.521782609456135, 0.854894436719968, 2.12741676294829, 470.365416351358, 436.354204149201, 4.60678366698814 AUC 0.920504164669174
#
# Thu Jul 23 00:00:29 2026  783, 98, 0.0252446273914949, 0.623882917837652, 0.228185115470057, 159.211410200159, 438.206286691282, 5.50330021389503 AUC 0.931202600852587
#
# Thu Jul 23 00:00:52 2026  87, 88, 0.274966379389893, 0.439921205402538, 0.00326855400617738, 534.270506825884, 526.832887696217, 1.86722640608975 AUC 0.92383645381041
#
# Thu Jul 23 00:00:58 2026  23, 7, 0.0391176285773674, 0.249525310945249, 28.0300498688405, 383.370928828058, 952.963167626315, 7.37936624927578 AUC 0.898584273250494
#
# Thu Jul 23 00:01:26 2026  141, 282, 0.10399221101246, 0.221554164711521, 647.21305471569, 593.89591638298, 305.880763618496, 0.122512660058013 AUC 0.92568420992444
#
# Thu Jul 23 00:01:35 2026  64, 135, 0.0128923776280612, 0.659393005640012, 3.36328016057839, 773.91521309022, 605.628111232805, 1.98365355698623 AUC 0.894827731087839
#
# Thu Jul 23 00:04:52 2026  876, 11, 0.0619432149067918, 0.412977750957579, 11.396971578719, 336.017659941961, 33.2715886503552, 7.18105371908382 AUC 0.927090327082485
#
# Thu Jul 23 00:06:26 2026  452, 1913, 0.0533313141867066, 0.331563303433616, 169.187825677388, 639.349058652496, 649.862062626066, 8.37461182906857 AUC 0.924981057589546
#
# Thu Jul 23 00:06:32 2026  27, 927, 0.00927559275712814, 0.72701394431282, 7.60992657149982, 108.615522156069, 106.811003780851, 8.57567405262443 AUC 0.913248256550503
#
# Thu Jul 23 00:06:35 2026  12, 43, 0.090738032526552, 0.675699050827118, 0.141039977204919, 827.323084250838, 268.130928995957, 9.24367457123224 AUC 0.89604015375408
#
# Thu Jul 23 00:06:41 2026  17, 4, 0.0758682245838261, 0.363464528451513, 0.00556399429474607, 131.345003262921, 583.510946226662, 3.59795919799956 AUC 0.897189107548757
#
# Thu Jul 23 00:06:45 2026  8, 52, 0.433906852071097, 0.525656172592553, 89.2688852715779, 371.339547270589, 359.628837065899, 6.22125143904595 AUC 0.916743651367443
#
# Thu Jul 23 00:08:03 2026  716, 63, 0.0176496873069584, 0.782695800344105, 0.0212587092511976, 730.97218423464, 892.481193843959, 6.52700116183929 AUC 0.924224247357023
#
# Thu Jul 23 00:08:25 2026  126, 980, 0.032045250574874, 0.134186603375536, 0.0571507276786588, 245.452105524085, 726.131340453359, 5.87799130265128 AUC 0.922171614116022
#
# Thu Jul 23 00:08:28 2026  5, 16, 0.838159323913207, 0.846423902695442, 0.366090746221419, 798.576079835201, 330.969622794756, 1.28863882329591 AUC 0.897772822610188
#
# Thu Jul 23 00:09:30 2026  222, 33, 0.0160003743251951, 0.571967608892129, 0.00147466474785541, 583.707920313172, 151.157011460608, 2.51152675210849 AUC 0.921882160203282
#
# Thu Jul 23 00:09:41 2026  48, 7, 0.0731579418534899, 0.193357992076859, 207.734490071005, 968.083818403581, 539.062825861054, 7.89658287940005 AUC 0.914439255358098
#
# Thu Jul 23 00:11:25 2026  366, 111, 0.010771060202225, 0.518649822378453, 36.6326715024938, 92.4023111149275, 844.105618993977, 0.556997457587386 AUC 0.925989964515432
#
# Thu Jul 23 00:11:31 2026  55, 363, 0.797740687205284, 0.975702322741379, 5.63156071550591, 860.412020875828, 706.229324231844, 9.59372593829059 AUC 0.913102138667995
#
# Thu Jul 23 00:12:06 2026  206, 10, 0.346784912956953, 0.159478674425846, 298.844433421674, 57.1696545122629, 662.714126570974, 3.90393863115325 AUC 0.931713490720278
#
# Thu Jul 23 00:12:10 2026  7, 768, 0.00837427232922656, 0.482058397271108, 0.00230448204222962, 973.091637634919, 833.906644725958, 5.29589472447315 AUC 0.889443464996698
#
# Thu Jul 23 00:12:16 2026  43, 515, 0.0258931639209121, 0.896652908891496, 752.595449981176, 708.577714680674, 25.0661152301477, 1.22263301591626 AUC 0.905015274834907
#
# Thu Jul 23 00:12:44 2026  299, 619, 0.23917579922869, 0.919479267559684, 0.0130521030865147, 20.3675320340429, 222.100991445071, 3.05899661864301 AUC 0.933464843965546
#
# Thu Jul 23 00:12:50 2026  16, 1268, 0.512644404262819, 0.390203346386213, 15.1372873574493, 446.802207326367, 992.892219602731, 0.88894672893242 AUC 0.920541936726171
#
# Thu Jul 23 00:13:05 2026  93, 6, 0.665201956566155, 0.057696333036269, 0.0042705185400231, 408.289048191887, 918.847457250003, 9.9769698011857 AUC 0.918433522595013
#
# Thu Jul 23 00:13:07 2026  4, 19, 0.0204819158372739, 0.969295858011052, 1.54116455730651, 292.857665905181, 772.755756868445, 6.65820685758827 AUC 0.881833801849829
#
# Thu Jul 23 00:14:22 2026  537, 315, 0.296319334048908, 0.0850548918280791, 0.863481392584232, 897.578632133688, 65.1861288706923, 4.13713769970337 AUC 0.921397871316363
#
# [mbo] 0: num_iterations=20; num_leaves=15; learning_rate=0.0446; feature_fraction=0.819; min_sum_hessian_in_leaf=0.105; lambda_l1=268; lambda_l2=379; min_gain_to_split=8.82 : y = 0.906 : 12.4 secs : initdesign
#
# [mbo] 0: num_iterations=36; num_leaves=38; learning_rate=0.131; feature_fraction=0.603; min_sum_hessian_in_leaf=61.5; lambda_l1=928; lambda_l2=206; min_gain_to_split=3.2 : y = 0.921 : 8.5 secs : initdesign
#
# [mbo] 0: num_iterations=175; num_leaves=23; learning_rate=0.204; feature_fraction=0.265; min_sum_hessian_in_leaf=0.0191; lambda_l1=212; lambda_l2=491; min_gain_to_split=7.62 : y = 0.929 : 35.6 secs : initdesign
#
# [mbo] 0: num_iterations=11; num_leaves=187; learning_rate=0.148; feature_fraction=0.748; min_sum_hessian_in_leaf=0.513; lambda_l1=685; lambda_l2=181; min_gain_to_split=2.22 : y = 0.912 : 3.3 secs : initdesign
#
# [mbo] 0: num_iterations=9; num_leaves=1.43e+03; learning_rate=0.173; feature_fraction=0.315; min_sum_hessian_in_leaf=0.0401; lambda_l1=528; lambda_l2=791; min_gain_to_split=4.73 : y = 0.907 : 4.0 secs : initdesign
#
# [mbo] 0: num_iterations=346; num_leaves=206; learning_rate=0.522; feature_fraction=0.855; min_sum_hessian_in_leaf=2.13; lambda_l1=470; lambda_l2=436; min_gain_to_split=4.61 : y = 0.921 : 24.1 secs : initdesign
#
# [mbo] 0: num_iterations=783; num_leaves=98; learning_rate=0.0252; feature_fraction=0.624; min_sum_hessian_in_leaf=0.228; lambda_l1=159; lambda_l2=438; min_gain_to_split=5.5 : y = 0.931 : 91.2 secs : initdesign
#
# [mbo] 0: num_iterations=87; num_leaves=88; learning_rate=0.275; feature_fraction=0.44; min_sum_hessian_in_leaf=0.00327; lambda_l1=534; lambda_l2=527; min_gain_to_split=1.87 : y = 0.924 : 22.7 secs : initdesign
#
# [mbo] 0: num_iterations=23; num_leaves=7; learning_rate=0.0391; feature_fraction=0.25; min_sum_hessian_in_leaf=28; lambda_l1=383; lambda_l2=953; min_gain_to_split=7.38 : y = 0.899 : 6.3 secs : initdesign
#
# [mbo] 0: num_iterations=141; num_leaves=282; learning_rate=0.104; feature_fraction=0.222; min_sum_hessian_in_leaf=647; lambda_l1=594; lambda_l2=306; min_gain_to_split=0.123 : y = 0.926 : 28.1 secs : initdesign
#
# [mbo] 0: num_iterations=64; num_leaves=135; learning_rate=0.0129; feature_fraction=0.659; min_sum_hessian_in_leaf=3.36; lambda_l1=774; lambda_l2=606; min_gain_to_split=1.98 : y = 0.895 : 8.7 secs : initdesign
#
# [mbo] 0: num_iterations=876; num_leaves=11; learning_rate=0.0619; feature_fraction=0.413; min_sum_hessian_in_leaf=11.4; lambda_l1=336; lambda_l2=33.3; min_gain_to_split=7.18 : y = 0.927 : 196.6 secs : initdesign
#
# [mbo] 0: num_iterations=452; num_leaves=1.91e+03; learning_rate=0.0533; feature_fraction=0.332; min_sum_hessian_in_leaf=169; lambda_l1=639; lambda_l2=650; min_gain_to_split=8.37 : y = 0.925 : 94.4 secs : initdesign
#
# [mbo] 0: num_iterations=27; num_leaves=927; learning_rate=0.00928; feature_fraction=0.727; min_sum_hessian_in_leaf=7.61; lambda_l1=109; lambda_l2=107; min_gain_to_split=8.58 : y = 0.913 : 5.6 secs : initdesign
#
# [mbo] 0: num_iterations=12; num_leaves=43; learning_rate=0.0907; feature_fraction=0.676; min_sum_hessian_in_leaf=0.141; lambda_l1=827; lambda_l2=268; min_gain_to_split=9.24 : y = 0.896 : 3.3 secs : initdesign
#
# [mbo] 0: num_iterations=17; num_leaves=4; learning_rate=0.0759; feature_fraction=0.363; min_sum_hessian_in_leaf=0.00556; lambda_l1=131; lambda_l2=584; min_gain_to_split=3.6 : y = 0.897 : 5.7 secs : initdesign
#
# [mbo] 0: num_iterations=8; num_leaves=52; learning_rate=0.434; feature_fraction=0.526; min_sum_hessian_in_leaf=89.3; lambda_l1=371; lambda_l2=360; min_gain_to_split=6.22 : y = 0.917 : 4.2 secs : initdesign
#
# [mbo] 0: num_iterations=716; num_leaves=63; learning_rate=0.0176; feature_fraction=0.783; min_sum_hessian_in_leaf=0.0213; lambda_l1=731; lambda_l2=892; min_gain_to_split=6.53 : y = 0.924 : 77.6 secs : initdesign
#
# [mbo] 0: num_iterations=126; num_leaves=980; learning_rate=0.032; feature_fraction=0.134; min_sum_hessian_in_leaf=0.0572; lambda_l1=245; lambda_l2=726; min_gain_to_split=5.88 : y = 0.922 : 22.8 secs : initdesign
#
# [mbo] 0: num_iterations=5; num_leaves=16; learning_rate=0.838; feature_fraction=0.846; min_sum_hessian_in_leaf=0.366; lambda_l1=799; lambda_l2=331; min_gain_to_split=1.29 : y = 0.898 : 2.5 secs : initdesign
#
# [mbo] 0: num_iterations=222; num_leaves=33; learning_rate=0.016; feature_fraction=0.572; min_sum_hessian_in_leaf=0.00147; lambda_l1=584; lambda_l2=151; min_gain_to_split=2.51 : y = 0.922 : 62.5 secs : initdesign
#
# [mbo] 0: num_iterations=48; num_leaves=7; learning_rate=0.0732; feature_fraction=0.193; min_sum_hessian_in_leaf=208; lambda_l1=968; lambda_l2=539; min_gain_to_split=7.9 : y = 0.914 : 10.3 secs : initdesign
#
# [mbo] 0: num_iterations=366; num_leaves=111; learning_rate=0.0108; feature_fraction=0.519; min_sum_hessian_in_leaf=36.6; lambda_l1=92.4; lambda_l2=844; min_gain_to_split=0.557 : y = 0.926 : 104.2 secs : initdesign
#
# [mbo] 0: num_iterations=55; num_leaves=363; learning_rate=0.798; feature_fraction=0.976; min_sum_hessian_in_leaf=5.63; lambda_l1=860; lambda_l2=706; min_gain_to_split=9.59 : y = 0.913 : 5.8 secs : initdesign
#
# [mbo] 0: num_iterations=206; num_leaves=10; learning_rate=0.347; feature_fraction=0.159; min_sum_hessian_in_leaf=299; lambda_l1=57.2; lambda_l2=663; min_gain_to_split=3.9 : y = 0.932 : 35.6 secs : initdesign
#
# [mbo] 0: num_iterations=7; num_leaves=768; learning_rate=0.00837; feature_fraction=0.482; min_sum_hessian_in_leaf=0.0023; lambda_l1=973; lambda_l2=834; min_gain_to_split=5.3 : y = 0.889 : 3.9 secs : initdesign
#
# [mbo] 0: num_iterations=43; num_leaves=515; learning_rate=0.0259; feature_fraction=0.897; min_sum_hessian_in_leaf=753; lambda_l1=709; lambda_l2=25.1; min_gain_to_split=1.22 : y = 0.905 : 6.2 secs : initdesign
#
# [mbo] 0: num_iterations=299; num_leaves=619; learning_rate=0.239; feature_fraction=0.919; min_sum_hessian_in_leaf=0.0131; lambda_l1=20.4; lambda_l2=222; min_gain_to_split=3.06 : y = 0.933 : 27.8 secs : initdesign
#
# [mbo] 0: num_iterations=16; num_leaves=1.27e+03; learning_rate=0.513; feature_fraction=0.39; min_sum_hessian_in_leaf=15.1; lambda_l1=447; lambda_l2=993; min_gain_to_split=0.889 : y = 0.921 : 6.0 secs : initdesign
#
# [mbo] 0: num_iterations=93; num_leaves=6; learning_rate=0.665; feature_fraction=0.0577; min_sum_hessian_in_leaf=0.00427; lambda_l1=408; lambda_l2=919; min_gain_to_split=9.98 : y = 0.918 : 14.4 secs : initdesign
#
# [mbo] 0: num_iterations=4; num_leaves=19; learning_rate=0.0205; feature_fraction=0.969; min_sum_hessian_in_leaf=1.54; lambda_l1=293; lambda_l2=773; min_gain_to_split=6.66 : y = 0.882 : 2.4 secs : initdesign
#
# [mbo] 0: num_iterations=537; num_leaves=315; learning_rate=0.296; feature_fraction=0.0851; min_sum_hessian_in_leaf=0.863; lambda_l1=898; lambda_l2=65.2; min_gain_to_split=4.14 : y = 0.921 : 74.9 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Thu Jul 23 00:14:45 2026  89, 615, 0.248941810525197, 0.286224563777995, 233.880016606031, 2.3199333432257, 99.2544991657189, 3.41237544936271 AUC 0.934681158142589
#
# [mbo] 1: num_iterations=89; num_leaves=615; learning_rate=0.249; feature_fraction=0.286; min_sum_hessian_in_leaf=234; lambda_l1=2.32; lambda_l2=99.3; min_gain_to_split=3.41 : y = 0.935 : 21.6 secs : infill_ei
#
# Thu Jul 23 00:15:10 2026  216, 239, 0.140614666485248, 0.721334768891879, 33.5452821363761, 1.49606972281125, 54.5134702885671, 4.93413573151744 AUC 0.93484707135711
#
# [mbo] 2: num_iterations=216; num_leaves=239; learning_rate=0.141; feature_fraction=0.721; min_sum_hessian_in_leaf=33.5; lambda_l1=1.5; lambda_l2=54.5; min_gain_to_split=4.93 : y = 0.935 : 24.7 secs : infill_ei
#
# Thu Jul 23 00:16:59 2026  367, 661, 0.0542784089816038, 0.592923514080914, 0.0102390475424992, 0.537549909519904, 145.569841657038, 2.26186641546373 AUC 0.938028884894335
#
# [mbo] 3: num_iterations=367; num_leaves=661; learning_rate=0.0543; feature_fraction=0.593; min_sum_hessian_in_leaf=0.0102; lambda_l1=0.538; lambda_l2=146; min_gain_to_split=2.26 : y = 0.938 : 108.5 secs : infill_ei
#
# Thu Jul 23 00:17:47 2026  338, 298, 0.0423986914303983, 0.758814751577511, 0.00126864831255731, 1.90176774533791, 208.776146836043, 9.26025695373169 AUC 0.934496528430733
#
# [mbo] 4: num_iterations=338; num_leaves=298; learning_rate=0.0424; feature_fraction=0.759; min_sum_hessian_in_leaf=0.00127; lambda_l1=1.9; lambda_l2=209; min_gain_to_split=9.26 : y = 0.934 : 47.4 secs : infill_ei
#
# Thu Jul 23 00:18:43 2026  301, 1676, 0.112941952607405, 0.146366973307213, 0.0801933104869101, 0.382038218771732, 66.8819126314228, 2.47853543117364 AUC 0.938597480858352
#
# [mbo] 5: num_iterations=301; num_leaves=1.68e+03; learning_rate=0.113; feature_fraction=0.146; min_sum_hessian_in_leaf=0.0802; lambda_l1=0.382; lambda_l2=66.9; min_gain_to_split=2.48 : y = 0.939 : 55.2 secs : infill_ei
#
# Thu Jul 23 00:20:13 2026  323, 248, 0.116915761151966, 0.316457469770611, 0.00390898747193124, 0.214855818208616, 23.9570935614635, 0.0530245212228918 AUC 0.936444947526175
#
# [mbo] 6: num_iterations=323; num_leaves=248; learning_rate=0.117; feature_fraction=0.316; min_sum_hessian_in_leaf=0.00391; lambda_l1=0.215; lambda_l2=24; min_gain_to_split=0.053 : y = 0.936 : 90.1 secs : infill_ei
#
# Thu Jul 23 00:21:47 2026  416, 1994, 0.0989546128890916, 0.304053884771597, 0.0111741042552922, 0.267326072374341, 776.136900303869, 2.42272054515453 AUC 0.937040301158858
#
# [mbo] 7: num_iterations=416; num_leaves=1.99e+03; learning_rate=0.099; feature_fraction=0.304; min_sum_hessian_in_leaf=0.0112; lambda_l1=0.267; lambda_l2=776; min_gain_to_split=2.42 : y = 0.937 : 93.5 secs : infill_ei
#
# Thu Jul 23 00:22:49 2026  355, 504, 0.0819674134645616, 0.118088583526731, 3.12710109395954, 1.08374219329189, 315.786991960756, 3.1631114614267 AUC 0.936638125718526
#
# [mbo] 8: num_iterations=355; num_leaves=504; learning_rate=0.082; feature_fraction=0.118; min_sum_hessian_in_leaf=3.13; lambda_l1=1.08; lambda_l2=316; min_gain_to_split=3.16 : y = 0.937 : 61.3 secs : infill_ei
#
# Thu Jul 23 00:24:12 2026  433, 1608, 0.0516478464975301, 0.193386788130626, 0.00124683980666258, 36.5754340527468, 159.197234708552, 3.76335989380821 AUC 0.934809150318181
#
# [mbo] 9: num_iterations=433; num_leaves=1.61e+03; learning_rate=0.0516; feature_fraction=0.193; min_sum_hessian_in_leaf=0.00125; lambda_l1=36.6; lambda_l2=159; min_gain_to_split=3.76 : y = 0.935 : 81.8 secs : infill_ei
#
# Thu Jul 23 00:25:04 2026  263, 1853, 0.112087545604085, 0.61160364568588, 0.0192694329118167, 1.44122006193917, 800.173191882135, 2.07221053736828 AUC 0.936771030444884
#
# [mbo] 10: num_iterations=263; num_leaves=1.85e+03; learning_rate=0.112; feature_fraction=0.612; min_sum_hessian_in_leaf=0.0193; lambda_l1=1.44; lambda_l2=800; min_gain_to_split=2.07 : y = 0.937 : 52.0 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Thu Jul 23 00:25:56 2026  189, 1331, 0.168188830869237, 0.296378825697212, 1.41517340191527, 0.777794040080801, 171.919591505408, 0.906839240497745 AUC 0.937951916461701
#
# [mbo] 11: num_iterations=189; num_leaves=1.33e+03; learning_rate=0.168; feature_fraction=0.296; min_sum_hessian_in_leaf=1.42; lambda_l1=0.778; lambda_l2=172; min_gain_to_split=0.907 : y = 0.938 : 50.7 secs : infill_ei
#
# Thu Jul 23 00:26:50 2026  419, 2024, 0.103931618802982, 0.760883672098265, 0.994214067757895, 5.37822324087714, 265.837364282663, 2.11464545974268 AUC 0.936858802636222
#
# [mbo] 12: num_iterations=419; num_leaves=2.02e+03; learning_rate=0.104; feature_fraction=0.761; min_sum_hessian_in_leaf=0.994; lambda_l1=5.38; lambda_l2=266; min_gain_to_split=2.11 : y = 0.937 : 53.6 secs : infill_ei
#
# Thu Jul 23 00:28:06 2026  277, 1240, 0.102195388166603, 0.467013656512706, 0.0535723115568855, 0.361735260280432, 178.094825543543, 3.30827606594203 AUC 0.936971890197008
#
# [mbo] 13: num_iterations=277; num_leaves=1.24e+03; learning_rate=0.102; feature_fraction=0.467; min_sum_hessian_in_leaf=0.0536; lambda_l1=0.362; lambda_l2=178; min_gain_to_split=3.31 : y = 0.937 : 74.9 secs : infill_ei
#
# Thu Jul 23 00:28:51 2026  295, 2044, 0.173519322882876, 0.057019795702842, 1.00441211968318, 3.83213200873164, 606.469930205425, 0.634899020480383 AUC 0.935807682450581
#
# [mbo] 14: num_iterations=295; num_leaves=2.04e+03; learning_rate=0.174; feature_fraction=0.057; min_sum_hessian_in_leaf=1; lambda_l1=3.83; lambda_l2=606; min_gain_to_split=0.635 : y = 0.936 : 45.1 secs : infill_ei
#
# Thu Jul 23 00:30:34 2026  514, 421, 0.0463675571587722, 0.817519595534693, 0.00217924195117977, 1.38957925242851, 947.797735694319, 1.02468371790089 AUC 0.936219424842718
#
# [mbo] 15: num_iterations=514; num_leaves=421; learning_rate=0.0464; feature_fraction=0.818; min_sum_hessian_in_leaf=0.00218; lambda_l1=1.39; lambda_l2=948; min_gain_to_split=1.02 : y = 0.936 : 102.3 secs : infill_ei
#
# Thu Jul 23 00:31:57 2026  372, 2021, 0.0553595318809691, 0.998335449720636, 0.00960331710120431, 0.239683702198834, 487.114373313376, 1.12420435803838 AUC 0.937128587080995
#
# [mbo] 16: num_iterations=372; num_leaves=2.02e+03; learning_rate=0.0554; feature_fraction=0.998; min_sum_hessian_in_leaf=0.0096; lambda_l1=0.24; lambda_l2=487; min_gain_to_split=1.12 : y = 0.937 : 82.3 secs : infill_ei
#
# Thu Jul 23 00:32:51 2026  368, 22, 0.0511823930669313, 0.73658903534174, 0.241233589623418, 0.450752404959732, 64.0394456957972, 1.44809433007888 AUC 0.935544690811298
#
# [mbo] 17: num_iterations=368; num_leaves=22; learning_rate=0.0512; feature_fraction=0.737; min_sum_hessian_in_leaf=0.241; lambda_l1=0.451; lambda_l2=64; min_gain_to_split=1.45 : y = 0.936 : 53.1 secs : infill_ei
#
# Thu Jul 23 00:33:38 2026  239, 559, 0.157386266993849, 0.151273585215014, 82.407932585051, 0.000978729668559543, 3.00550051599604, 1.37554943711989 AUC 0.935259792406419
#
# [mbo] 18: num_iterations=239; num_leaves=559; learning_rate=0.157; feature_fraction=0.151; min_sum_hessian_in_leaf=82.4; lambda_l1=0.000979; lambda_l2=3.01; min_gain_to_split=1.38 : y = 0.935 : 46.7 secs : infill_ei
#
# Thu Jul 23 00:33:47 2026  34, 1448, 0.289475342807513, 0.824496079031481, 41.5377615722106, 3.66610498434762, 7.64434730149099, 4.35880102165148 AUC 0.93226744664085
#
# [mbo] 19: num_iterations=34; num_leaves=1.45e+03; learning_rate=0.289; feature_fraction=0.824; min_sum_hessian_in_leaf=41.5; lambda_l1=3.67; lambda_l2=7.64; min_gain_to_split=4.36 : y = 0.932 : 8.6 secs : infill_ei
#
# Thu Jul 23 00:34:26 2026  173, 1692, 0.132275820689849, 0.0566549722664047, 0.18287690324192, 0.318851287364623, 5.30227720737173, 1.53865514732128 AUC 0.933459679686689
#
# [mbo] 20: num_iterations=173; num_leaves=1.69e+03; learning_rate=0.132; feature_fraction=0.0567; min_sum_hessian_in_leaf=0.183; lambda_l1=0.319; lambda_l2=5.3; min_gain_to_split=1.54 : y = 0.933 : 38.1 secs : infill_ei
#
# Thu Jul 23 00:36:36 2026  359, 1674, 0.0386892539840889, 0.742704262992165, 0.0912377286814433, 0.163285580623083, 121.439517416489, 0.479640814553444 AUC 0.937276780435931
#
# [mbo] 21: num_iterations=359; num_leaves=1.67e+03; learning_rate=0.0387; feature_fraction=0.743; min_sum_hessian_in_leaf=0.0912; lambda_l1=0.163; lambda_l2=121; min_gain_to_split=0.48 : y = 0.937 : 128.9 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Thu Jul 23 00:37:48 2026  341, 1993, 0.139694831385499, 0.252697293338435, 0.0912086269401156, 25.2357998911515, 143.929799309142, 1.0533376995335 AUC 0.937113385786652
#
# [mbo] 22: num_iterations=341; num_leaves=1.99e+03; learning_rate=0.14; feature_fraction=0.253; min_sum_hessian_in_leaf=0.0912; lambda_l1=25.2; lambda_l2=144; min_gain_to_split=1.05 : y = 0.937 : 71.2 secs : infill_ei
#
# Thu Jul 23 00:38:36 2026  163, 1601, 0.229677481365196, 0.889480014793193, 16.7234061368774, 0.899406463147191, 237.366219606991, 0.23128650358836 AUC 0.937212094022374
#
# [mbo] 23: num_iterations=163; num_leaves=1.6e+03; learning_rate=0.23; feature_fraction=0.889; min_sum_hessian_in_leaf=16.7; lambda_l1=0.899; lambda_l2=237; min_gain_to_split=0.231 : y = 0.937 : 47.6 secs : infill_ei
#
# Thu Jul 23 00:39:24 2026  184, 934, 0.249016120821232, 0.386670626180923, 9.93827180496248, 1.54167471373153, 854.43609849147, 1.98120393871994 AUC 0.936456967542545
#
# [mbo] 24: num_iterations=184; num_leaves=934; learning_rate=0.249; feature_fraction=0.387; min_sum_hessian_in_leaf=9.94; lambda_l1=1.54; lambda_l2=854; min_gain_to_split=1.98 : y = 0.936 : 47.1 secs : infill_ei
#
# Thu Jul 23 00:40:24 2026  354, 947, 0.0506876843979474, 0.748340006239051, 0.139717312071836, 0.332674385150817, 791.502084353161, 3.40490070756261 AUC 0.935032258466883
#
# [mbo] 25: num_iterations=354; num_leaves=947; learning_rate=0.0507; feature_fraction=0.748; min_sum_hessian_in_leaf=0.14; lambda_l1=0.333; lambda_l2=792; min_gain_to_split=3.4 : y = 0.935 : 59.6 secs : infill_ei
#
# Thu Jul 23 00:41:11 2026  205, 220, 0.185016103656707, 0.681583820637433, 1.99976749386587, 2.83888825616897, 410.312450571464, 0.828633336234432 AUC 0.937435941943426
#
# [mbo] 26: num_iterations=205; num_leaves=220; learning_rate=0.185; feature_fraction=0.682; min_sum_hessian_in_leaf=2; lambda_l1=2.84; lambda_l2=410; min_gain_to_split=0.829 : y = 0.937 : 45.4 secs : infill_ei
#
# Thu Jul 23 00:42:12 2026  324, 109, 0.0257783677495464, 0.164934580060058, 1.63323069557187, 0.774180052464899, 76.4488229996478, 9.52803355076214 AUC 0.93477616237925
#
# [mbo] 27: num_iterations=324; num_leaves=109; learning_rate=0.0258; feature_fraction=0.165; min_sum_hessian_in_leaf=1.63; lambda_l1=0.774; lambda_l2=76.4; min_gain_to_split=9.53 : y = 0.935 : 61.1 secs : infill_ei
#
# Thu Jul 23 00:43:23 2026  300, 923, 0.0822367073168164, 0.270797152494267, 0.152032775973144, 0.236128179645832, 573.42972563262, 1.59619758208814 AUC 0.936854484728856
#
# [mbo] 28: num_iterations=300; num_leaves=923; learning_rate=0.0822; feature_fraction=0.271; min_sum_hessian_in_leaf=0.152; lambda_l1=0.236; lambda_l2=573; min_gain_to_split=1.6 : y = 0.937 : 70.1 secs : infill_ei
#
# Thu Jul 23 00:45:00 2026  472, 667, 0.00931463507935391, 0.745657659568128, 0.00883311600259241, 1.27055008014332, 2.00310685772016, 8.67061117539152 AUC 0.93391661240856
#
# [mbo] 29: num_iterations=472; num_leaves=667; learning_rate=0.00931; feature_fraction=0.746; min_sum_hessian_in_leaf=0.00883; lambda_l1=1.27; lambda_l2=2; min_gain_to_split=8.67 : y = 0.934 : 95.7 secs : infill_ei
#
# Thu Jul 23 00:46:47 2026  464, 336, 0.030473049986495, 0.979278498821598, 0.00637000828278243, 0.697103392844806, 67.4955558044237, 1.88160432194127 AUC 0.937618515447759
#
# [mbo] 30: num_iterations=464; num_leaves=336; learning_rate=0.0305; feature_fraction=0.979; min_sum_hessian_in_leaf=0.00637; lambda_l1=0.697; lambda_l2=67.5; min_gain_to_split=1.88 : y = 0.938 : 106.9 secs : infill_ei
#
# Saved the current state after iteration 31 in the file HT.RDATA.
#
# Thu Jul 23 00:47:37 2026  206, 1920, 0.249912970996703, 0.336004092944334, 3.61720678036975, 1.21312824141269, 271.940404103436, 1.90821673755598 AUC 0.935517410421544
#
# [mbo] 31: num_iterations=206; num_leaves=1.92e+03; learning_rate=0.25; feature_fraction=0.336; min_sum_hessian_in_leaf=3.62; lambda_l1=1.21; lambda_l2=272; min_gain_to_split=1.91 : y = 0.936 : 49.3 secs : infill_ei
#
# Thu Jul 23 00:49:39 2026  358, 756, 0.0730848952946101, 0.87112655141333, 0.0154021685042403, 1.32690400768763, 61.6053064358567, 0.164179241187988 AUC 0.937448764664169
#
# [mbo] 32: num_iterations=358; num_leaves=756; learning_rate=0.0731; feature_fraction=0.871; min_sum_hessian_in_leaf=0.0154; lambda_l1=1.33; lambda_l2=61.6; min_gain_to_split=0.164 : y = 0.937 : 120.5 secs : infill_ei
#
# Thu Jul 23 00:50:14 2026  105, 1369, 0.182781805536409, 0.821918993535713, 7.69709008342181, 0.491922869268582, 370.549800694416, 0.0470122554546828 AUC 0.937527208788524
#
# [mbo] 33: num_iterations=105; num_leaves=1.37e+03; learning_rate=0.183; feature_fraction=0.822; min_sum_hessian_in_leaf=7.7; lambda_l1=0.492; lambda_l2=371; min_gain_to_split=0.047 : y = 0.938 : 35.0 secs : infill_ei
#
# Thu Jul 23 00:50:38 2026  129, 123, 0.202055977415495, 0.982814356479925, 305.642914726938, 1.36244861261901, 961.424704759277, 0.0825758436954623 AUC 0.935144678177631
#
# [mbo] 34: num_iterations=129; num_leaves=123; learning_rate=0.202; feature_fraction=0.983; min_sum_hessian_in_leaf=306; lambda_l1=1.36; lambda_l2=961; min_gain_to_split=0.0826 : y = 0.935 : 23.1 secs : infill_ei
#
# Thu Jul 23 00:52:06 2026  407, 218, 0.0366328314117363, 0.180806848649503, 0.032451688540382, 0.00582069178009627, 33.6426853798723, 1.61396245957047 AUC 0.939358138934559
#
# [mbo] 35: num_iterations=407; num_leaves=218; learning_rate=0.0366; feature_fraction=0.181; min_sum_hessian_in_leaf=0.0325; lambda_l1=0.00582; lambda_l2=33.6; min_gain_to_split=1.61 : y = 0.939 : 87.6 secs : infill_ei
#
# Thu Jul 23 00:54:08 2026  569, 588, 0.0157732921847853, 0.124885578246898, 0.0299455526675687, 2.24944863385813, 6.10799536965933, 1.12057207250196 AUC 0.939157078827424
#
# [mbo] 36: num_iterations=569; num_leaves=588; learning_rate=0.0158; feature_fraction=0.125; min_sum_hessian_in_leaf=0.0299; lambda_l1=2.25; lambda_l2=6.11; min_gain_to_split=1.12 : y = 0.939 : 120.7 secs : infill_ei
#
# Thu Jul 23 00:55:41 2026  409, 401, 0.0218701153162547, 0.189717794487469, 0.0213863677686919, 0.49628091548151, 3.44735698230555, 2.20382815594233 AUC 0.938640751119226
#
# [mbo] 37: num_iterations=409; num_leaves=401; learning_rate=0.0219; feature_fraction=0.19; min_sum_hessian_in_leaf=0.0214; lambda_l1=0.496; lambda_l2=3.45; min_gain_to_split=2.2 : y = 0.939 : 92.8 secs : infill_ei
#
# Thu Jul 23 00:57:47 2026  633, 680, 0.0325408858844743, 0.148185373534358, 0.023150757309176, 1.73695080922277, 3.24834218292134, 1.53457830248336 AUC 0.939444551023607
#
# [mbo] 38: num_iterations=633; num_leaves=680; learning_rate=0.0325; feature_fraction=0.148; min_sum_hessian_in_leaf=0.0232; lambda_l1=1.74; lambda_l2=3.25; min_gain_to_split=1.53 : y = 0.939 : 124.7 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Thu Jul 23 01:01:18 2026  1011, 921, 0.0114599852225805, 0.200578359483653, 0.0110491766376881, 0.668867577899404, 836.644260800475, 0.998691683509572 AUC 0.934300718652364
#
# [mbo] 39: num_iterations=1.01e+03; num_leaves=921; learning_rate=0.0115; feature_fraction=0.201; min_sum_hessian_in_leaf=0.011; lambda_l1=0.669; lambda_l2=837; min_gain_to_split=0.999 : y = 0.934 : 210.0 secs : infill_ei
#
# Thu Jul 23 01:04:11 2026  923, 1272, 0.0103527636550666, 0.122218475380667, 2.19510512415195, 4.61642551356874, 1.97838292226977, 2.70265081341035 AUC 0.938746908451533
#
# [mbo] 40: num_iterations=923; num_leaves=1.27e+03; learning_rate=0.0104; feature_fraction=0.122; min_sum_hessian_in_leaf=2.2; lambda_l1=4.62; lambda_l2=1.98; min_gain_to_split=2.7 : y = 0.939 : 171.9 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_iterations num_leaves learning_rate feature_fraction
#             <num>      <num>         <num>            <num>
# 1:       9.305491   9.408947     -4.941603        0.1481854
#    min_sum_hessian_in_leaf lambda_l1 lambda_l2 min_gain_to_split
#                      <num>     <num>     <num>             <num>
# 1:               -5.432797  1.736951  3.248342          1.534578

# %% [markdown]
# ### 9.7.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005, 202006,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105, 202106,
  202107
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 4547505

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- copy(fijos)

x <- PARAM$out$lgbm$mejores_hiperparametros
param_final$num_iterations <- round( 2^x$num_iterations )
param_final$num_leaves <- round( 2^x$num_leaves )
param_final$learning_rate <- 2^x$learning_rate
param_final$feature_fraction <- x$feature_fraction
param_final$min_sum_hessian_in_leaf <- 2^x$min_sum_hessian_in_leaf

# NUEVAS - agregar estas 3 líneas:
param_final$lambda_l1 <- x$lambda_l1
param_final$lambda_l2 <- x$lambda_l2
param_final$min_gain_to_split <- x$min_gain_to_split

# %%
param_final
# Out:
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] TRUE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $verbosity
# [1] -100
#
# $force_row_wise
# [1] TRUE
#
# $seed
# [1] 998443
#
# $extra_trees
# [1] FALSE
#
# $num_leaves
# [1] 680
#
# $max_depth
# [1] -1
#
# $min_data_in_leaf
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.02315076
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $max_bin
# [1] 31
#
# $num_iterations
# [1] 633
#
# $learning_rate
# [1] 0.03254089
#
# $feature_fraction
# [1] 0.1481854
#
# $lambda_l1
# [1] 1.736951
#
# $lambda_l2
# [1] 3.248342
#
# $min_gain_to_split
# [1] 1.534578

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# poner este valor en 5 o en 1  si se está muy ajustado de tiempo

PARAM$FT$semillerio <- 10  # cantidad de semillas

# %%
if(!require("primes")) install.packages("primes")
require("primes")
# Out:
# Loading required package: primes

# %%
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
# me quedo con PARAM$semillerio  primos al azar
PARAM$FT$semillas <- sample(primos)[seq(PARAM$FT$semillerio)]

cat( PARAM$FT$semillas)
# Out:
# 456047 759911 846061 295901 276587 283183 150589 126019 231223 130423

# %%
primero <- TRUE

crear_modelo_final <- function( sem ) {

  nombre_arch <- paste0( "./modelos/modelo_", sem, ".txt")
  if( !file.exists(nombre_arch) )
  {
    param_final$seed <- sem

    set.seed(sem, kind = "L'Ecuyer-CMRG")
    final_model <- lgb.train(
      data= dfinal_train,
      param= param_final,
      verbose= -100
    )

    lgb.save(final_model, nombre_arch) # grabo el modelo"

    # grabo la primer importancia de variables
    #  Natalia : da lo mismo cual se guarda
    if( primero)
    {
      primero <<- FALSE
      tb_importancia <- as.data.table(lgb.importance(final_model))
      archivo_importancia <- "impo.txt"

      fwrite( tb_importancia,
        file= archivo_importancia,
        sep= "\t"
      )
    }

    rm(final_model)
    gc(full = TRUE, verbose=FALSE)
  }
}

# %%
gc(full = TRUE, verbose=FALSE)
dir.create("modelos", showWarnings =FALSE)

primero <- TRUE
for( sem in PARAM$FT$semillas)  crear_modelo_final(sem)
# Out:
#        used       (Mb)    gc trigger (Mb)    max used   (Mb)
# Ncells    3057931   163.4    5582705   298.2    5582705   298.2
# Vcells 3924587803 29942.3 6790678055 51808.8 7481506430 57079.4

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := 0]

datos_matrix <- data.matrix(dfuture[, campos_buenos, with= FALSE])

# %%
agregar_a_ensemble <- function( sem ) {

  nombre_arch <- paste0( "./modelos/modelo_", sem, ".txt")
  final_model <- lgb.load(nombre_arch)

  prediccion <- predict(
    final_model,
    datos_matrix
  )

  tb_prediccion[, paste0("prob_", isem) := prediccion]
  tb_prediccion[, prob := prob + prediccion]

  rm(final_model)
  rm(prediccion)
  gc(full = TRUE, verbose=FALSE)
}

# %%
for( isem in seq(length(PARAM$FT$semillas)) )
{
  sem <- PARAM$FT$semillas[ isem ]
  agregar_a_ensemble( sem )
  gc(full = TRUE, verbose=FALSE)
}

rm( datos_matrix)
gc(full = TRUE, verbose=FALSE)

tb_prediccion[, prob := prob /length(PARAM$FT$semillas) ]
# Out:
#        used       (Mb)    gc trigger (Mb)    max used   (Mb)
# Ncells    3071037   164.1    9321743   497.9   11652178   622.3
# Vcells 1966430508 15002.7 5432542444 41447.1 7481506430 57079.4

# %%
# veo que hay en tb_prediccion
tb_prediccion
# Out:
#        numero_de_cliente prob         prob_1       prob_2       prob_3
# 1      11673459          7.034055e-04 0.0009906032 5.763359e-04 7.410087e-04
# 2      11673463          9.970773e-04 0.0011859357 8.516765e-04 9.692574e-04
# 3      11674064          2.227419e-03 0.0020481963 2.491541e-03 1.250913e-03
# 4      11674166          2.517248e-04 0.0003351926 2.369017e-04 1.902985e-04
# 5      11674316          2.222804e-03 0.0022563942 1.444061e-03 1.853765e-03
# 6      11674337          1.151725e-03 0.0013501118 8.486347e-04 8.956641e-04
# 7      11674528          5.299038e-03 0.0075241934 5.068748e-03 6.043856e-03
# 8      11674689          4.861249e-04 0.0004836409 3.609885e-04 3.709194e-04
# 9      11674959          1.365527e-02 0.0151250017 1.719708e-02 9.065358e-03
# 10     11675482          2.902499e-04 0.0003193728 2.302472e-04 3.272377e-04
# 11     11675570          7.283221e-04 0.0009240566 4.864056e-04 7.234999e-04
# 12     11675622          4.699972e-03 0.0024558979 4.734611e-03 4.624381e-03
# 13     11675635          5.423886e-04 0.0006488568 3.944451e-04 5.105106e-04
# 14     11675731          1.213653e-03 0.0017807429 1.835871e-03 1.628863e-03
# 15     11675748          1.122069e-02 0.0113882764 1.191193e-02 8.925850e-03
# 16     11675765          2.281548e-04 0.0001646487 2.055971e-04 2.426011e-04
# 17     11676465          9.698691e-05 0.0001274841 7.322531e-05 7.487449e-05
# 18     11676667          1.663732e-04 0.0001711210 1.249652e-04 1.593184e-04
# 19     11676687          3.424237e-03 0.0025709802 2.286521e-03 2.890544e-03
# 20     11676742          1.289894e-04 0.0001084308 1.616063e-04 1.038263e-04
# 21     11676923          9.064704e-03 0.0098417560 6.907345e-03 1.149660e-02
# 22     11677176          4.194187e-03 0.0047145224 3.415551e-03 3.812610e-03
# 23     11677288          9.761353e-04 0.0009396715 8.597283e-04 8.196773e-04
# 24     11677418          1.759102e-03 0.0017940031 1.231539e-03 1.963103e-03
# 25     11677599          4.357308e-04 0.0004671524 4.007407e-04 5.033011e-04
# 26     11677630          1.607435e-03 0.0018317511 2.089333e-03 1.917270e-03
# 27     11677678          2.508716e-04 0.0002194049 2.235190e-04 2.334419e-04
# 28     11678043          1.000870e-03 0.0011542277 9.445193e-04 1.039687e-03
# 29     11678491          8.357554e-04 0.0007693607 7.912437e-04 1.042278e-03
# 30     11678621          3.796503e-04 0.0005039587 3.819118e-04 2.765855e-04
# ⋮      ⋮                 ⋮            ⋮            ⋮            ⋮
# 165047 75196022          0.018752801  0.019978300  0.017859678  0.020258285
# 165048 75196074          0.004158501  0.004404354  0.003610489  0.003998680
# 165049 75197225          0.004465919  0.004111368  0.003722576  0.004017344
# 165050 75200716          0.003258076  0.003066968  0.002777548  0.003051814
# 165051 75203476          0.010726430  0.011038314  0.009281943  0.010428274
# 165052 75207175          0.014380460  0.014106179  0.012254356  0.013236589
# 165053 75208238          0.008825255  0.011834292  0.006254644  0.007282259
# 165054 75211633          0.003230252  0.002973064  0.002933581  0.003252927
# 165055 75211708          0.012530566  0.015487682  0.011823828  0.009077979
# 165056 75212566          0.014320666  0.013145791  0.013444008  0.014816883
# 165057 75214571          0.002880985  0.003169559  0.002092939  0.003123675
# 165058 75214998          0.005422732  0.005060836  0.004684756  0.005404739
# 165059 75220309          0.009412554  0.009841209  0.008669388  0.010540377
# 165060 75222335          0.004891804  0.004922742  0.004021011  0.004868221
# 165061 75222526          0.008594780  0.009789025  0.007429389  0.008742988
# 165062 75225280          0.004179769  0.004320516  0.003761377  0.003677906
# 165063 75226714          0.007525006  0.008402700  0.006544383  0.007936150
# 165064 75229116          0.013418411  0.012398332  0.012267987  0.015090127
# 165065 75232798          0.011692976  0.011237158  0.010788323  0.011581573
# 165066 75234270          0.003503991  0.003568873  0.002688822  0.003329949
# 165067 75235763          0.003403469  0.003541957  0.003514017  0.002918090
# 165068 75236630          0.007170548  0.006989766  0.007398139  0.007333250
# 165069 75237624          0.015377169  0.014158496  0.014688450  0.014983206
# 165070 75238038          0.007312291  0.007797861  0.006370453  0.006434313
# 165071 75238178          0.005388113  0.005262569  0.004518876  0.004867464
# 165072 75240132          0.019104069  0.018633262  0.018053085  0.021129782
# 165073 75249174          0.012077739  0.011921153  0.009860948  0.012212507
# 165074 75250451          0.015201245  0.014064125  0.014835249  0.015238213
# 165075 75254708          0.012281418  0.011321523  0.011026689  0.012552147
# 165076 75254991          0.012183062  0.011388782  0.010914179  0.012387917
#        prob_4       prob_5       prob_6       prob_7       prob_8
# 1      0.0005673836 5.710906e-04 0.0007911533 5.478813e-04 0.0008291863
# 2      0.0012642101 9.406275e-04 0.0011525183 8.097091e-04 0.0008786271
# 3      0.0024426330 2.433602e-03 0.0026792192 2.114737e-03 0.0020589140
# 4      0.0002007829 1.989186e-04 0.0002452936 2.740229e-04 0.0003312677
# 5      0.0018964072 1.918127e-03 0.0017148565 2.519561e-03 0.0030068779
# 6      0.0009602833 1.605402e-03 0.0013362012 7.346924e-04 0.0014199926
# 7      0.0041293530 3.884990e-03 0.0079695164 4.472100e-03 0.0034419807
# 8      0.0005623529 4.575233e-04 0.0005178699 6.607517e-04 0.0005218177
# 9      0.0164657802 1.288817e-02 0.0163623764 1.070052e-02 0.0184011025
# 10     0.0002975748 3.325555e-04 0.0002527367 1.648525e-04 0.0002323330
# 11     0.0007603585 5.902826e-04 0.0005883104 5.171707e-04 0.0011135721
# 12     0.0052425336 5.848154e-03 0.0039555911 5.081598e-03 0.0051644658
# 13     0.0004744807 4.400281e-04 0.0004357910 4.441255e-04 0.0009482286
# 14     0.0008285003 7.505025e-04 0.0013798798 1.017902e-03 0.0009692169
# 15     0.0146525349 8.376059e-03 0.0180958251 7.120343e-03 0.0131909244
# 16     0.0002551293 2.138260e-04 0.0002629262 2.027623e-04 0.0001861726
# 17     0.0001236771 9.524936e-05 0.0001414357 5.355023e-05 0.0001092137
# 18     0.0002576739 1.274641e-04 0.0001494094 1.435178e-04 0.0002579087
# 19     0.0034023139 3.984870e-03 0.0031981957 4.700676e-03 0.0031722739
# 20     0.0001013226 1.272943e-04 0.0001385085 1.287588e-04 0.0001644339
# 21     0.0094623806 1.155485e-02 0.0093571988 7.633667e-03 0.0075629112
# 22     0.0032287701 3.255424e-03 0.0079288032 4.083444e-03 0.0031236097
# 23     0.0011742095 6.701753e-04 0.0008018923 9.561926e-04 0.0012653128
# 24     0.0015503057 2.149357e-03 0.0023817062 2.131613e-03 0.0018483670
# 25     0.0004065979 4.734263e-04 0.0005432361 3.347090e-04 0.0003681597
# 26     0.0015039566 2.149132e-03 0.0010963158 1.114895e-03 0.0019005252
# 27     0.0003335441 2.322778e-04 0.0002159605 2.369166e-04 0.0003421272
# 28     0.0007993348 9.320320e-04 0.0010314322 8.462314e-04 0.0008257203
# 29     0.0007268154 6.466916e-04 0.0009852647 7.380066e-04 0.0009567053
# 30     0.0004167103 2.150303e-04 0.0005445767 3.017703e-04 0.0004607642
# ⋮      ⋮            ⋮            ⋮            ⋮            ⋮
# 165047 0.021045421  0.020739429  0.016134027  0.016972662  0.019769383
# 165048 0.005054365  0.003734124  0.004846278  0.002585649  0.004257053
# 165049 0.005012638  0.003622597  0.004806179  0.004634534  0.006156385
# 165050 0.003801228  0.002499890  0.003154533  0.003615311  0.003804033
# 165051 0.011767873  0.009355048  0.012218265  0.009215714  0.012516741
# 165052 0.016489745  0.012657067  0.015938337  0.011871132  0.018003543
# 165053 0.009677160  0.009315910  0.008747389  0.007885933  0.011866350
# 165054 0.003303568  0.002311085  0.003395733  0.003228958  0.004049214
# 165055 0.016663775  0.012535375  0.012355846  0.011193362  0.014820695
# 165056 0.014816659  0.015239633  0.015004853  0.013039378  0.015327057
# 165057 0.003940526  0.002192626  0.002682405  0.002423002  0.003353397
# 165058 0.005911108  0.004494106  0.005566468  0.005687153  0.005808112
# 165059 0.011261495  0.008318248  0.007064488  0.007037464  0.013154897
# 165060 0.005051284  0.004046077  0.004807118  0.005096781  0.005500422
# 165061 0.010221398  0.008029442  0.008502753  0.007625302  0.010420702
# 165062 0.004594924  0.003372267  0.004096834  0.004054169  0.005327194
# 165063 0.007086720  0.006572341  0.009158180  0.006449063  0.008649734
# 165064 0.013697176  0.013375886  0.013779404  0.011841924  0.014018621
# 165065 0.012255653  0.010980505  0.012652714  0.011251522  0.013291163
# 165066 0.004277158  0.002724946  0.003503578  0.003243996  0.003785349
# 165067 0.004147818  0.002965801  0.003169095  0.003046886  0.003597029
# 165068 0.006341404  0.008189650  0.005860065  0.005452283  0.007920927
# 165069 0.017090580  0.015360607  0.015276076  0.013761676  0.018122362
# 165070 0.007581754  0.005891821  0.007321053  0.007666695  0.007314751
# 165071 0.006058351  0.004767682  0.005103867  0.005308985  0.006339230
# 165072 0.018752160  0.020478264  0.019151975  0.017215245  0.020095667
# 165073 0.013671344  0.011743581  0.013563270  0.011566922  0.013303846
# 165074 0.016375171  0.014519128  0.014434052  0.014153010  0.016906499
# 165075 0.012404128  0.011357851  0.013302868  0.011738662  0.014439331
# 165076 0.012754479  0.011143213  0.013222727  0.010844857  0.014456752
#        prob_9       prob_10
# 1      5.187902e-04 9.006217e-04
# 2      9.802483e-04 9.379630e-04
# 3      1.736985e-03 3.017446e-03
# 4      2.576524e-04 2.469174e-04
# 5      3.317991e-03 2.299997e-03
# 6      1.149527e-03 1.216739e-03
# 7      6.117694e-03 4.337952e-03
# 8      3.482988e-04 5.770864e-04
# 9      9.466991e-03 1.088031e-02
# 10     3.388892e-04 4.066999e-04
# 11     4.296139e-04 1.149951e-03
# 12     5.868684e-03 4.023807e-03
# 13     3.526619e-04 7.747579e-04
# 14     1.006301e-03 9.387458e-04
# 15     8.517512e-03 1.002767e-02
# 16     2.483647e-04 2.995197e-04
# 17     8.653460e-05 8.462435e-05
# 18     9.306586e-05 1.792881e-04
# 19     4.022769e-03 4.013226e-03
# 20     1.362126e-04 1.195000e-04
# 21     6.844353e-03 9.985977e-03
# 22     4.204215e-03 4.174918e-03
# 23     8.022012e-04 1.472292e-03
# 24     1.226680e-03 1.314349e-03
# 25     3.521148e-04 5.078702e-04
# 26     1.678128e-03 7.930402e-04
# 27     2.621162e-04 2.094082e-04
# 28     1.092394e-03 1.343124e-03
# 29     1.238552e-03 4.626369e-04
# 30     2.995567e-04 3.956385e-04
# ⋮      ⋮            ⋮
# 165047 0.016496187  0.018274640
# 165048 0.003755206  0.005338809
# 165049 0.004058838  0.004516728
# 165050 0.003180371  0.003629067
# 165051 0.009826205  0.011615924
# 165052 0.012319859  0.016927791
# 165053 0.006687071  0.008701544
# 165054 0.003370437  0.003483949
# 165055 0.009058718  0.012288398
# 165056 0.013902215  0.014470180
# 165057 0.002634898  0.003196824
# 165058 0.005345545  0.006264503
# 165059 0.007996189  0.010241788
# 165060 0.005036601  0.005567787
# 165061 0.007062450  0.008124349
# 165062 0.004187036  0.004405471
# 165063 0.005764003  0.008686785
# 165064 0.013941704  0.013772945
# 165065 0.010676240  0.012214906
# 165066 0.004069005  0.003848234
# 165067 0.003430559  0.003703436
# 165068 0.009585720  0.006634281
# 165069 0.014202657  0.016127581
# 165070 0.008245633  0.008498577
# 165071 0.005494222  0.006159886
# 165072 0.018513454  0.019017798
# 165073 0.010774490  0.012159328
# 165074 0.014103166  0.017383834
# 165075 0.011184973  0.013486014
# 165076 0.010886675  0.013831037

# %%
# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggles

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "data-mining-senior-2026-a"
PARAM$kaggle$cortes <- seq(8000, 12000, by = 500)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0(
    "./kaggle/KA",
    PARAM$experimento, "_",
    "s", length(PARAM$FT$semillas), "_",
    envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  Sys.sleep(30)
  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Warning message in dir.create("kaggle"):
# “'kaggle' already exists”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c data-mining-senior-2026-a -f ./kaggle/KA9900_s10_8000.csv -m 'envios=8000  semilla=998443'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c data-mining-senior-2026-a -f ./kaggle/KA9900_s10_8500.csv -m 'envios=8500  semilla=998443'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c data-mining-senior-2026-a -f ./kaggle/KA9900_s10_9000.csv -m 'envios=9000  semilla=998443'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c data-mining-senior-2026-a -f ./kaggle/KA9900_s10_9500.csv -m 'envios=9500  semilla=998443'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c data-mining-senior-2026-a -f ./kaggle/KA9900_s10_10000.csv -m 'envios=10000  semilla=998443'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c data-mining-senior-2026-a -f ./kaggle/KA9900_s10_10500.csv -m 'envios=10500  semilla=998443'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c data-mining-senior-2026-a -f ./kaggle/KA9900_s10_11000.csv -m 'envios=11000  semilla=998443'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c data-mining-senior-2026-a -f ./kaggle/KA9900_s10_11500.csv -m 'envios=11500  semilla=998443'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c data-mining-senior-2026-a -f ./kaggle/KA9900_s10_12000.csv -m 'envios=12000  semilla=998443'' had status 1”

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 23 02:46:44 2026"
